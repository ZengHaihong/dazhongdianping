# %%
import os
import requests
import re
from bs4 import BeautifulSoup
import lxml
import os.path
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException,WebDriverException
from selenium.webdriver.common.keys import Keys
import time
import warnings
warnings.filterwarnings("ignore")
import pickle
import pandas as pd
from requests.exceptions import ProxyError,ConnectionError,Timeout,HTTPError
import itertools
import multiprocessing
import Ipynb_importer
from IPpool import GetHeaders
from IPpool import Ip_pool
import random
import copy
# Out:
# importing Jupyter notebook from IPpool.ipynb

# %%
#**************将装机地址变成一组一组*****************
def get_chunk(adr_ls,n):
    new_adr_ls = copy.deepcopy(adr_ls)
    adr_chunk = [new_adr_ls[i:i + n] for i in range(0, len(new_adr_ls), n)]
    return adr_chunk

# %%
#设置谷歌浏览器的参数
def set_chrome_param():
    #PROXY = '175.155.24.61:808'
    options = webdriver.ChromeOptions()
    chrome_path = '/home/zhh/下载/chromedriver'  
    #options.add_argument('--proxy-server={0}'.format(PROXY))
    # 设置成中文
    options.add_argument('lang=zh_CN.UTF-8')
    # 添加头部
    #1允许所有图片；2阻止所有图片；3阻止第三方服务器图片
    prefs = {'profile.default_content_setting_values': { 'images':2}}
    options.add_experimental_option('prefs', prefs)
    options.add_argument('user-agent="Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.103 Safari/537.36"')
    chrome = webdriver.Chrome(chrome_path,chrome_options=options)
    return chrome

# %%
#requests请求网页，返回一个BeautifulSoup对象
def requests_visit_url(url,prox_ip=None):
    headers = {"Accept":"application/json, text/javascript, */*; q=0.01",
                    "Accept-Encoding":"gzip, deflate",
                    "Accept-Language":"zh-CN,zh;q=0.8,en;q=0.6",
                    "Connection":"keep-alive",
                    "Cookie":"_hc.v=f72dbe69-bcfc-a9d4-1f7f-d8daeca1ad7f.1505634421; __utma=1.1801105885.1505634423.1505634423.1505636820.2; __utmz=1.1505634423.1.1.utmcsr=google.com.hk|utmccn=(referral)|utmcmd=referral|utmcct=/; _lxsdk_cuid=15e956d9d5ec8-0a28c942cf39be-2a044871-100200-15e956d9d5fc8; _lxsdk=15e956d9d5ec8-0a28c942cf39be-2a044871-100200-15e956d9d5fc8; _lx_utm=utm_source%3DBaidu%26utm_medium%3Dorganic; __mta=222713764.1505836341840.1507819135553.1507819166825.4; JSESSIONID=D2D3D245867334198A59E676F146C5A8; aburl=1; cy=4; cye=guangzhou; s_ViewType=10; _lxsdk_s=15f2012787a-db4-26a-c8%7C%7C47",
                    "Host":"www.dianping.com",
                    "Referer":"http://www.dianping.com/shop/92374637",
                    #"User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/61.0.3163.100 Chrome/61.0.3163.100 Safari/537.36",
                    "X-Requested-With":"XMLHttpRequest"}
    headers["User-Agent"] = random.choice(GetHeaders().user_agent_list)
    #headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.103 Safari/537.36"}
    is_continue = True
    num = 0
    while is_continue:
        num +=1
        print("访问{0}次".format(num))
        try:
            if prox_ip is None:
                res = requests.get(url,headers = headers)  #访问url，不设代理ip访问
            else:
                http = prox_ip[0]
                ip = http+"://"+prox_ip[1]
                proxies={http:ip}
                res = requests.get(url,headers = headers,proxies = proxies) #设代理ip访问
            html =  res.content.decode('utf-8')
            soup  =  BeautifulSoup(html,'lxml')
            is_continue = False 
            
        except HTTPError as e:
            print("断网")
            time.sleep(2)
            
        except Timeout as e:
            print("请求超时")
            time.sleep(2)
            
        except ConnectionError as e:
            print("访问被拒")
            is_continue = True
            time.sleep(2)
    return soup

# %%
#缓存结果
def save_cache(result,filename):
    with open(filename,'wb') as f1:
        pickle.dump(result,f1)

# %%
#加载缓存
def read_cache(filename):
    with open(filename,'rb')as f1:
        result = pickle.load(f1)
    return result

# %%
# 切换路径
def get_spc_path(father_path,child_path):
    os.chdir(father_path)
    if os.path.exists(child_path):
        os.chdir(child_path)
    else:
        os.mkdir(child_path)
        os.chdir(child_path)
    print("done!!")

# %% [markdown]
# ## 1.二级分类层

# %%
# %%time
#获取所有的二级分类url
def classify(city_url,city,big_class):
    soup = requests_visit_url(city_url)
    clf_ls = []
    for i in soup.select("#classfy a"):
        clf_url = i["href"] #分类网址
        clf_tl = i.text.strip() # 分类标题
        clf_ls.append([big_class,city,clf_tl,clf_url])
    return clf_ls
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 11 µs

# %%
# %%time
# clf_ls = classify("http://www.dianping.com/search/category/7/10",'深圳',"美食")

# %% [markdown]
# ## 2.区县层

# %%
def get_region(class_ls=None,prox_ip=None):
    print('正在爬取{0}'.format(class_ls[-2]))
    url = class_ls[-1]  #url
    soup = requests_visit_url(url,prox_ip) #访问
    region_ls = [] #地区的列表
    for i in soup.select("#region-nav a"):
        if i.text.strip() != "不限":
            region_url = i["href"] 
            region_tl = i.text.strip()
            region = class_ls[:-1]
            region.extend([region_tl,region_url])
            region_ls.append(region)
    return region_ls

# %%
# ip = Ip_pool(['http://www.xicidaili.com/nn/'])
# ip_pool = ip.get_ip_pool(test_url='http://www.dianping.com/search/category/7/10/g104',timeout =1)

# %%
# %%time
# prox_ip = random.choice(ip_pool)
# region_ls = []
# for i in clf_ls:
#     print(i)
#     sub_region = get_region(i,prox_ip)
#     region_ls.append(sub_region)

# %%
# region_ls

# %% [markdown]
# ## 3.商圈层

# %%
def get_circle(region_ls=None):
    url = region_ls[-1]   #url网址
    soup = requests_visit_url(url) #访问BeautifulSoup
    circle_ls =[]             
    for i in soup.select("#region-nav-sub a"):  #商圈信息
        if i.span.text.strip()!="不限":   #剔除掉不限的url
            circle_url = i["href"]       #商圈url
            circle_tit = i.span.text.strip()  #商圈名
            circle = region_ls[:-1] 
            circle.extend([circle_tit,circle_url]) 
            circle_ls.append(circle)
            
    #如果没有商圈的话，就拿原来的url当作是商圈的url
    if circle_ls==[]:
        print(region_ls[-2]+"没有子分类！！")
        region_ls.insert(4,"没有商圈")
        circle_ls.append(region_ls)

    return circle_ls

# %%
# %%time
# circle_ls = get_circle(['美食',
#   '广州',
#   '茶餐厅',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g207r22'])

# %% [markdown]
# ## 4.商家信息层

# %%
#获取每个商家的链接、店名
def get_stores(circle_ls = None):
    store_ls=[] #存储的列表
    url = circle_ls[-1]  #url
    soup = requests_visit_url(url)  #访问当前主页
    is_continue = True
    page = 0
    while is_continue:
        page += 1
        print("正在爬取第{0}页".format(page))
        
        #解析数据
        if soup.select(".content") ==[]:
            print("此页没有任何信息！！")
            store_ls = []
            is_continue = False 
            
        else:
            for i in soup.select(".content"):  
                for j in i.select(".pic"):
                    store_name = j.img["alt"]   #店名
                    link = j.a["href"]     #详情层
                    store = circle_ls[:5]  #只取前5位
                    store.extend([url,store_name,link]) 
                    store_ls.append(store)


            #获取下一页的数据
            time.sleep(2)

            next_tag = soup.find_all("a",text = re.compile("下一页"))  #获取字符属性为下一页的url
            if next_tag != []:                                         #保证含有字符属性
                url = next_tag[0]["href"]                              #获取下一页的url
                soup = requests_visit_url(url)                         #更新BeautifulSoup对象
                time.sleep(2)
            else:
                url = ''
                is_continue  = False                                  #如果没有下一页，就停止更新
    
    return store_ls

# %%
# %%time
# store_ls = get_stores(['美食',
#   '广州',
#   '茶餐厅',
#   '天河区',
#   '天河城/体育中心',
#   'http://www.dianping.com/search/category/4/10/g207r1519'])

# %% [markdown]
# ###### get_info_vesion2()

# %% [markdown]
# ## 5.详情层

# %%
#获取详情层的数据，如星级用户、浏览人数、均价
def get_info(store_ls=None):
    
    #首先先保证导入的数据不为空
    if store_ls !=[]:
        url = store_ls[-1] #详情信息表
        soup = requests_visit_url(url)
        try:
            start = soup.select(".mid-rank-stars")[0]["title"]       #星级用户
        except Exception as e:
            print("start",e)
            start = ''

        try:
            review_count = soup.select("#reviewCount")[0].text  #浏览人数
        except Exception as e:
            review_count = ''
            print("review_coun",e)

        try:
            avgprice = soup.select("#avgPriceTitle")[0].text   #均价
        except Exception as e:
            avgprice = ''
            print("avgprice",e)

        #评分系统
        try:
            score= []
            for j in soup.select("#comment_score .item"):
                score.append(j.text)
            score = "|".join(score)

        except Exception as e:
            score = ""
            print("score",e)

        try:   
            address = soup.select(".address .item")[0].text.strip() #地址
        except Exception as e:
            address = ''
            print("address出错了",e)

        #电话号码
        try:
            tel =[]
            for i in soup.select(".tel .item"):
                tel.append(i.text)
            tel = "|".join(tel)

        except:
            tel=""
            print("tel出错了",e)

        #路径
        try:
            path = []
            for i in soup.select(".breadcrumb a"):
                path.append(i.text.strip())
            path ='>'.join(path)
        except Exception as e:
            print("path出错了",e)
            path =''

        info = store_ls[:]
        info.extend([start,review_count,avgprice,score,address,tel,path])
    return info

# %%
# get_info(['美食',
#   '广州',
#   '茶餐厅',
#   '天河区',
#   '天河城/体育中心',
#   'http://www.dianping.com/search/category/4/10/g207r1519p2',
#   '粤港烧卤鸭饭(天河店)',
#   'http://www.dianping.com/shop/94311152'])

# %% [markdown]
# ## 6 主程序

# %%
# %%time

clf_ls = classify("http://www.dianping.com/search/category/4/10",'广州',"美食")
print("所有二级分类已经获取完毕")

region_ls = list(map(get_region,clf_ls))
print("获取所有的区域清单")
# Out:
# 所有二级分类已经获取完毕
# 正在爬取快餐简餐
# 正在爬取粤菜
# 正在爬取自助餐
# 正在爬取日本料理
# 正在爬取面包甜点
# 正在爬取西餐
# 正在爬取咖啡厅
# 正在爬取韩国料理
# 正在爬取火锅
# 正在爬取川菜
# 正在爬取茶餐厅
# 正在爬取小吃
# 正在爬取小龙虾
# 正在爬取东南亚菜
# 正在爬取素菜
# 正在爬取烧烤
# 正在爬取海鲜
# 正在爬取创意菜
# 正在爬取湘菜
# 正在爬取粥粉面
# 正在爬取台湾菜
# 正在爬取新疆菜
# 正在爬取江浙菜
# 正在爬取东北菜
# 正在爬取私房菜
# 正在爬取西北菜
# 正在爬取湖北菜
# 正在爬取其他
# 正在爬取江西菜
# 正在爬取家常菜
# 获取所有的区域清单
# CPU times: user 6.27 s, sys: 124 ms, total: 6.39 s
# Wall time: 52 s

# %%
#解链
region_ls = list(itertools.chain.from_iterable(region_ls))
region_ls
# Out:
# [['美食',
#   '广州',
#   '快餐简餐',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g210r22'],
#  ['美食',
#   '广州',
#   '快餐简餐',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g210r24'],
#  ['美食',
#   '广州',
#   '快餐简餐',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g210r25'],
#  ['美食',
#   '广州',
#   '快餐简餐',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g210r27'],
#  ['美食',
#   '广州',
#   '快餐简餐',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g210r621'],
#  ['美食',
#   '广州',
#   '快餐简餐',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g210r26'],
#  ['美食',
#   '广州',
#   '快餐简餐',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g210r1552'],
#  ['美食',
#   '广州',
#   '快餐简餐',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g210r1554'],
#  ['美食',
#   '广州',
#   '快餐简餐',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g210r1555'],
#  ['美食',
#   '广州',
#   '快餐简餐',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g210r1549'],
#  ['美食',
#   '广州',
#   '快餐简餐',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g210r1964'],
#  ['美食',
#   '广州',
#   '快餐简餐',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g210r1963'],
#  ['美食',
#   '广州',
#   '粤菜',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g103r22'],
#  ['美食',
#   '广州',
#   '粤菜',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g103r24'],
#  ['美食',
#   '广州',
#   '粤菜',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g103r25'],
#  ['美食',
#   '广州',
#   '粤菜',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g103r27'],
#  ['美食',
#   '广州',
#   '粤菜',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g103r621'],
#  ['美食',
#   '广州',
#   '粤菜',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g103r26'],
#  ['美食',
#   '广州',
#   '粤菜',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g103r1552'],
#  ['美食',
#   '广州',
#   '粤菜',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g103r1554'],
#  ['美食',
#   '广州',
#   '粤菜',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g103r1555'],
#  ['美食',
#   '广州',
#   '粤菜',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g103r1549'],
#  ['美食',
#   '广州',
#   '粤菜',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g103r1964'],
#  ['美食',
#   '广州',
#   '粤菜',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g103r1963'],
#  ['美食',
#   '广州',
#   '自助餐',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g111r22'],
#  ['美食',
#   '广州',
#   '自助餐',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g111r24'],
#  ['美食',
#   '广州',
#   '自助餐',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g111r25'],
#  ['美食',
#   '广州',
#   '自助餐',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g111r27'],
#  ['美食',
#   '广州',
#   '自助餐',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g111r621'],
#  ['美食',
#   '广州',
#   '自助餐',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g111r26'],
#  ['美食',
#   '广州',
#   '自助餐',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g111r1552'],
#  ['美食',
#   '广州',
#   '自助餐',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g111r1554'],
#  ['美食',
#   '广州',
#   '自助餐',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g111r1555'],
#  ['美食',
#   '广州',
#   '自助餐',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g111r1549'],
#  ['美食',
#   '广州',
#   '自助餐',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g111r1964'],
#  ['美食',
#   '广州',
#   '自助餐',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g111r1963'],
#  ['美食',
#   '广州',
#   '日本料理',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g113r22'],
#  ['美食',
#   '广州',
#   '日本料理',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g113r24'],
#  ['美食',
#   '广州',
#   '日本料理',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g113r25'],
#  ['美食',
#   '广州',
#   '日本料理',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g113r27'],
#  ['美食',
#   '广州',
#   '日本料理',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g113r621'],
#  ['美食',
#   '广州',
#   '日本料理',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g113r26'],
#  ['美食',
#   '广州',
#   '日本料理',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g113r1552'],
#  ['美食',
#   '广州',
#   '日本料理',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g113r1554'],
#  ['美食',
#   '广州',
#   '日本料理',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g113r1555'],
#  ['美食',
#   '广州',
#   '日本料理',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g113r1549'],
#  ['美食',
#   '广州',
#   '日本料理',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g113r1964'],
#  ['美食',
#   '广州',
#   '日本料理',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g113r1963'],
#  ['美食',
#   '广州',
#   '面包甜点',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g117r22'],
#  ['美食',
#   '广州',
#   '面包甜点',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g117r24'],
#  ['美食',
#   '广州',
#   '面包甜点',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g117r25'],
#  ['美食',
#   '广州',
#   '面包甜点',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g117r27'],
#  ['美食',
#   '广州',
#   '面包甜点',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g117r621'],
#  ['美食',
#   '广州',
#   '面包甜点',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g117r26'],
#  ['美食',
#   '广州',
#   '面包甜点',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g117r1552'],
#  ['美食',
#   '广州',
#   '面包甜点',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g117r1554'],
#  ['美食',
#   '广州',
#   '面包甜点',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g117r1555'],
#  ['美食',
#   '广州',
#   '面包甜点',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g117r1549'],
#  ['美食',
#   '广州',
#   '面包甜点',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g117r1964'],
#  ['美食',
#   '广州',
#   '面包甜点',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g117r1963'],
#  ['美食',
#   '广州',
#   '西餐',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g116r22'],
#  ['美食',
#   '广州',
#   '西餐',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g116r24'],
#  ['美食',
#   '广州',
#   '西餐',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g116r25'],
#  ['美食',
#   '广州',
#   '西餐',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g116r27'],
#  ['美食',
#   '广州',
#   '西餐',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g116r621'],
#  ['美食',
#   '广州',
#   '西餐',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g116r26'],
#  ['美食',
#   '广州',
#   '西餐',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g116r1552'],
#  ['美食',
#   '广州',
#   '西餐',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g116r1554'],
#  ['美食',
#   '广州',
#   '西餐',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g116r1555'],
#  ['美食',
#   '广州',
#   '西餐',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g116r1549'],
#  ['美食',
#   '广州',
#   '西餐',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g116r1964'],
#  ['美食',
#   '广州',
#   '西餐',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g116r1963'],
#  ['美食',
#   '广州',
#   '咖啡厅',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g132r22'],
#  ['美食',
#   '广州',
#   '咖啡厅',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g132r24'],
#  ['美食',
#   '广州',
#   '咖啡厅',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g132r25'],
#  ['美食',
#   '广州',
#   '咖啡厅',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g132r27'],
#  ['美食',
#   '广州',
#   '咖啡厅',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g132r621'],
#  ['美食',
#   '广州',
#   '咖啡厅',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g132r26'],
#  ['美食',
#   '广州',
#   '咖啡厅',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g132r1552'],
#  ['美食',
#   '广州',
#   '咖啡厅',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g132r1554'],
#  ['美食',
#   '广州',
#   '咖啡厅',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g132r1555'],
#  ['美食',
#   '广州',
#   '咖啡厅',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g132r1549'],
#  ['美食',
#   '广州',
#   '咖啡厅',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g132r1964'],
#  ['美食',
#   '广州',
#   '咖啡厅',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g132r1963'],
#  ['美食',
#   '广州',
#   '韩国料理',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g114r22'],
#  ['美食',
#   '广州',
#   '韩国料理',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g114r24'],
#  ['美食',
#   '广州',
#   '韩国料理',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g114r25'],
#  ['美食',
#   '广州',
#   '韩国料理',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g114r27'],
#  ['美食',
#   '广州',
#   '韩国料理',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g114r621'],
#  ['美食',
#   '广州',
#   '韩国料理',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g114r26'],
#  ['美食',
#   '广州',
#   '韩国料理',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g114r1552'],
#  ['美食',
#   '广州',
#   '韩国料理',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g114r1554'],
#  ['美食',
#   '广州',
#   '韩国料理',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g114r1555'],
#  ['美食',
#   '广州',
#   '韩国料理',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g114r1549'],
#  ['美食',
#   '广州',
#   '韩国料理',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g114r1964'],
#  ['美食',
#   '广州',
#   '韩国料理',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g114r1963'],
#  ['美食',
#   '广州',
#   '火锅',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g110r22'],
#  ['美食',
#   '广州',
#   '火锅',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g110r24'],
#  ['美食',
#   '广州',
#   '火锅',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g110r25'],
#  ['美食',
#   '广州',
#   '火锅',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g110r27'],
#  ['美食',
#   '广州',
#   '火锅',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g110r621'],
#  ['美食',
#   '广州',
#   '火锅',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g110r26'],
#  ['美食',
#   '广州',
#   '火锅',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g110r1552'],
#  ['美食',
#   '广州',
#   '火锅',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g110r1554'],
#  ['美食',
#   '广州',
#   '火锅',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g110r1555'],
#  ['美食',
#   '广州',
#   '火锅',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g110r1549'],
#  ['美食',
#   '广州',
#   '火锅',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g110r1964'],
#  ['美食',
#   '广州',
#   '火锅',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g110r1963'],
#  ['美食',
#   '广州',
#   '川菜',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g102r22'],
#  ['美食',
#   '广州',
#   '川菜',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g102r24'],
#  ['美食',
#   '广州',
#   '川菜',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g102r25'],
#  ['美食',
#   '广州',
#   '川菜',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g102r27'],
#  ['美食',
#   '广州',
#   '川菜',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g102r621'],
#  ['美食',
#   '广州',
#   '川菜',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g102r26'],
#  ['美食',
#   '广州',
#   '川菜',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g102r1552'],
#  ['美食',
#   '广州',
#   '川菜',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g102r1554'],
#  ['美食',
#   '广州',
#   '川菜',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g102r1555'],
#  ['美食',
#   '广州',
#   '川菜',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g102r1549'],
#  ['美食',
#   '广州',
#   '川菜',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g102r1964'],
#  ['美食',
#   '广州',
#   '川菜',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g102r1963'],
#  ['美食',
#   '广州',
#   '茶餐厅',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g207r22'],
#  ['美食',
#   '广州',
#   '茶餐厅',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g207r24'],
#  ['美食',
#   '广州',
#   '茶餐厅',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g207r25'],
#  ['美食',
#   '广州',
#   '茶餐厅',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g207r27'],
#  ['美食',
#   '广州',
#   '茶餐厅',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g207r621'],
#  ['美食',
#   '广州',
#   '茶餐厅',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g207r26'],
#  ['美食',
#   '广州',
#   '茶餐厅',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g207r1552'],
#  ['美食',
#   '广州',
#   '茶餐厅',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g207r1554'],
#  ['美食',
#   '广州',
#   '茶餐厅',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g207r1555'],
#  ['美食',
#   '广州',
#   '茶餐厅',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g207r1549'],
#  ['美食',
#   '广州',
#   '茶餐厅',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g207r1964'],
#  ['美食',
#   '广州',
#   '茶餐厅',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g207r1963'],
#  ['美食',
#   '广州',
#   '小吃',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g217r22'],
#  ['美食',
#   '广州',
#   '小吃',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g217r24'],
#  ['美食',
#   '广州',
#   '小吃',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g217r25'],
#  ['美食',
#   '广州',
#   '小吃',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g217r27'],
#  ['美食',
#   '广州',
#   '小吃',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g217r621'],
#  ['美食',
#   '广州',
#   '小吃',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g217r26'],
#  ['美食',
#   '广州',
#   '小吃',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g217r1552'],
#  ['美食',
#   '广州',
#   '小吃',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g217r1554'],
#  ['美食',
#   '广州',
#   '小吃',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g217r1555'],
#  ['美食',
#   '广州',
#   '小吃',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g217r1549'],
#  ['美食',
#   '广州',
#   '小吃',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g217r1964'],
#  ['美食',
#   '广州',
#   '小吃',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g217r1963'],
#  ['美食',
#   '广州',
#   '小龙虾',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g219r22'],
#  ['美食',
#   '广州',
#   '小龙虾',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g219r24'],
#  ['美食',
#   '广州',
#   '小龙虾',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g219r25'],
#  ['美食',
#   '广州',
#   '小龙虾',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g219r27'],
#  ['美食',
#   '广州',
#   '小龙虾',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g219r621'],
#  ['美食',
#   '广州',
#   '小龙虾',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g219r26'],
#  ['美食',
#   '广州',
#   '小龙虾',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g219r1552'],
#  ['美食',
#   '广州',
#   '小龙虾',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g219r1554'],
#  ['美食',
#   '广州',
#   '小龙虾',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g219r1555'],
#  ['美食',
#   '广州',
#   '小龙虾',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g219r1549'],
#  ['美食',
#   '广州',
#   '小龙虾',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g219r1964'],
#  ['美食',
#   '广州',
#   '小龙虾',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g219r1963'],
#  ['美食',
#   '广州',
#   '东南亚菜',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g115r22'],
#  ['美食',
#   '广州',
#   '东南亚菜',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g115r24'],
#  ['美食',
#   '广州',
#   '东南亚菜',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g115r25'],
#  ['美食',
#   '广州',
#   '东南亚菜',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g115r27'],
#  ['美食',
#   '广州',
#   '东南亚菜',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g115r621'],
#  ['美食',
#   '广州',
#   '东南亚菜',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g115r26'],
#  ['美食',
#   '广州',
#   '东南亚菜',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g115r1552'],
#  ['美食',
#   '广州',
#   '东南亚菜',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g115r1554'],
#  ['美食',
#   '广州',
#   '东南亚菜',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g115r1555'],
#  ['美食',
#   '广州',
#   '东南亚菜',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g115r1549'],
#  ['美食',
#   '广州',
#   '东南亚菜',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g115r1964'],
#  ['美食',
#   '广州',
#   '东南亚菜',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g115r1963'],
#  ['美食',
#   '广州',
#   '素菜',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g109r22'],
#  ['美食',
#   '广州',
#   '素菜',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g109r24'],
#  ['美食',
#   '广州',
#   '素菜',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g109r25'],
#  ['美食',
#   '广州',
#   '素菜',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g109r27'],
#  ['美食',
#   '广州',
#   '素菜',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g109r621'],
#  ['美食',
#   '广州',
#   '素菜',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g109r26'],
#  ['美食',
#   '广州',
#   '素菜',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g109r1552'],
#  ['美食',
#   '广州',
#   '素菜',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g109r1554'],
#  ['美食',
#   '广州',
#   '素菜',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g109r1555'],
#  ['美食',
#   '广州',
#   '素菜',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g109r1549'],
#  ['美食',
#   '广州',
#   '素菜',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g109r1963'],
#  ['美食',
#   '广州',
#   '烧烤',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g508r22'],
#  ['美食',
#   '广州',
#   '烧烤',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g508r24'],
#  ['美食',
#   '广州',
#   '烧烤',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g508r25'],
#  ['美食',
#   '广州',
#   '烧烤',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g508r27'],
#  ['美食',
#   '广州',
#   '烧烤',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g508r621'],
#  ['美食',
#   '广州',
#   '烧烤',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g508r26'],
#  ['美食',
#   '广州',
#   '烧烤',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g508r1552'],
#  ['美食',
#   '广州',
#   '烧烤',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g508r1554'],
#  ['美食',
#   '广州',
#   '烧烤',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g508r1555'],
#  ['美食',
#   '广州',
#   '烧烤',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g508r1549'],
#  ['美食',
#   '广州',
#   '烧烤',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g508r1964'],
#  ['美食',
#   '广州',
#   '烧烤',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g508r1963'],
#  ['美食',
#   '广州',
#   '海鲜',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g251r22'],
#  ['美食',
#   '广州',
#   '海鲜',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g251r24'],
#  ['美食',
#   '广州',
#   '海鲜',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g251r25'],
#  ['美食',
#   '广州',
#   '海鲜',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g251r27'],
#  ['美食',
#   '广州',
#   '海鲜',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g251r621'],
#  ['美食',
#   '广州',
#   '海鲜',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g251r26'],
#  ['美食',
#   '广州',
#   '海鲜',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g251r1552'],
#  ['美食',
#   '广州',
#   '海鲜',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g251r1554'],
#  ['美食',
#   '广州',
#   '海鲜',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g251r1555'],
#  ['美食',
#   '广州',
#   '海鲜',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g251r1549'],
#  ['美食',
#   '广州',
#   '海鲜',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g251r1964'],
#  ['美食',
#   '广州',
#   '海鲜',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g251r1963'],
#  ['美食',
#   '广州',
#   '创意菜',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g250r22'],
#  ['美食',
#   '广州',
#   '创意菜',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g250r24'],
#  ['美食',
#   '广州',
#   '创意菜',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g250r25'],
#  ['美食',
#   '广州',
#   '创意菜',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g250r27'],
#  ['美食',
#   '广州',
#   '创意菜',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g250r621'],
#  ['美食',
#   '广州',
#   '创意菜',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g250r26'],
#  ['美食',
#   '广州',
#   '创意菜',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g250r1552'],
#  ['美食',
#   '广州',
#   '创意菜',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g250r1554'],
#  ['美食',
#   '广州',
#   '创意菜',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g250r1555'],
#  ['美食',
#   '广州',
#   '创意菜',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g250r1964'],
#  ['美食',
#   '广州',
#   '创意菜',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g250r1963'],
#  ['美食',
#   '广州',
#   '创意菜',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g250r1549'],
#  ['美食',
#   '广州',
#   '湘菜',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g104r22'],
#  ['美食',
#   '广州',
#   '湘菜',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g104r24'],
#  ['美食',
#   '广州',
#   '湘菜',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g104r25'],
#  ['美食',
#   '广州',
#   '湘菜',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g104r27'],
#  ['美食',
#   '广州',
#   '湘菜',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g104r621'],
#  ['美食',
#   '广州',
#   '湘菜',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g104r26'],
#  ['美食',
#   '广州',
#   '湘菜',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g104r1552'],
#  ['美食',
#   '广州',
#   '湘菜',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g104r1554'],
#  ['美食',
#   '广州',
#   '湘菜',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g104r1555'],
#  ['美食',
#   '广州',
#   '湘菜',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g104r1549'],
#  ['美食',
#   '广州',
#   '湘菜',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g104r1964'],
#  ['美食',
#   '广州',
#   '湘菜',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g104r1963'],
#  ['美食',
#   '广州',
#   '粥粉面',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g1959r22'],
#  ['美食',
#   '广州',
#   '粥粉面',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g1959r24'],
#  ['美食',
#   '广州',
#   '粥粉面',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g1959r25'],
#  ['美食',
#   '广州',
#   '粥粉面',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g1959r27'],
#  ['美食',
#   '广州',
#   '粥粉面',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g1959r621'],
#  ['美食',
#   '广州',
#   '粥粉面',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g1959r26'],
#  ['美食',
#   '广州',
#   '粥粉面',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g1959r1552'],
#  ['美食',
#   '广州',
#   '粥粉面',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g1959r1554'],
#  ['美食',
#   '广州',
#   '粥粉面',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g1959r1555'],
#  ['美食',
#   '广州',
#   '粥粉面',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g1959r1549'],
#  ['美食',
#   '广州',
#   '粥粉面',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g1959r1964'],
#  ['美食',
#   '广州',
#   '粥粉面',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g1959r1963'],
#  ['美食',
#   '广州',
#   '台湾菜',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g107r22'],
#  ['美食',
#   '广州',
#   '台湾菜',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g107r24'],
#  ['美食',
#   '广州',
#   '台湾菜',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g107r25'],
#  ['美食',
#   '广州',
#   '台湾菜',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g107r27'],
#  ['美食',
#   '广州',
#   '台湾菜',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g107r621'],
#  ['美食',
#   '广州',
#   '台湾菜',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g107r26'],
#  ['美食',
#   '广州',
#   '台湾菜',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g107r1552'],
#  ['美食',
#   '广州',
#   '台湾菜',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g107r1554'],
#  ['美食',
#   '广州',
#   '台湾菜',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g107r1555'],
#  ['美食',
#   '广州',
#   '台湾菜',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g107r1964'],
#  ['美食',
#   '广州',
#   '台湾菜',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g107r1963'],
#  ['美食',
#   '广州',
#   '台湾菜',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g107r1549'],
#  ['美食',
#   '广州',
#   '新疆菜',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g3243r22'],
#  ['美食',
#   '广州',
#   '新疆菜',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g3243r24'],
#  ['美食',
#   '广州',
#   '新疆菜',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g3243r25'],
#  ['美食',
#   '广州',
#   '新疆菜',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g3243r27'],
#  ['美食',
#   '广州',
#   '新疆菜',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g3243r621'],
#  ['美食',
#   '广州',
#   '新疆菜',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g3243r26'],
#  ['美食',
#   '广州',
#   '新疆菜',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g3243r1552'],
#  ['美食',
#   '广州',
#   '新疆菜',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g3243r1554'],
#  ['美食',
#   '广州',
#   '新疆菜',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g3243r1549'],
#  ['美食',
#   '广州',
#   '新疆菜',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g3243r1964'],
#  ['美食',
#   '广州',
#   '新疆菜',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g3243r1555'],
#  ['美食',
#   '广州',
#   '新疆菜',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g3243r1963'],
#  ['美食',
#   '广州',
#   '江浙菜',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g101r22'],
#  ['美食',
#   '广州',
#   '江浙菜',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g101r24'],
#  ['美食',
#   '广州',
#   '江浙菜',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g101r25'],
#  ['美食',
#   '广州',
#   '江浙菜',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g101r27'],
#  ['美食',
#   '广州',
#   '江浙菜',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g101r621'],
#  ['美食',
#   '广州',
#   '江浙菜',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g101r26'],
#  ['美食',
#   '广州',
#   '江浙菜',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g101r1552'],
#  ['美食',
#   '广州',
#   '江浙菜',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g101r1554'],
#  ['美食',
#   '广州',
#   '江浙菜',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g101r1555'],
#  ['美食',
#   '广州',
#   '江浙菜',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g101r1549'],
#  ['美食',
#   '广州',
#   '江浙菜',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g101r1964'],
#  ['美食',
#   '广州',
#   '江浙菜',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g101r1963'],
#  ['美食',
#   '广州',
#   '东北菜',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g106r22'],
#  ['美食',
#   '广州',
#   '东北菜',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g106r24'],
#  ['美食',
#   '广州',
#   '东北菜',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g106r25'],
#  ['美食',
#   '广州',
#   '东北菜',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g106r27'],
#  ['美食',
#   '广州',
#   '东北菜',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g106r621'],
#  ['美食',
#   '广州',
#   '东北菜',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g106r26'],
#  ['美食',
#   '广州',
#   '东北菜',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g106r1552'],
#  ['美食',
#   '广州',
#   '东北菜',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g106r1554'],
#  ['美食',
#   '广州',
#   '东北菜',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g106r1555'],
#  ['美食',
#   '广州',
#   '东北菜',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g106r1549'],
#  ['美食',
#   '广州',
#   '东北菜',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g106r1964'],
#  ['美食',
#   '广州',
#   '东北菜',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g106r1963'],
#  ['美食',
#   '广州',
#   '私房菜',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g1338r22'],
#  ['美食',
#   '广州',
#   '私房菜',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g1338r24'],
#  ['美食',
#   '广州',
#   '私房菜',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g1338r25'],
#  ['美食',
#   '广州',
#   '私房菜',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g1338r27'],
#  ['美食',
#   '广州',
#   '私房菜',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g1338r621'],
#  ['美食',
#   '广州',
#   '私房菜',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g1338r26'],
#  ['美食',
#   '广州',
#   '私房菜',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g1338r1552'],
#  ['美食',
#   '广州',
#   '私房菜',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g1338r1554'],
#  ['美食',
#   '广州',
#   '私房菜',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g1338r1555'],
#  ['美食',
#   '广州',
#   '私房菜',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g1338r1549'],
#  ['美食',
#   '广州',
#   '私房菜',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g1338r1964'],
#  ['美食',
#   '广州',
#   '私房菜',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g1338r1963'],
#  ['美食',
#   '广州',
#   '西北菜',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g26481r22'],
#  ['美食',
#   '广州',
#   '西北菜',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g26481r24'],
#  ['美食',
#   '广州',
#   '西北菜',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g26481r25'],
#  ['美食',
#   '广州',
#   '西北菜',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g26481r27'],
#  ['美食',
#   '广州',
#   '西北菜',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g26481r621'],
#  ['美食',
#   '广州',
#   '西北菜',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g26481r26'],
#  ['美食',
#   '广州',
#   '西北菜',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g26481r1552'],
#  ['美食',
#   '广州',
#   '西北菜',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g26481r1554'],
#  ['美食',
#   '广州',
#   '西北菜',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g26481r1555'],
#  ['美食',
#   '广州',
#   '西北菜',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g26481r1549'],
#  ['美食',
#   '广州',
#   '西北菜',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g26481r1964'],
#  ['美食',
#   '广州',
#   '西北菜',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g26481r1963'],
#  ['美食',
#   '广州',
#   '湖北菜',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g246r22'],
#  ['美食',
#   '广州',
#   '湖北菜',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g246r24'],
#  ['美食',
#   '广州',
#   '湖北菜',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g246r25'],
#  ['美食',
#   '广州',
#   '湖北菜',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g246r27'],
#  ['美食',
#   '广州',
#   '湖北菜',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g246r621'],
#  ['美食',
#   '广州',
#   '湖北菜',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g246r1552'],
#  ['美食',
#   '广州',
#   '湖北菜',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g246r1554'],
#  ['美食',
#   '广州',
#   '湖北菜',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g246r1555'],
#  ['美食',
#   '广州',
#   '湖北菜',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g246r1549'],
#  ['美食',
#   '广州',
#   '湖北菜',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g246r1964'],
#  ['美食',
#   '广州',
#   '湖北菜',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g246r1963'],
#  ['美食',
#   '广州',
#   '湖北菜',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g246r26'],
#  ['美食',
#   '广州',
#   '其他',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g118r22'],
#  ['美食',
#   '广州',
#   '其他',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g118r24'],
#  ['美食',
#   '广州',
#   '其他',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g118r25'],
#  ['美食',
#   '广州',
#   '其他',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g118r27'],
#  ['美食',
#   '广州',
#   '其他',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g118r621'],
#  ['美食',
#   '广州',
#   '其他',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g118r26'],
#  ['美食',
#   '广州',
#   '其他',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g118r1552'],
#  ['美食',
#   '广州',
#   '其他',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g118r1554'],
#  ['美食',
#   '广州',
#   '其他',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g118r1555'],
#  ['美食',
#   '广州',
#   '其他',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g118r1549'],
#  ['美食',
#   '广州',
#   '其他',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g118r1964'],
#  ['美食',
#   '广州',
#   '其他',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g118r1963'],
#  ['美食',
#   '广州',
#   '江西菜',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g247r22'],
#  ['美食',
#   '广州',
#   '江西菜',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g247r24'],
#  ['美食',
#   '广州',
#   '江西菜',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g247r25'],
#  ['美食',
#   '广州',
#   '江西菜',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g247r27'],
#  ['美食',
#   '广州',
#   '江西菜',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g247r621'],
#  ['美食',
#   '广州',
#   '江西菜',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g247r26'],
#  ['美食',
#   '广州',
#   '江西菜',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g247r1552'],
#  ['美食',
#   '广州',
#   '江西菜',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g247r1554'],
#  ['美食',
#   '广州',
#   '江西菜',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g247r1555'],
#  ['美食',
#   '广州',
#   '江西菜',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g247r1964'],
#  ['美食',
#   '广州',
#   '江西菜',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g247r1963'],
#  ['美食',
#   '广州',
#   '江西菜',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g247r1549'],
#  ['美食',
#   '广州',
#   '家常菜',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g1783r22'],
#  ['美食',
#   '广州',
#   '家常菜',
#   '越秀区',
#   'http://www.dianping.com/search/category/4/10/g1783r24'],
#  ['美食',
#   '广州',
#   '家常菜',
#   '海珠区',
#   'http://www.dianping.com/search/category/4/10/g1783r25'],
#  ['美食',
#   '广州',
#   '家常菜',
#   '白云区',
#   'http://www.dianping.com/search/category/4/10/g1783r27'],
#  ['美食',
#   '广州',
#   '家常菜',
#   '番禺区',
#   'http://www.dianping.com/search/category/4/10/g1783r621'],
#  ['美食',
#   '广州',
#   '家常菜',
#   '荔湾区',
#   'http://www.dianping.com/search/category/4/10/g1783r26'],
#  ['美食',
#   '广州',
#   '家常菜',
#   '花都区',
#   'http://www.dianping.com/search/category/4/10/g1783r1552'],
#  ['美食',
#   '广州',
#   '家常菜',
#   '增城区',
#   'http://www.dianping.com/search/category/4/10/g1783r1554'],
#  ['美食',
#   '广州',
#   '家常菜',
#   '从化区',
#   'http://www.dianping.com/search/category/4/10/g1783r1555'],
#  ['美食',
#   '广州',
#   '家常菜',
#   '黄埔区',
#   'http://www.dianping.com/search/category/4/10/g1783r1549'],
#  ['美食',
#   '广州',
#   '家常菜',
#   '萝岗区',
#   'http://www.dianping.com/search/category/4/10/g1783r1964'],
#  ['美食',
#   '广州',
#   '家常菜',
#   '南沙区',
#   'http://www.dianping.com/search/category/4/10/g1783r1963']]

# %%
# %%time
#***************获取所有的商圈信息****************************888
circle_ls = list(map(get_circle,region_ls))
# Out:
# 黄埔区没有子分类！！
# 黄埔区没有子分类！！
# 从化区没有子分类！！
# 南沙区没有子分类！！
# 荔湾区没有子分类！！
# 黄埔区没有子分类！！
# CPU times: user 1min 3s, sys: 1.14 s, total: 1min 4s
# Wall time: 10min 32s

# %%
#解链
circle_ls = list(itertools.chain.from_iterable(circle_ls))

# %%
save_cache(circle_ls,"/media/zhh/东方国信/智润安排/移动互联网需求/爬虫/缓存/广州_circle_ls.pickle")

# %%
circle_ls = read_cache("/media/zhh/东方国信/智润安排/移动互联网需求/爬虫/缓存/广州_circle_ls.pickle")
print(len(circle_ls))
circle_chunk = get_chunk(circle_ls,5)
len(circle_chunk)
# Out:
# 3298
# 660

# %%
# %%time
if __name__=='__main__':
    
    offset = 107
    end = 660
    for index,chunk in enumerate(circle_chunk[offset:end]):
        offset_index = offset + index
        print("正在爬第{0}chunk".format(offset_index))
        pool = multiprocessing.Pool(processes=3) # 创建3个进程
        result = []
        for i in chunk:
            result.append(pool.apply_async(get_stores, (i, )))
        pool.close() # 关闭进程池，表示不能再往进程池中添加进程，需要在join之前调用
        pool.join() # 等待进程池中的所有进程执行完毕

        store_ls = []
        for res in result:
            store_ls.append(res.get())
        
        print("第{0}chunk已经爬完了".format(offset_index))
        store_ls = list(itertools.chain.from_iterable(store_ls))
        save_cache(store_ls,"/media/zhh/东方国信/智润安排/移动互联网需求/爬虫/缓存/广州_store_ls_{0}_chunk.pickle".format(offset_index))
        t1 = random.randint(20,50)
        print("睡{0}秒".format(t1))
        time.sleep(t1)
#     print("***********准备爬商家的详情信息******************")
#     pool = multiprocessing.Pool(processes=3) # 创建3个进程
#     result=[]
#     for i in store_ls:
#         result.append(pool.apply_async(get_info,(i,)))
#     pool.close()
#     pool.join()
    
#     print("信息页已经爬完了！！")
#     info_ls=[]
#     for res in result:
#         info_ls.append(res.get())
#     save_cache(info_ls,"/media/zhh/东方国信/智润安排/移动互联网需求/爬虫/缓存/广州_info_test_ls.pickle")
# Out:
# 正在爬第107chunk
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第2页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第2页
# 正在爬取第2页
# 访问1次
# 访问1次
# 正在爬取第3页
# 访问1次
# 正在爬取第3页
# 正在爬取第3页
# 访问1次
# 访问1次
# 正在爬取第4页
# 访问1次
# 正在爬取第4页
# 正在爬取第4页
# 访问1次
# 访问1次
# 正在爬取第5页
# 访问1次
# 正在爬取第5页
# 正在爬取第5页
# 正在爬取第6页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第6页
# 正在爬取第6页
# 访问1次
# 正在爬取第7页
# 访问1次
# 访问1次
# 正在爬取第7页
# 正在爬取第7页
# 访问1次
# 访问1次
# 正在爬取第8页
# 访问1次
# 正在爬取第8页
# 正在爬取第8页
# 访问1次
# 访问1次
# 正在爬取第9页
# 访问1次
# 正在爬取第9页
# 正在爬取第9页
# 访问1次
# 访问1次
# 正在爬取第10页
# 访问1次
# 正在爬取第10页
# 正在爬取第10页
# 访问1次
# 访问1次
# 正在爬取第11页
# 访问1次
# 正在爬取第11页
# 正在爬取第11页
# 访问1次
# 访问1次
# 正在爬取第12页
# 访问1次
# 正在爬取第12页
# 正在爬取第12页
# 访问1次
# 访问1次
# 正在爬取第13页
# 访问1次
# 正在爬取第13页
# 正在爬取第13页
# 访问1次
# 访问1次
# 正在爬取第14页
# 访问1次
# 正在爬取第14页
# 正在爬取第14页
# 访问1次
# 正在爬取第15页
# 正在爬取第15页
# 访问1次
# 访问1次
# 正在爬取第16页
# 正在爬取第16页
# 访问1次
# 访问1次
# 正在爬取第17页
# 正在爬取第17页
# 访问1次
# 访问1次
# 正在爬取第18页
# 正在爬取第18页
# 访问1次
# 访问1次
# 正在爬取第19页
# 正在爬取第19页
# 访问1次
# 访问1次
# 正在爬取第20页
# 正在爬取第20页
# 访问1次
# 正在爬取第21页
# 访问1次
# 正在爬取第22页
# 访问1次
# 正在爬取第23页
# 访问1次
# 正在爬取第24页
# 访问1次
# 正在爬取第25页
# 访问1次
# 正在爬取第26页
# 访问1次
# 正在爬取第27页
# 访问1次
# 正在爬取第28页
# 访问1次
# 正在爬取第29页
# 第107chunk已经爬完了
# 睡47秒
# 正在爬第108chunk
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第2页
# 正在爬取第2页
# 正在爬取第2页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第3页
# 正在爬取第3页
# 正在爬取第3页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第4页
# 正在爬取第4页
# 正在爬取第4页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第5页
# 正在爬取第5页
# 正在爬取第5页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第6页
# 正在爬取第6页
# 正在爬取第6页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第1页
# 正在爬取第1页
# 访问1次
# 正在爬取第7页
# 访问1次
# 访问1次
# 正在爬取第2页
# 正在爬取第2页
# 访问1次
# 访问1次
# 正在爬取第8页
# 正在爬取第3页
# 访问1次
# 正在爬取第3页
# 访问1次
# 访问1次
# 正在爬取第9页
# 正在爬取第4页
# 访问1次
# 正在爬取第4页
# 访问1次
# 访问1次
# 正在爬取第10页
# 正在爬取第5页
# 正在爬取第5页
# 访问1次
# 访问1次
# 正在爬取第6页
# 正在爬取第6页
# 访问1次
# 访问1次
# 正在爬取第7页
# 正在爬取第7页
# 访问1次
# 访问1次
# 正在爬取第8页
# 正在爬取第8页
# 访问1次
# 访问1次
# 正在爬取第9页
# 正在爬取第9页
# 访问1次
# 访问1次
# 正在爬取第10页
# 正在爬取第10页
# 访问1次
# 访问1次
# 正在爬取第11页
# 正在爬取第11页
# 访问1次
# 访问1次
# 正在爬取第12页
# 正在爬取第12页
# 访问1次
# 访问1次
# 正在爬取第13页
# 正在爬取第13页
# 访问1次
# 访问1次
# 正在爬取第14页
# 正在爬取第14页
# 访问1次
# 访问1次
# 正在爬取第15页
# 正在爬取第15页
# 访问1次
# 访问1次
# 正在爬取第16页
# 正在爬取第16页
# 访问1次
# 访问1次
# 正在爬取第17页
# 正在爬取第17页
# 访问1次
# 访问1次
# 正在爬取第18页
# 正在爬取第18页
# 访问1次
# 访问1次
# 正在爬取第19页
# 访问1次
# 正在爬取第20页
# 正在爬取第19页
# 访问1次
# 访问1次
# 正在爬取第21页
# 访问1次
# 正在爬取第20页
# 访问1次
# 正在爬取第22页
# 访问1次
# 正在爬取第21页
# 访问1次
# 正在爬取第23页
# 访问1次
# 正在爬取第22页
# 访问1次
# 正在爬取第24页
# 正在爬取第23页
# 访问1次
# 正在爬取第24页
# 访问1次
# 正在爬取第25页
# 访问1次
# 正在爬取第26页
# 访问1次
# 正在爬取第27页
# 访问1次
# 正在爬取第28页
# 访问1次
# 正在爬取第29页
# 第108chunk已经爬完了
# 睡23秒
# 正在爬第109chunk
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第2页
# 正在爬取第2页
# 正在爬取第2页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第3页
# 正在爬取第3页
# 正在爬取第3页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第4页
# 正在爬取第4页
# 正在爬取第4页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第5页
# 正在爬取第5页
# 正在爬取第5页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第6页
# 正在爬取第6页
# 正在爬取第6页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第1页
# 正在爬取第7页
# 正在爬取第7页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第2页
# 访问1次
# 正在爬取第8页
# 正在爬取第8页
# 访问1次
# 访问1次
# 正在爬取第3页
# 访问1次
# 正在爬取第9页
# 正在爬取第9页
# 访问1次
# 访问1次
# 正在爬取第4页
# 正在爬取第1页
# 访问1次
# 正在爬取第10页
# 访问1次
# 访问1次
# 正在爬取第5页
# 正在爬取第2页
# 访问1次
# 正在爬取第11页
# 访问1次
# 访问1次
# 正在爬取第6页
# 正在爬取第3页
# 访问1次
# 正在爬取第12页
# 访问1次
# 访问1次
# 正在爬取第7页
# 正在爬取第4页
# 访问1次
# 正在爬取第13页
# 访问1次
# 访问1次
# 正在爬取第8页
# 正在爬取第5页
# 正在爬取第14页
# 访问1次
# 访问1次
# 正在爬取第6页
# 正在爬取第15页
# 访问1次
# 正在爬取第16页
# 访问1次
# 正在爬取第17页
# 访问1次
# 正在爬取第18页
# 访问1次
# 正在爬取第19页
# 访问1次
# 正在爬取第20页
# 访问1次
# 正在爬取第21页
# 访问1次
# 正在爬取第22页
# 访问1次
# 正在爬取第23页
# 访问1次
# 正在爬取第24页
# 访问1次
# 正在爬取第25页
# 访问1次
# 正在爬取第26页
# 访问1次
# 正在爬取第27页
# 第109chunk已经爬完了
# 睡41秒
# 正在爬第110chunk
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第2页
# 正在爬取第2页
# 正在爬取第2页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第1页
# 正在爬取第3页
# 正在爬取第3页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第2页
# 访问1次
# 正在爬取第4页
# 正在爬取第4页
# 访问1次
# 访问1次
# 正在爬取第3页
# 访问1次
# 正在爬取第5页
# 正在爬取第5页
# 访问1次
# 访问1次
# 正在爬取第6页
# 正在爬取第6页
# 正在爬取第4页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第7页
# 访问1次
# 正在爬取第7页
# 正在爬取第5页
# 正在爬取第1页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第6页
# 正在爬取第8页
# 正在爬取第2页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第7页
# 正在爬取第9页
# 正在爬取第3页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第10页
# 正在爬取第8页
# 正在爬取第4页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第9页
# 正在爬取第11页
# 正在爬取第5页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第10页
# 正在爬取第12页
# 访问1次
# 访问1次
# 正在爬取第6页
# 访问1次
# 正在爬取第11页
# 正在爬取第13页
# 访问1次
# 访问1次
# 正在爬取第7页
# 访问1次
# 正在爬取第12页
# 正在爬取第14页
# 访问1次
# 正在爬取第8页
# 正在爬取第15页
# 访问1次
# 正在爬取第16页
# 访问1次
# 正在爬取第17页
# 访问1次
# 正在爬取第18页
# 访问1次
# 正在爬取第19页
# 访问1次
# 正在爬取第20页
# 访问1次
# 正在爬取第21页
# 访问1次
# 正在爬取第22页
# 访问1次
# 正在爬取第23页
# 第110chunk已经爬完了
# 睡43秒
# 正在爬第111chunk
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第2页
# 正在爬取第2页
# 正在爬取第2页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第3页
# 正在爬取第3页
# 正在爬取第3页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第4页
# 正在爬取第4页
# 正在爬取第4页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第1页
# 正在爬取第5页
# 访问1次
# 正在爬取第5页
# 访问1次
# 访问1次
# 正在爬取第1页
# 正在爬取第2页
# 正在爬取第6页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第2页
# 正在爬取第3页
# 正在爬取第7页
# 访问1次
# 访问1次
# 正在爬取第3页
# 正在爬取第4页
# 访问1次
# 访问1次
# 正在爬取第4页
# 正在爬取第5页
# 访问1次
# 正在爬取第6页
# 访问1次
# 正在爬取第7页
# 访问1次
# 正在爬取第8页
# 第111chunk已经爬完了
# 睡47秒
# 正在爬第112chunk
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第2页
# 正在爬取第2页
# 正在爬取第2页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第3页
# 正在爬取第3页
# 正在爬取第3页
# 访问1次
# 访问1次
# 访问1次
# 正在爬取第1页
