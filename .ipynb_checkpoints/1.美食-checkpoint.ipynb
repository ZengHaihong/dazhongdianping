# %%
import os
import requests
import re
from bs4 import BeautifulSoup
import lxml
import os.path
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException,WebDriverException
from selenium.webdriver.common.keys import Keys
import time
import warnings
warnings.filterwarnings("ignore")
import pickle
import pandas as pd
from requests.exceptions import ProxyError,ConnectionError,Timeout,HTTPError,ChunkedEncodingError
import itertools
import multiprocessing
import Ipynb_importer
from IPpool import GetHeaders
from IPpool import Ip_pool
import random
import copy
import os
# import requests_toolbelt.adapters.appengine

# requests_toolbelt.adapters.appengine.monkeypatch()
from dzdp_common import *
# Out:
# importing Jupyter notebook from IPpool.ipynb
# importing Jupyter notebook from dzdp_common.ipynb

# %%
def requests_visit_url_test(url,is_use_ip =True,timeout=5):
        global ip_pool
        global bad_ip
        #headers = {"User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/61.0.3163.100 Chrome/61.0.3163.100 Safari/537.36"}
        headers = {'User-Agent':random.choice(GetHeaders().user_agent_list)}
        print(headers)
        #获取任意一个请求头
        #headers["User-Agent"] = random.choice(GetHeaders().user_agent_list)
        bad_ip = []  #用来装坏的ip
        
        #*********如果不设置ip的话**********************************
        if is_use_ip == False:
            
            res = requests.get(url,headers = headers,timeout=timeout)  #访问url，不设代理ip访问
            html =  res.content.decode('utf-8')
            soup  =  BeautifulSoup(html,'lxml')
            if soup.title.text == '403 Forbidden' or "有道" in soup.title.text:
                print("ip被禁止了！！！！！！！！！！！！！！！！")
                raise ConnectionError
           
        #************如果设置ip的话，则执行这一段*********************
        else:
            is_continue = True   #设置循环标志
            while is_continue:
            #整理成ip地址的格式
                try:
                    #
                    headers = {'User-Agent':random.choice(GetHeaders().user_agent_list)}
                    print(headers)
                    print(len(bad_ip))
                    if len(ip_pool)==len(bad_ip):
                        ip_url = ['http://www.xicidaili.com/nn/']
                        test_url = 'http://www.dianping.com/'
                        ip_pool= Ip_pool().get_ip_pool(test_url,timeout=2)
                        prox_ip = random.choice(ip_pool)
                        bad_ip = []
                        
                    #******随机生成一个ip*******
                    prox_ip = random.choice(ip_pool)
                    http = prox_ip[0]
                    ip = prox_ip[1]
                    proxies={http:ip}
                    print(proxies)
                    
                    #*******用代理ip访问********
                    res = requests.get(url,headers = headers,proxies = proxies,timeout=timeout) #设代理ip访问
                    html =  res.content.decode('utf-8')
                    soup  =  BeautifulSoup(html,'lxml')
                    
                    
                    #********如果返回网页被禁止的情况，触发异常,否则返回正常**********
                    if  soup.title.text == '403 Forbidden' or "有道" in soup.title.text:
                        print("ip被禁止了!!!!!!!!!!!!!!!!!!!!")
                        raise ConnectionError
                    else:
                        is_continue = False

                except HTTPError as e:
                    bad_ip.append(prox_ip)
                    print("断网")
                    prox_ip = random.choice(ip_pool)
                    time.sleep(3)


                except Timeout as e:
                    bad_ip.append(prox_ip)
                    print("超时")
                    prox_ip = random.choice(ip_pool)
                    time.sleep(3)


                except ConnectionError as e:
                    bad_ip.append(prox_ip)
                    print("访问被拒")
                    prox_ip = random.choice(ip_pool)
                    time.sleep(3)
                    
                except AttributeError as e:
                    bad_ip.append(prox_ip)
                    print("----------",soup)
                    prox_ip = random.choice(ip_pool)
                    time.sleep(3)
            
        time.sleep(2)
        return soup

# %%
#**************将装机地址变成一组一组*****************
def get_chunk(adr_ls,n):
    new_adr_ls = copy.deepcopy(adr_ls)
    adr_chunk = [new_adr_ls[i:i + n] for i in range(0, len(new_adr_ls), n)]
    return adr_chunk

# %%
#设置谷歌浏览器的参数
def set_chrome_param():
    #PROXY = '175.155.24.61:808'
    options = webdriver.ChromeOptions()
    chrome_path = '/home/zhh/下载/chromedriver'  
    #options.add_argument('--proxy-server={0}'.format(PROXY))
    # 设置成中文
    options.add_argument('lang=zh_CN.UTF-8')
    # 添加头部
    #1允许所有图片；2阻止所有图片；3阻止第三方服务器图片
    prefs = {'profile.default_content_setting_values': { 'images':2}}
    options.add_experimental_option('prefs', prefs)
    options.add_argument('user-agent="Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.103 Safari/537.36"')
    chrome = webdriver.Chrome(chrome_path,chrome_options=options)
    return chrome

# %%
#requests请求网页，返回一个BeautifulSoup对象
def requests_visit_url(url,prox_ip=None):
    
    #*******设置请求头*************
    headers = {"Accept":"application/json, text/javascript, */*; q=0.01",
                    "Accept-Encoding":"gzip, deflate",
                    "Accept-Language":"zh-CN,zh;q=0.8,en;q=0.6",
                    "Connection":"keep-alive",
                    "Cookie":"_hc.v=f72dbe69-bcfc-a9d4-1f7f-d8daeca1ad7f.1505634421; __utma=1.1801105885.1505634423.1505634423.1505636820.2; __utmz=1.1505634423.1.1.utmcsr=google.com.hk|utmccn=(referral)|utmcmd=referral|utmcct=/; _lxsdk_cuid=15e956d9d5ec8-0a28c942cf39be-2a044871-100200-15e956d9d5fc8; _lxsdk=15e956d9d5ec8-0a28c942cf39be-2a044871-100200-15e956d9d5fc8; _lx_utm=utm_source%3DBaidu%26utm_medium%3Dorganic; __mta=222713764.1505836341840.1507819135553.1507819166825.4; JSESSIONID=D2D3D245867334198A59E676F146C5A8; aburl=1; cy=4; cye=guangzhou; s_ViewType=10; _lxsdk_s=15f2012787a-db4-26a-c8%7C%7C47",
                    "Host":"www.dianping.com",
                    "Referer":url,
                    #"User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/61.0.3163.100 Chrome/61.0.3163.100 Safari/537.36",
                    "X-Requested-With":"XMLHttpRequest"}
    headers["User-Agent"] = random.choice(GetHeaders().user_agent_list)
    #headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.103 Safari/537.36"}
    
    #********是否循环*************
    is_continue = True
    num = 0
    while is_continue:
        num +=1
        print("访问{0}次".format(num))
        try:
            #***********不设代理访问*************
            if prox_ip is None:
                res = requests.get(url,headers = headers)  #访问url，不设代理ip访问
            else:
                
            #*********设置代理ip访问*************
                http = prox_ip[0]
                ip = http+"://"+prox_ip[1]
                proxies={http:ip}
                print(proxies)
                res = requests.get(url,headers = headers,proxies = proxies) #设代理ip访问
            html =  res.content.decode('utf-8')
            soup  =  BeautifulSoup(html,'lxml')
            is_continue = False 
            
        except HTTPError as e:
            print("断网")
            time.sleep(2)
            
        except Timeout as e:
            print("请求超时")
            time.sleep(2)
            
        except ConnectionError as e:
            print("访问被拒")
            is_continue = True
            time.sleep(2)
    return soup

# %%
#缓存结果
def save_cache(result,filename):
    with open(filename,'wb') as f1:
        pickle.dump(result,f1)

# %%
#加载缓存
def read_cache(filename):
    with open(filename,'rb')as f1:
        result = pickle.load(f1)
    return result

# %%
# 切换路径
def get_spc_path(father_path,child_path):
    os.chdir(father_path)
    if os.path.exists(child_path):
        os.chdir(child_path)
    else:
        os.mkdir(child_path)
        os.chdir(child_path)
    print("done!!")

# %% [markdown]
# ## 1.二级分类层

# %%
# %%time
#获取所有的二级分类url
def classify(city_url,city,big_class):
    soup = requests_visit_url(city_url)
    clf_ls = []
    for i in soup.select("#classfy a"):
        clf_url = i["href"] #分类网址
        clf_tl = i.text.strip() # 分类标题
        clf_ls.append([big_class,city,clf_tl,clf_url])
    return clf_ls
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 7.15 µs

# %%
# %%time
# clf_ls = classify("http://www.dianping.com/search/category/7/10",'深圳',"美食")

# %% [markdown]
# ## 2.区县层

# %%
def get_region(class_ls=None,prox_ip=None):
    print('正在爬取{0}'.format(class_ls[-2]))
    url = class_ls[-1]  #url
    soup = requests_visit_url(url,prox_ip) #访问
    region_ls = [] #地区的列表
    for i in soup.select("#region-nav a"):
        if i.text.strip() != "不限":
            region_url = i["href"] 
            region_tl = i.text.strip()
            region = class_ls[:-1]
            region.extend([region_tl,region_url])
            region_ls.append(region)
    return region_ls

# %%
# ip = Ip_pool(['http://www.xicidaili.com/nn/'])
# ip_pool = ip.get_ip_pool(test_url='http://www.dianping.com/search/category/7/10/g104',timeout =1)

# %%
# %%time
# prox_ip = random.choice(ip_pool)
# region_ls = []
# for i in clf_ls:
#     print(i)
#     sub_region = get_region(i,prox_ip)
#     region_ls.append(sub_region)

# %%
# region_ls

# %% [markdown]
# ## 3.商圈层

# %%
def get_circle(region_ls=None):
    url = region_ls[-1]   #url网址
    soup = requests_visit_url(url) #访问BeautifulSoup
    circle_ls =[]             
    for i in soup.select("#region-nav-sub a"):  #商圈信息
        if i.span.text.strip()!="不限":   #剔除掉不限的url
            circle_url = i["href"]       #商圈url
            circle_tit = i.span.text.strip()  #商圈名
            circle = region_ls[:-1] 
            circle.extend([circle_tit,circle_url]) 
            circle_ls.append(circle)
            
    #如果没有商圈的话，就拿原来的url当作是商圈的url
    if circle_ls==[]:
        print(region_ls[-2]+"没有子分类！！")
        region_ls.insert(4,"没有商圈")
        circle_ls.append(region_ls)

    return circle_ls

# %%
# %%time
# circle_ls = get_circle(['美食',
#   '广州',
#   '茶餐厅',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g207r22'])

# %% [markdown]
# ## 4.商家信息层

# %%
#获取每个商家的链接、店名
def get_stores(circle_ls = None):
    store_ls=[] #存储的列表
    url = circle_ls[-1]  #url
    soup = requests_visit_url_test(url,is_use_ip=True,timeout=3)  #访问当前主页
    is_continue = True
    page = 0
    while is_continue:
        page += 1
        print("正在爬取第{0}页".format(page))
        
        #解析数据
        if soup.select(".content") ==[]:
            print("此页没有任何信息！！")
            store_ls = []
            is_continue = False 
            
        else:
            for i in soup.select(".content"):  
                for j in i.select(".pic"):
                    store_name = j.img["alt"]   #店名
                    link = j.a["href"]     #详情层
                    store = circle_ls[:5]  #只取前5位
                    store.extend([url,store_name,link]) 
                    store_ls.append(store)


            #获取下一页的数据

            next_tag = soup.find_all("a",text = re.compile("下一页"))  #获取字符属性为下一页的url
            if next_tag != []:                                         #保证含有字符属性
                url = next_tag[0]["href"]                              #获取下一页的url
                soup = requests_visit_url_test(url,is_use_ip=True,timeout=2)   #更新BeautifulSoup对象
            else:
                url = ''
                is_continue  = False                                  #如果没有下一页，就停止更新
    
    return store_ls

# %%
# %%time
# store_ls = get_stores(['美食',
#   '广州',
#   '茶餐厅',
#   '天河区',
#   '天河城/体育中心',
#   'http://www.dianping.com/search/category/4/10/g207r1519'])

# %% [markdown]
# ## 5.详情层

# %%
#获取详情层的数据，如星级用户、浏览人数、均价
def get_info(store_ls=None):
    
    #首先先保证导入的数据不为空
    if store_ls !=[]:
        url = store_ls[-1] #详情信息表
        soup = requests_visit_url_test(url,is_use_ip =True,timeout=2)
        try:
            start = soup.select(".mid-rank-stars")[0]["title"]       #星级用户
        except Exception as e:
            print("start",e)
            start = ''

        try:
            review_count = soup.select("#reviewCount")[0].text  #浏览人数
        except Exception as e:
            review_count = ''
            print("review_coun",e)

        try:
            avgprice = soup.select("#avgPriceTitle")[0].text   #均价
        except Exception as e:
            avgprice = ''
            print("avgprice",e)

        #评分系统
        try:
            score= []
            for j in soup.select("#comment_score .item"):
                score.append(j.text)
            score = "|".join(score)

        except Exception as e:
            score = ""
            print("score",e)

        try:   
            address = soup.select(".address .item")[0].text.strip() #地址
        except Exception as e:
            address = ''
            print("address出错了",e)

        #电话号码
        try:
            tel =[]
            for i in soup.select(".tel .item"):
                tel.append(i.text)
            tel = "|".join(tel)

        except:
            tel=""
            print("tel出错了",e)

        #路径
        try:
            path = []
            for i in soup.select(".breadcrumb a"):
                path.append(i.text.strip())
            path ='>'.join(path)
        except Exception as e:
            print("path出错了",e)
            path =''
            
        #五星评论人数
        try:
            
            five_starts = soup.find_all(id=re.compile("reviewCountStar\d"))
            if five_starts ==[]:
                five =''
                four =''
                three =''
                two =''
                one =''
            else:
                five,four,three,two,one = list(map(lambda x:x.text.strip(),five_starts))
        except Exception as e:
            print("五星评论人数出错","---->",e)
            five =''
            four =''
            three =''
            two =''
            one =''

        info = store_ls[:]
        info.extend([start,review_count,avgprice,score,address,tel,five,four,three,two,one,path])
        time.sleep(1)
    return info

# %%
# get_info(['美食',
#   '广州',
#   '茶餐厅',
#   '天河区',
#   '天河城/体育中心',
#   'http://www.dianping.com/search/category/4/10/g207r1519p2',
#   '粤港烧卤鸭饭(天河店)',
#   'http://www.dianping.com/shop/94311152'])

# %% [markdown]
# ## 6 主程序

# %%
# %%time

clf_ls = classify("http://www.dianping.com/search/category/7/10/r1556",'深圳',"美食")
print("所有二级分类已经获取完毕")

region_ls = list(map(get_region,clf_ls))
print("获取所有的区域清单")
# Out:
# 访问1次
# 所有二级分类已经获取完毕
# 正在爬取面包甜点
# 访问1次
# 正在爬取小吃快餐
# 访问1次
# 正在爬取粤菜
# 访问1次
# 正在爬取自助餐
# 访问1次
# 正在爬取咖啡厅
# 访问1次
# 正在爬取日本料理
# 访问1次
# 正在爬取火锅
# 访问1次
# 正在爬取西餐
# 访问1次
# 正在爬取小龙虾
# 访问1次
# 正在爬取海鲜
# 访问1次
# 正在爬取烧烤
# 访问1次
# 正在爬取韩国料理
# 访问1次
# 正在爬取川菜
# 访问1次
# 正在爬取东南亚菜
# 访问1次
# 正在爬取湘菜
# 访问1次
# 正在爬取茶餐厅
# 访问1次
# 正在爬取素菜
# 访问1次
# 正在爬取江浙菜
# 访问1次
# 正在爬取东北菜
# 访问1次
# 正在爬取创意菜
# 访问1次
# 正在爬取新疆菜
# 访问1次
# 正在爬取西北菜
# 访问1次
# 正在爬取粥粉面
# 访问1次
# 正在爬取私房菜
# 访问1次
# 正在爬取台湾菜
# 访问1次
# 正在爬取农家菜
# 访问1次
# 正在爬取其他
# 访问1次
# 正在爬取家常菜
# 访问1次
# 正在爬取下午茶
# 访问1次
# 获取所有的区域清单
# CPU times: user 6.63 s, sys: 112 ms, total: 6.74 s
# Wall time: 36.8 s

# %%
#解链
region_ls = list(itertools.chain.from_iterable(region_ls))
region_ls
# Out:
# [['美食',
#   '深圳',
#   '面包甜点',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g117r29'],
#  ['美食',
#   '深圳',
#   '面包甜点',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g117r31'],
#  ['美食',
#   '深圳',
#   '面包甜点',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g117r30'],
#  ['美食',
#   '深圳',
#   '面包甜点',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g117r33'],
#  ['美食',
#   '深圳',
#   '面包甜点',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g117r34'],
#  ['美食',
#   '深圳',
#   '面包甜点',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g117r12033'],
#  ['美食',
#   '深圳',
#   '面包甜点',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g117r32'],
#  ['美食',
#   '深圳',
#   '面包甜点',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g117r12036'],
#  ['美食',
#   '深圳',
#   '面包甜点',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g117r12034'],
#  ['美食',
#   '深圳',
#   '面包甜点',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g117r12035'],
#  ['美食',
#   '深圳',
#   '小吃快餐',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g112r29'],
#  ['美食',
#   '深圳',
#   '小吃快餐',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g112r31'],
#  ['美食',
#   '深圳',
#   '小吃快餐',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g112r30'],
#  ['美食',
#   '深圳',
#   '小吃快餐',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g112r33'],
#  ['美食',
#   '深圳',
#   '小吃快餐',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g112r34'],
#  ['美食',
#   '深圳',
#   '小吃快餐',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g112r12033'],
#  ['美食',
#   '深圳',
#   '小吃快餐',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g112r32'],
#  ['美食',
#   '深圳',
#   '小吃快餐',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g112r12036'],
#  ['美食',
#   '深圳',
#   '小吃快餐',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g112r12034'],
#  ['美食',
#   '深圳',
#   '小吃快餐',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g112r12035'],
#  ['美食',
#   '深圳',
#   '粤菜',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g103r29'],
#  ['美食',
#   '深圳',
#   '粤菜',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g103r31'],
#  ['美食',
#   '深圳',
#   '粤菜',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g103r30'],
#  ['美食',
#   '深圳',
#   '粤菜',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g103r33'],
#  ['美食',
#   '深圳',
#   '粤菜',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g103r34'],
#  ['美食',
#   '深圳',
#   '粤菜',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g103r12033'],
#  ['美食',
#   '深圳',
#   '粤菜',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g103r32'],
#  ['美食',
#   '深圳',
#   '粤菜',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g103r12036'],
#  ['美食',
#   '深圳',
#   '粤菜',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g103r12034'],
#  ['美食',
#   '深圳',
#   '粤菜',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g103r12035'],
#  ['美食',
#   '深圳',
#   '自助餐',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g111r29'],
#  ['美食',
#   '深圳',
#   '自助餐',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g111r31'],
#  ['美食',
#   '深圳',
#   '自助餐',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g111r30'],
#  ['美食',
#   '深圳',
#   '自助餐',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g111r33'],
#  ['美食',
#   '深圳',
#   '自助餐',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g111r34'],
#  ['美食',
#   '深圳',
#   '自助餐',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g111r12033'],
#  ['美食',
#   '深圳',
#   '自助餐',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g111r32'],
#  ['美食',
#   '深圳',
#   '自助餐',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g111r12036'],
#  ['美食',
#   '深圳',
#   '自助餐',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g111r12034'],
#  ['美食',
#   '深圳',
#   '自助餐',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g111r12035'],
#  ['美食',
#   '深圳',
#   '咖啡厅',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g132r29'],
#  ['美食',
#   '深圳',
#   '咖啡厅',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g132r31'],
#  ['美食',
#   '深圳',
#   '咖啡厅',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g132r30'],
#  ['美食',
#   '深圳',
#   '咖啡厅',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g132r33'],
#  ['美食',
#   '深圳',
#   '咖啡厅',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g132r34'],
#  ['美食',
#   '深圳',
#   '咖啡厅',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g132r12033'],
#  ['美食',
#   '深圳',
#   '咖啡厅',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g132r32'],
#  ['美食',
#   '深圳',
#   '咖啡厅',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g132r12036'],
#  ['美食',
#   '深圳',
#   '咖啡厅',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g132r12034'],
#  ['美食',
#   '深圳',
#   '咖啡厅',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g132r12035'],
#  ['美食',
#   '深圳',
#   '日本料理',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g113r29'],
#  ['美食',
#   '深圳',
#   '日本料理',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g113r31'],
#  ['美食',
#   '深圳',
#   '日本料理',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g113r30'],
#  ['美食',
#   '深圳',
#   '日本料理',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g113r33'],
#  ['美食',
#   '深圳',
#   '日本料理',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g113r34'],
#  ['美食',
#   '深圳',
#   '日本料理',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g113r12033'],
#  ['美食',
#   '深圳',
#   '日本料理',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g113r32'],
#  ['美食',
#   '深圳',
#   '日本料理',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g113r12036'],
#  ['美食',
#   '深圳',
#   '日本料理',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g113r12034'],
#  ['美食',
#   '深圳',
#   '日本料理',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g113r12035'],
#  ['美食',
#   '深圳',
#   '火锅',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g110r29'],
#  ['美食',
#   '深圳',
#   '火锅',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g110r31'],
#  ['美食',
#   '深圳',
#   '火锅',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g110r30'],
#  ['美食',
#   '深圳',
#   '火锅',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g110r33'],
#  ['美食',
#   '深圳',
#   '火锅',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g110r34'],
#  ['美食',
#   '深圳',
#   '火锅',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g110r12033'],
#  ['美食',
#   '深圳',
#   '火锅',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g110r32'],
#  ['美食',
#   '深圳',
#   '火锅',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g110r12036'],
#  ['美食',
#   '深圳',
#   '火锅',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g110r12034'],
#  ['美食',
#   '深圳',
#   '火锅',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g110r12035'],
#  ['美食',
#   '深圳',
#   '西餐',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g116r29'],
#  ['美食',
#   '深圳',
#   '西餐',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g116r31'],
#  ['美食',
#   '深圳',
#   '西餐',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g116r30'],
#  ['美食',
#   '深圳',
#   '西餐',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g116r33'],
#  ['美食',
#   '深圳',
#   '西餐',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g116r34'],
#  ['美食',
#   '深圳',
#   '西餐',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g116r12033'],
#  ['美食',
#   '深圳',
#   '西餐',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g116r32'],
#  ['美食',
#   '深圳',
#   '西餐',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g116r12036'],
#  ['美食',
#   '深圳',
#   '西餐',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g116r12034'],
#  ['美食',
#   '深圳',
#   '西餐',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g116r12035'],
#  ['美食',
#   '深圳',
#   '小龙虾',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g219r29'],
#  ['美食',
#   '深圳',
#   '小龙虾',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g219r31'],
#  ['美食',
#   '深圳',
#   '小龙虾',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g219r30'],
#  ['美食',
#   '深圳',
#   '小龙虾',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g219r33'],
#  ['美食',
#   '深圳',
#   '小龙虾',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g219r34'],
#  ['美食',
#   '深圳',
#   '小龙虾',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g219r12033'],
#  ['美食',
#   '深圳',
#   '小龙虾',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g219r32'],
#  ['美食',
#   '深圳',
#   '小龙虾',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g219r12036'],
#  ['美食',
#   '深圳',
#   '小龙虾',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g219r12034'],
#  ['美食',
#   '深圳',
#   '小龙虾',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g219r12035'],
#  ['美食',
#   '深圳',
#   '海鲜',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g251r29'],
#  ['美食',
#   '深圳',
#   '海鲜',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g251r31'],
#  ['美食',
#   '深圳',
#   '海鲜',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g251r30'],
#  ['美食',
#   '深圳',
#   '海鲜',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g251r33'],
#  ['美食',
#   '深圳',
#   '海鲜',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g251r34'],
#  ['美食',
#   '深圳',
#   '海鲜',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g251r12033'],
#  ['美食',
#   '深圳',
#   '海鲜',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g251r32'],
#  ['美食',
#   '深圳',
#   '海鲜',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g251r12036'],
#  ['美食',
#   '深圳',
#   '海鲜',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g251r12034'],
#  ['美食',
#   '深圳',
#   '海鲜',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g251r12035'],
#  ['美食',
#   '深圳',
#   '烧烤',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g508r29'],
#  ['美食',
#   '深圳',
#   '烧烤',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g508r31'],
#  ['美食',
#   '深圳',
#   '烧烤',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g508r30'],
#  ['美食',
#   '深圳',
#   '烧烤',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g508r33'],
#  ['美食',
#   '深圳',
#   '烧烤',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g508r34'],
#  ['美食',
#   '深圳',
#   '烧烤',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g508r12033'],
#  ['美食',
#   '深圳',
#   '烧烤',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g508r32'],
#  ['美食',
#   '深圳',
#   '烧烤',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g508r12036'],
#  ['美食',
#   '深圳',
#   '烧烤',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g508r12034'],
#  ['美食',
#   '深圳',
#   '烧烤',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g508r12035'],
#  ['美食',
#   '深圳',
#   '韩国料理',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g114r29'],
#  ['美食',
#   '深圳',
#   '韩国料理',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g114r31'],
#  ['美食',
#   '深圳',
#   '韩国料理',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g114r30'],
#  ['美食',
#   '深圳',
#   '韩国料理',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g114r33'],
#  ['美食',
#   '深圳',
#   '韩国料理',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g114r34'],
#  ['美食',
#   '深圳',
#   '韩国料理',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g114r12033'],
#  ['美食',
#   '深圳',
#   '韩国料理',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g114r32'],
#  ['美食',
#   '深圳',
#   '韩国料理',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g114r12036'],
#  ['美食',
#   '深圳',
#   '韩国料理',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g114r12034'],
#  ['美食',
#   '深圳',
#   '韩国料理',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g114r12035'],
#  ['美食',
#   '深圳',
#   '川菜',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g102r29'],
#  ['美食',
#   '深圳',
#   '川菜',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g102r31'],
#  ['美食',
#   '深圳',
#   '川菜',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g102r30'],
#  ['美食',
#   '深圳',
#   '川菜',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g102r33'],
#  ['美食',
#   '深圳',
#   '川菜',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g102r34'],
#  ['美食',
#   '深圳',
#   '川菜',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g102r12033'],
#  ['美食',
#   '深圳',
#   '川菜',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g102r32'],
#  ['美食',
#   '深圳',
#   '川菜',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g102r12036'],
#  ['美食',
#   '深圳',
#   '川菜',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g102r12034'],
#  ['美食',
#   '深圳',
#   '川菜',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g102r12035'],
#  ['美食',
#   '深圳',
#   '东南亚菜',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g115r29'],
#  ['美食',
#   '深圳',
#   '东南亚菜',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g115r31'],
#  ['美食',
#   '深圳',
#   '东南亚菜',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g115r30'],
#  ['美食',
#   '深圳',
#   '东南亚菜',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g115r33'],
#  ['美食',
#   '深圳',
#   '东南亚菜',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g115r34'],
#  ['美食',
#   '深圳',
#   '东南亚菜',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g115r12033'],
#  ['美食',
#   '深圳',
#   '东南亚菜',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g115r32'],
#  ['美食',
#   '深圳',
#   '东南亚菜',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g115r12036'],
#  ['美食',
#   '深圳',
#   '东南亚菜',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g115r12034'],
#  ['美食',
#   '深圳',
#   '湘菜',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g104r29'],
#  ['美食',
#   '深圳',
#   '湘菜',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g104r31'],
#  ['美食',
#   '深圳',
#   '湘菜',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g104r30'],
#  ['美食',
#   '深圳',
#   '湘菜',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g104r33'],
#  ['美食',
#   '深圳',
#   '湘菜',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g104r34'],
#  ['美食',
#   '深圳',
#   '湘菜',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g104r12033'],
#  ['美食',
#   '深圳',
#   '湘菜',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g104r32'],
#  ['美食',
#   '深圳',
#   '湘菜',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g104r12036'],
#  ['美食',
#   '深圳',
#   '湘菜',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g104r12034'],
#  ['美食',
#   '深圳',
#   '湘菜',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g104r12035'],
#  ['美食',
#   '深圳',
#   '茶餐厅',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g207r29'],
#  ['美食',
#   '深圳',
#   '茶餐厅',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g207r31'],
#  ['美食',
#   '深圳',
#   '茶餐厅',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g207r30'],
#  ['美食',
#   '深圳',
#   '茶餐厅',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g207r33'],
#  ['美食',
#   '深圳',
#   '茶餐厅',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g207r34'],
#  ['美食',
#   '深圳',
#   '茶餐厅',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g207r12033'],
#  ['美食',
#   '深圳',
#   '茶餐厅',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g207r32'],
#  ['美食',
#   '深圳',
#   '茶餐厅',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g207r12036'],
#  ['美食',
#   '深圳',
#   '茶餐厅',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g207r12034'],
#  ['美食',
#   '深圳',
#   '茶餐厅',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g207r12035'],
#  ['美食',
#   '深圳',
#   '素菜',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g109r29'],
#  ['美食',
#   '深圳',
#   '素菜',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g109r31'],
#  ['美食',
#   '深圳',
#   '素菜',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g109r30'],
#  ['美食',
#   '深圳',
#   '素菜',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g109r33'],
#  ['美食',
#   '深圳',
#   '素菜',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g109r34'],
#  ['美食',
#   '深圳',
#   '素菜',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g109r12033'],
#  ['美食',
#   '深圳',
#   '素菜',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g109r32'],
#  ['美食',
#   '深圳',
#   '素菜',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g109r12036'],
#  ['美食',
#   '深圳',
#   '素菜',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g109r12035'],
#  ['美食',
#   '深圳',
#   '素菜',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g109r12034'],
#  ['美食',
#   '深圳',
#   '江浙菜',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g101r29'],
#  ['美食',
#   '深圳',
#   '江浙菜',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g101r31'],
#  ['美食',
#   '深圳',
#   '江浙菜',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g101r30'],
#  ['美食',
#   '深圳',
#   '江浙菜',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g101r33'],
#  ['美食',
#   '深圳',
#   '江浙菜',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g101r34'],
#  ['美食',
#   '深圳',
#   '江浙菜',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g101r12033'],
#  ['美食',
#   '深圳',
#   '江浙菜',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g101r32'],
#  ['美食',
#   '深圳',
#   '江浙菜',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g101r12036'],
#  ['美食',
#   '深圳',
#   '江浙菜',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g101r12034'],
#  ['美食',
#   '深圳',
#   '江浙菜',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g101r12035'],
#  ['美食',
#   '深圳',
#   '东北菜',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g106r29'],
#  ['美食',
#   '深圳',
#   '东北菜',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g106r31'],
#  ['美食',
#   '深圳',
#   '东北菜',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g106r30'],
#  ['美食',
#   '深圳',
#   '东北菜',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g106r33'],
#  ['美食',
#   '深圳',
#   '东北菜',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g106r34'],
#  ['美食',
#   '深圳',
#   '东北菜',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g106r12033'],
#  ['美食',
#   '深圳',
#   '东北菜',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g106r32'],
#  ['美食',
#   '深圳',
#   '东北菜',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g106r12036'],
#  ['美食',
#   '深圳',
#   '东北菜',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g106r12034'],
#  ['美食',
#   '深圳',
#   '东北菜',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g106r12035'],
#  ['美食',
#   '深圳',
#   '创意菜',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g250r29'],
#  ['美食',
#   '深圳',
#   '创意菜',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g250r31'],
#  ['美食',
#   '深圳',
#   '创意菜',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g250r30'],
#  ['美食',
#   '深圳',
#   '创意菜',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g250r33'],
#  ['美食',
#   '深圳',
#   '创意菜',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g250r34'],
#  ['美食',
#   '深圳',
#   '创意菜',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g250r12033'],
#  ['美食',
#   '深圳',
#   '创意菜',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g250r32'],
#  ['美食',
#   '深圳',
#   '创意菜',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g250r12036'],
#  ['美食',
#   '深圳',
#   '创意菜',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g250r12034'],
#  ['美食',
#   '深圳',
#   '创意菜',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g250r12035'],
#  ['美食',
#   '深圳',
#   '新疆菜',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g3243r29'],
#  ['美食',
#   '深圳',
#   '新疆菜',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g3243r31'],
#  ['美食',
#   '深圳',
#   '新疆菜',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g3243r30'],
#  ['美食',
#   '深圳',
#   '新疆菜',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g3243r33'],
#  ['美食',
#   '深圳',
#   '新疆菜',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g3243r34'],
#  ['美食',
#   '深圳',
#   '新疆菜',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g3243r12033'],
#  ['美食',
#   '深圳',
#   '新疆菜',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g3243r32'],
#  ['美食',
#   '深圳',
#   '新疆菜',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g3243r12034'],
#  ['美食',
#   '深圳',
#   '西北菜',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g26481r29'],
#  ['美食',
#   '深圳',
#   '西北菜',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g26481r31'],
#  ['美食',
#   '深圳',
#   '西北菜',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g26481r30'],
#  ['美食',
#   '深圳',
#   '西北菜',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g26481r33'],
#  ['美食',
#   '深圳',
#   '西北菜',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g26481r34'],
#  ['美食',
#   '深圳',
#   '西北菜',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g26481r12033'],
#  ['美食',
#   '深圳',
#   '西北菜',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g26481r32'],
#  ['美食',
#   '深圳',
#   '西北菜',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g26481r12036'],
#  ['美食',
#   '深圳',
#   '西北菜',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g26481r12034'],
#  ['美食',
#   '深圳',
#   '西北菜',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g26481r12035'],
#  ['美食',
#   '深圳',
#   '粥粉面',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g1959r29'],
#  ['美食',
#   '深圳',
#   '粥粉面',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g1959r31'],
#  ['美食',
#   '深圳',
#   '粥粉面',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g1959r30'],
#  ['美食',
#   '深圳',
#   '粥粉面',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g1959r33'],
#  ['美食',
#   '深圳',
#   '粥粉面',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g1959r34'],
#  ['美食',
#   '深圳',
#   '粥粉面',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g1959r12033'],
#  ['美食',
#   '深圳',
#   '粥粉面',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g1959r32'],
#  ['美食',
#   '深圳',
#   '粥粉面',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g1959r12036'],
#  ['美食',
#   '深圳',
#   '粥粉面',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g1959r12034'],
#  ['美食',
#   '深圳',
#   '粥粉面',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g1959r12035'],
#  ['美食',
#   '深圳',
#   '私房菜',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g1338r29'],
#  ['美食',
#   '深圳',
#   '私房菜',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g1338r31'],
#  ['美食',
#   '深圳',
#   '私房菜',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g1338r30'],
#  ['美食',
#   '深圳',
#   '私房菜',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g1338r33'],
#  ['美食',
#   '深圳',
#   '私房菜',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g1338r34'],
#  ['美食',
#   '深圳',
#   '私房菜',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g1338r12033'],
#  ['美食',
#   '深圳',
#   '私房菜',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g1338r32'],
#  ['美食',
#   '深圳',
#   '私房菜',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g1338r12036'],
#  ['美食',
#   '深圳',
#   '私房菜',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g1338r12034'],
#  ['美食',
#   '深圳',
#   '私房菜',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g1338r12035'],
#  ['美食',
#   '深圳',
#   '台湾菜',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g107r29'],
#  ['美食',
#   '深圳',
#   '台湾菜',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g107r31'],
#  ['美食',
#   '深圳',
#   '台湾菜',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g107r30'],
#  ['美食',
#   '深圳',
#   '台湾菜',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g107r33'],
#  ['美食',
#   '深圳',
#   '台湾菜',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g107r34'],
#  ['美食',
#   '深圳',
#   '台湾菜',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g107r12033'],
#  ['美食',
#   '深圳',
#   '台湾菜',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g107r32'],
#  ['美食',
#   '深圳',
#   '台湾菜',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g107r12036'],
#  ['美食',
#   '深圳',
#   '台湾菜',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g107r12034'],
#  ['美食',
#   '深圳',
#   '台湾菜',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g107r12035'],
#  ['美食',
#   '深圳',
#   '农家菜',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g25474r29'],
#  ['美食',
#   '深圳',
#   '农家菜',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g25474r31'],
#  ['美食',
#   '深圳',
#   '农家菜',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g25474r30'],
#  ['美食',
#   '深圳',
#   '农家菜',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g25474r33'],
#  ['美食',
#   '深圳',
#   '农家菜',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g25474r34'],
#  ['美食',
#   '深圳',
#   '农家菜',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g25474r12033'],
#  ['美食',
#   '深圳',
#   '农家菜',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g25474r32'],
#  ['美食',
#   '深圳',
#   '农家菜',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g25474r12036'],
#  ['美食',
#   '深圳',
#   '农家菜',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g25474r12034'],
#  ['美食',
#   '深圳',
#   '农家菜',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g25474r12035'],
#  ['美食',
#   '深圳',
#   '其他',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g118r29'],
#  ['美食',
#   '深圳',
#   '其他',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g118r31'],
#  ['美食',
#   '深圳',
#   '其他',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g118r30'],
#  ['美食',
#   '深圳',
#   '其他',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g118r33'],
#  ['美食',
#   '深圳',
#   '其他',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g118r34'],
#  ['美食',
#   '深圳',
#   '其他',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g118r12033'],
#  ['美食',
#   '深圳',
#   '其他',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g118r32'],
#  ['美食',
#   '深圳',
#   '其他',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g118r12036'],
#  ['美食',
#   '深圳',
#   '其他',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g118r12034'],
#  ['美食',
#   '深圳',
#   '其他',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g118r12035'],
#  ['美食',
#   '深圳',
#   '家常菜',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g1783r29'],
#  ['美食',
#   '深圳',
#   '家常菜',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g1783r31'],
#  ['美食',
#   '深圳',
#   '家常菜',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g1783r30'],
#  ['美食',
#   '深圳',
#   '家常菜',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g1783r33'],
#  ['美食',
#   '深圳',
#   '家常菜',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g1783r34'],
#  ['美食',
#   '深圳',
#   '家常菜',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g1783r12033'],
#  ['美食',
#   '深圳',
#   '家常菜',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g1783r32'],
#  ['美食',
#   '深圳',
#   '家常菜',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g1783r12036'],
#  ['美食',
#   '深圳',
#   '家常菜',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g1783r12034'],
#  ['美食',
#   '深圳',
#   '家常菜',
#   '坪山新区',
#   'http://www.dianping.com/search/category/7/10/g1783r12035'],
#  ['美食',
#   '深圳',
#   '下午茶',
#   '福田区',
#   'http://www.dianping.com/search/category/7/10/g34014r29'],
#  ['美食',
#   '深圳',
#   '下午茶',
#   '南山区',
#   'http://www.dianping.com/search/category/7/10/g34014r31'],
#  ['美食',
#   '深圳',
#   '下午茶',
#   '罗湖区',
#   'http://www.dianping.com/search/category/7/10/g34014r30'],
#  ['美食',
#   '深圳',
#   '下午茶',
#   '宝安区',
#   'http://www.dianping.com/search/category/7/10/g34014r33'],
#  ['美食',
#   '深圳',
#   '下午茶',
#   '龙岗区',
#   'http://www.dianping.com/search/category/7/10/g34014r34'],
#  ['美食',
#   '深圳',
#   '下午茶',
#   '龙华新区',
#   'http://www.dianping.com/search/category/7/10/g34014r12033'],
#  ['美食',
#   '深圳',
#   '下午茶',
#   '盐田区',
#   'http://www.dianping.com/search/category/7/10/g34014r32'],
#  ['美食',
#   '深圳',
#   '下午茶',
#   '大鹏新区',
#   'http://www.dianping.com/search/category/7/10/g34014r12036'],
#  ['美食',
#   '深圳',
#   '下午茶',
#   '光明新区',
#   'http://www.dianping.com/search/category/7/10/g34014r12034']]

# %%
# %%time
#***************获取所有的商圈信息****************************888
circle_ls = list(map(get_circle,region_ls))
# Out:
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 光明新区没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 光明新区没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# CPU times: user 55.4 s, sys: 920 ms, total: 56.3 s
# Wall time: 8min 37s

# %%
#解链
circle_ls = list(itertools.chain.from_iterable(circle_ls))

# %%
get_spc_path("/home/zhh/dzdp_data/","szmeishi")
# Out:
# done!!

# %%
save_cache(circle_ls,"/home/zhh/dzdp_data/szmeishi/深圳_circle_ls.pickle")

# %%
circle_ls = read_cache("/home/zhh/dzdp_data/szmeishi/深圳_circle_ls.pickle")
print(len(circle_ls))
circle_chunk = get_chunk(circle_ls,5)
len(circle_chunk)
# Out:
# 2342
# 469

# %%
offset=33
save_cache(offset,"/home/zhh/dzdp_data/szmeishi/深圳_offset.pickle")

# %%
# %%time
if __name__=='__main__':
    
    
    is_continue = True
    while is_continue:
        
        try:
            #如果偏移量已经达到了660,跳出整个大循环
            offset = read_cache("/home/zhh/dzdp_data/szmeishi/深圳_offset.pickle")
            end = len(circle_chunk)
            if offset >= len(circle_chunk):
                print("整个程序已经完毕！！！")
                break
                
            #************爬取代理ip******************
            global ip_pool
            ip_url = ['http://www.xicidaili.com/nn/']
            test_url = "http://www.dianping.com/shop/2954893"
            ip_pool= Ip_pool(ip_url).get_ip_pool(test_url)
        
                
            #***********多进程处理*************************
            for index,chunk in enumerate(circle_chunk[offset:end]):
                offset_index = offset + index                       #偏移量+计数器
                print("正在爬第{0}chunk".format(offset_index))
                pool = multiprocessing.Pool(processes=2)           # 创建3个进程
                result = []
                for i in chunk:
                    result.append(pool.apply_async(get_stores, (i, ))) #将参数全部加进去
                pool.close()                                  # 关闭进程池，表示不能再往进程池中添加进程，需要在join之前调用
                pool.join()                                   # 等待进程池中的所有进程执行完毕
                
                #***********遍历每个进程的结果*****************
                store_ls = []
                for res in result:
                    store_ls.append(res.get())               #
                
                #***********获取每一个chunk的内容****************
                print("第{0}chunk已经爬完了".format(offset_index))
                store_ls = list(itertools.chain.from_iterable(store_ls))
                save_cache(store_ls,"/home/zhh/dzdp_data/szmeishi/深圳_store_ls_{0}_chunk.pickle".format(offset_index))
                
                #********爬完直接将偏移量设为下一个*************************
                last_offset_1 = offset_index+1
                save_cache(last_offset_1,"/home/zhh/dzdp_data/szmeishi/深圳_offset.pickle")
                
        #***************如果出现ChunkedEncodingError重复执行这段代码*********************     
        except ChunkedEncodingError as e:
            print("出现ChunkedEncodingError")
            last_offset_2 = offset_index
            print("chunkedEncodingError保存offset:{0}".format(last_offset_2))
            save_cache(last_offset_2,"/home/zhh/dzdp_data/szmeishi/深圳_offset.pickle")
            continue
            
        #***************如果出现ChunkedEncodingError重复执行这段代码*********************      
        except KeyboardInterrupt as e:
            print("手动停止")
            last_offset_3 = offset_index
            print("KeyboardInterrupt保存现有的offset:{0}".format(last_offset_3))
            save_cache(last_offset_3,"/home/zhh/dzdp_data/szmeishi/深圳_offset.pickle")
            break
            
            
#     print("***********准备爬商家的详情信息******************")
#     pool = multiprocessing.Pool(processes=3) # 创建3个进程
#     result=[]
#     for i in store_ls:
#         result.append(pool.apply_async(get_info,(i,)))
#     pool.close()
#     pool.join()
    
#     print("信息页已经爬完了！！")
#     info_ls=[]
#     for res in result:
#         info_ls.append(res.get())
#     save_cache(info_ls,"/media/zhh/东方国信/智润安排/移动互联网需求/爬虫/缓存/广州_info_test_ls.pickle")
# Out:
# 一共获取了29个ip
# 正在爬第33chunk
# 0
# 0
# {'https': 'https://124.237.129.154:9999'}
# {'https': 'https://27.219.36.127:8118'}
# 正在爬取第1页
# 0
# {'http': 'http://61.135.217.7:80'}
# 正在爬取第1页
# 0
# {'https': 'https://124.234.240.207:8118'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# 正在爬取第2页
# 0
# {'https': 'https://183.63.140.82:53281'}
# 正在爬取第3页
# 0
# {'http': 'http://61.135.217.7:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# 1
# {'https': 'https://171.212.141.50:8118'}
# 正在爬取第2页
# 0
# {'http': 'http://61.135.217.7:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# 1
# {'https': 'https://119.136.198.124:808'}
# 正在爬取第4页
# 0
# {'https': 'https://114.230.125.130:41452'}
# 正在爬取第5页
# 0
# {'https': 'https://124.237.129.154:9999'}
# 1
# {'https': 'https://114.235.82.126:8118'}
# 正在爬取第6页
# 0
# {'https': 'https://27.219.36.127:8118'}
# 正在爬取第3页
# 0
# {'https': 'https://182.90.108.188:8123'}
# 正在爬取第7页
# 0
# {'https': 'https://114.230.125.130:41452'}
# 正在爬取第8页
# 正在爬取第4页
# 0
# {'https': 'https://183.63.140.82:53281'}
# 0
# {'https': 'https://220.166.240.171:8118'}
# 正在爬取第9页
# 0
# {'https': 'https://114.235.82.126:8118'}
# 正在爬取第5页
# 0
# {'https': 'https://125.109.197.177:46244'}
# 正在爬取第10页
# 0
# {'https': 'https://125.109.197.177:46244'}
# 正在爬取第6页
# 0
# {'https': 'https://124.234.240.207:8118'}
# 正在爬取第7页
# 0
# {'https': 'https://124.237.129.154:9999'}
# 超时
# 正在爬取第11页
# 0
# {'https': 'https://120.78.73.169:808'}
# 正在爬取第12页
# 0
# {'https': 'https://114.98.6.62:4326'}
# 正在爬取第13页
# 0
# {'https': 'https://27.219.36.127:8118'}
# 1
# {'https': 'https://114.98.6.62:4326'}
# 超时
# 访问被拒
# 1
# {'https': 'https://114.230.125.130:41452'}
# 访问被拒
# 2
# {'https': 'https://183.148.67.54:28898'}
# 2
# {'https': 'https://223.241.116.155:8010'}
# 超时
# 3
# {'https': 'https://27.219.36.127:8118'}
# 访问被拒
# 超时
# 3
# {'https': 'https://110.73.13.39:8123'}
# 4
# {'https': 'https://123.196.124.230:10000'}
# 超时
# 超时
# 5
# {'https': 'https://183.148.67.54:28898'}
# 超时
# 4
# {'https': 'https://110.73.13.39:8123'}
# 6
# {'https': 'https://171.212.141.50:8118'}
# 访问被拒
# 正在爬取第8页
# 0
# {'https': 'https://183.151.224.250:8118'}
# 5
# {'https': 'https://223.241.116.155:8010'}
# 超时
# 正在爬取第9页
# 0
# {'https': 'https://27.219.36.127:8118'}
# 正在爬取第10页
# 0
# {'https': 'https://58.221.179.234:8081'}
# 正在爬取第11页
# 0
# {'https': 'https://58.221.179.234:8081'}
# 正在爬取第12页
# 0
# {'https': 'https://183.63.140.82:53281'}
# 6
# {'https': 'https://223.241.78.248:8010'}
# 正在爬取第13页
# 0
# {'https': 'https://183.148.67.54:28898'}
# 正在爬取第14页
# 0
# {'https': 'https://120.78.73.169:808'}
# 正在爬取第14页
# 0
# {'https': 'https://59.40.50.113:8010'}
# 正在爬取第15页
# 0
# {'https': 'https://114.230.125.130:41452'}
# 正在爬取第16页
# 0
# {'https': 'https://182.90.108.188:8123'}
# 正在爬取第17页
# 0
# {'https': 'https://183.148.67.54:28898'}
# 正在爬取第18页
# 0
# {'https': 'https://114.98.6.62:4326'}
# 正在爬取第15页
# 0
# {'https': 'https://223.241.118.235:8010'}
# 正在爬取第16页
# 正在爬取第19页
# 0
# {'https': 'https://124.237.129.154:9999'}
# 0
# {'https': 'https://114.230.125.130:41452'}
# 正在爬取第17页
# 正在爬取第20页
# 0
# {'https': 'https://27.219.36.127:8118'}
# 0
# {'https': 'https://220.166.240.171:8118'}
# 正在爬取第21页
# 正在爬取第18页
# 0
# {'https': 'https://114.230.125.130:41452'}
# 0
# {'https': 'https://220.166.240.171:8118'}
# 正在爬取第22页
# 0
# {'https': 'https://27.219.36.127:8118'}
# 正在爬取第19页
# 0
# {'https': 'https://124.234.240.207:8118'}
# 正在爬取第20页
# 0
# {'https': 'https://58.221.179.234:8081'}
# 正在爬取第23页
# 0
# {'https': 'https://171.212.141.50:8118'}
# 正在爬取第24页
# 正在爬取第21页
# 0
# {'https': 'https://223.241.116.155:8010'}
# 0
# {'https': 'https://27.219.36.127:8118'}
# 正在爬取第25页
# 正在爬取第22页
# 0
# {'https': 'https://59.40.50.113:8010'}
# 0
# {'https': 'https://119.136.198.124:808'}
# 正在爬取第26页
# 正在爬取第23页
# 0
# {'https': 'https://125.109.197.177:46244'}
# 0
# {'https': 'https://110.73.13.39:8123'}
# 正在爬取第24页
# 正在爬取第27页
# 0
# {'https': 'https://124.237.129.154:9999'}
# 0
# {'https': 'https://114.98.6.62:4326'}
# 正在爬取第28页
# 正在爬取第25页
# 0
# {'http': 'http://61.135.217.7:80'}
# 0
# {'https': 'https://58.221.179.234:8081'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# 正在爬取第26页
# 0
# {'https': 'https://122.193.188.236:8118'}
# 正在爬取第27页
# 0
# {'https': 'https://120.78.73.169:808'}
# 正在爬取第28页
# 0
# {'https': 'https://223.241.116.155:8010'}
# 正在爬取第29页
# 0
# {'https': 'https://171.39.28.179:8123'}
# 正在爬取第30页
# 0
# {'https': 'https://114.98.6.62:4326'}
# 正在爬取第31页
# 0
# {'https': 'https://223.241.78.248:8010'}
# 正在爬取第32页
# 0
# {'https': 'https://27.219.36.127:8118'}
# 1
# {'https': 'https://123.196.124.230:10000'}
# 正在爬取第29页
# 正在爬取第33页
# 0
# {'https': 'https://114.98.6.62:4326'}
# 0
# {'https': 'https://223.241.116.155:8010'}
# 正在爬取第30页
# 0
# {'https': 'https://122.193.188.236:8118'}
# 正在爬取第34页
# 0
# {'https': 'https://123.53.135.133:45470'}
# 访问被拒
# 访问被拒
# 1
# {'https': 'https://59.40.50.113:8010'}
# 1
# {'https': 'https://119.136.198.124:808'}
# 超时
# 超时
# 2
# {'https': 'https://171.39.28.179:8123'}
# 2
# {'https': 'https://58.221.179.234:8081'}
# 访问被拒
# 访问被拒
# 3
# {'https': 'https://223.241.118.235:8010'}
# 3
# {'https': 'https://123.196.124.230:10000'}
# 访问被拒
# 访问被拒
# 4
# {'https': 'https://220.166.240.171:8118'}
# 4
# {'https': 'https://122.193.188.236:8118'}
# 访问被拒
# 访问被拒
# 5
# {'https': 'https://114.230.125.130:41452'}
# 5
# {'https': 'https://120.78.73.169:808'}
# 正在爬取第31页
# 0
# {'https': 'https://124.237.129.154:9999'}
# 正在爬取第32页
# 0
# {'https': 'https://123.53.135.133:45470'}
# 正在爬取第33页
# 0
# {'http': 'http://61.135.217.7:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# 正在爬取第35页
# 0
# {'http': 'http://61.135.217.7:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# 1
# {'https': 'https://223.241.78.248:8010'}
# 1
# {'https': 'https://223.241.78.248:8010'}
# 正在爬取第36页
# 0
# {'https': 'https://183.151.224.250:8118'}
# 正在爬取第34页
# 0
# {'https': 'https://27.219.36.127:8118'}
# 超时
# 正在爬取第35页
# 0
# {'https': 'https://114.98.6.62:4326'}
# 1
# {'https': 'https://115.216.119.113:808'}
# 正在爬取第36页
# 0
# {'https': 'https://123.53.135.133:45470'}
# 正在爬取第37页
# 0
# {'https': 'https://120.78.73.169:808'}
# 正在爬取第37页
# 0
# {'https': 'https://119.136.198.124:808'}
# 超时
# 超时
# 1
# {'https': 'https://59.40.50.113:8010'}
# 1
# {'https': 'https://124.234.240.207:8118'}
# 超时
# 超时
# 2
# {'http': 'http://61.135.217.7:80'}
# 超时
# 2
# {'https': 'https://183.151.224.250:8118'}
# 超时
# 3
# {'https': 'https://114.235.82.126:8118'}
# 3
# {'https': 'https://223.241.118.235:8010'}
# 正在爬取第38页
# 0
# {'https': 'https://110.72.18.178:8123'}
# 访问被拒
# 超时
# 1
# {'https': 'https://120.78.73.169:808'}
# 4
# {'https': 'https://183.148.67.54:28898'}
# 超时
# 超时
# 2
# {'https': 'https://114.98.6.62:4326'}
# 5
# {'https': 'https://124.237.129.154:9999'}
# 超时
# 超时
# 3
# {'https': 'https://182.90.108.188:8123'}
# 6
# {'https': 'https://27.219.36.127:8118'}
# 访问被拒
# 访问被拒
# 4
# {'https': 'https://110.72.18.178:8123'}
# 7
# {'https': 'https://125.109.197.177:46244'}
# 访问被拒
# 访问被拒
# 5
# {'https': 'https://114.235.82.126:8118'}
# 8
# {'https': 'https://220.166.240.171:8118'}
# 超时
# 超时
# 9
# {'https': 'https://58.221.179.234:8081'}
# 6
# {'https': 'https://123.196.124.230:10000'}
# 超时
# 正在爬取第39页
# 0
# {'https': 'https://120.78.73.169:808'}
# 10
# {'https': 'https://124.237.129.154:9999'}
# 超时
# 超时
# 1
# {'https': 'https://123.53.135.133:45470'}
# 11
# {'https': 'https://123.53.135.133:45470'}
# 访问被拒
# 超时
# 12
# {'https': 'https://183.148.67.54:28898'}
# 2
# {'https': 'https://110.73.13.39:8123'}
# 超时
# 超时
# 13
# {'https': 'https://120.78.73.169:808'}
# 3
# {'https': 'https://27.219.36.127:8118'}
# 超时
# 超时
# 4
# {'https': 'https://115.216.119.113:808'}
# 14
# {'https': 'https://60.255.186.169:8888'}
# 正在爬取第38页
# 0
# {'https': 'https://114.235.82.126:8118'}
# 访问被拒
# 5
# {'https': 'https://122.193.188.236:8118'}
# 超时
# 超时
# 1
# {'https': 'https://171.212.141.50:8118'}
# 6
# {'https': 'https://125.109.197.177:46244'}
# 超时
# 超时
# 2
# {'https': 'https://122.193.188.236:8118'}
# 7
# {'https': 'https://114.98.6.62:4326'}
# 超时
# 超时
# 3
# {'https': 'https://123.196.124.230:10000'}
# 8
# {'https': 'https://110.72.18.178:8123'}
# 超时
# 超时
# 4
# {'https': 'https://183.151.224.250:8118'}
# 9
# {'https': 'https://59.40.50.113:8010'}
# 超时
# 5
# {'https': 'https://183.63.140.82:53281'}
# 超时
# 超时
# 10
# {'https': 'https://223.241.78.248:8010'}
# 6
# {'https': 'https://60.255.186.169:8888'}
# 超时
# 访问被拒
# 7
# {'https': 'https://115.216.119.113:808'}
# 11
# {'https': 'https://171.39.28.179:8123'}
# 超时
# 超时
# 8
# {'https': 'https://125.109.197.177:46244'}
# 12
# {'https': 'https://183.148.67.54:28898'}
# 超时
# 正在爬取第40页
# 0
# {'https': 'https://124.234.240.207:8118'}
# 访问被拒
# 9
# {'https': 'https://183.151.224.250:8118'}
# 超时
# 1
# {'https': 'https://60.255.186.169:8888'}
# 10
# {'https': 'https://124.234.240.207:8118'}
# 超时
# 超时
# 2
# {'https': 'https://58.221.179.234:8081'}
# 11
# {'https': 'https://223.241.78.248:8010'}
# 超时
# 访问被拒
# 12
# {'https': 'https://123.53.135.133:45470'}
# 3
# {'https': 'https://119.136.198.124:808'}
# 超时
# 超时
# 13
# {'https': 'https://114.98.6.62:4326'}
# 4
# {'https': 'https://27.219.36.127:8118'}
# 超时
# 访问被拒
# 5
# {'https': 'https://110.72.18.178:8123'}
# 14
# {'https': 'https://125.109.197.177:46244'}
# 超时
# 超时
# 6
# {'https': 'https://114.230.125.130:41452'}
# 15
# {'https': 'https://223.241.118.235:8010'}
# 超时
# 超时
# 7
# {'https': 'https://171.212.141.50:8118'}
# 16
# {'http': 'http://61.135.217.7:80'}
# 超时
# 超时
# 8
# {'https': 'https://171.212.141.50:8118'}
# 17
# {'https': 'https://115.216.119.113:808'}
# 超时
# 超时
# 18
# {'https': 'https://59.40.50.113:8010'}
# 9
# {'https': 'https://171.212.141.50:8118'}
# 超时
# 超时
# 19
# {'https': 'https://59.40.50.113:8010'}
# 正在爬取第39页
# 0
# {'https': 'https://171.39.28.179:8123'}
# 10
# {'https': 'https://124.237.129.154:9999'}
# 正在爬取第40页
# 0
# {'https': 'https://60.255.186.169:8888'}
# 正在爬取第41页
# 0
# {'https': 'https://223.241.116.155:8010'}
# 正在爬取第41页
# 0
# {'https': 'https://59.40.50.113:8010'}
# 正在爬取第42页
# 0
# {'https': 'https://123.53.135.133:45470'}
# 正在爬取第43页
# 0
# {'https': 'https://223.241.78.248:8010'}
# 超时
# 正在爬取第44页
# 0
# {'https': 'https://183.148.67.54:28898'}
# 正在爬取第45页
# 0
# {'https': 'https://110.72.18.178:8123'}
# 正在爬取第46页
# 0
# {'https': 'https://120.78.73.169:808'}
# 正在爬取第47页
# 0
# {'https': 'https://125.109.197.177:46244'}
# 1
# {'https': 'https://60.255.186.169:8888'}
# 正在爬取第48页
# 0
# {'https': 'https://125.109.197.177:46244'}
# 正在爬取第42页
# 0
# {'https': 'https://115.216.119.113:808'}
# 正在爬取第49页
# 正在爬取第43页
# 0
# {'https': 'https://27.219.36.127:8118'}
# 0
# {'https': 'https://171.212.141.50:8118'}
# 正在爬取第44页
# 正在爬取第50页
# 0
# {'https': 'https://223.241.118.235:8010'}
# 0
# {'https': 'https://183.151.224.250:8118'}
# 正在爬取第1页
# 正在爬取第1页
# 0
# {'https': 'https://183.148.67.54:28898'}
# 0
# {'https': 'https://223.241.116.155:8010'}
# 正在爬取第2页
# 0
# {'https': 'https://60.255.186.169:8888'}
# 正在爬取第2页
# 0
# {'https': 'https://183.63.140.82:53281'}
# 正在爬取第3页
# 0
# {'https': 'https://183.148.67.54:28898'}
# 正在爬取第3页
# 0
# {'https': 'https://124.234.240.207:8118'}
# 正在爬取第4页
# 0
# {'https': 'https://27.219.36.127:8118'}
# 超时
# 正在爬取第5页
# 0
# {'https': 'https://110.72.18.178:8123'}
# 1
# {'https': 'https://223.241.116.155:8010'}
# 超时
# 访问被拒
# 1
# {'https': 'https://123.196.124.230:10000'}
# 正在爬取第6页
# 0
# {'https': 'https://123.196.124.230:10000'}
# 正在爬取第7页
# 0
# {'https': 'https://120.78.73.169:808'}
# 2
# {'https': 'https://171.212.141.50:8118'}
# 正在爬取第4页
# 0
# {'https': 'https://125.109.197.177:46244'}
# 正在爬取第8页
# 0
# {'https': 'https://124.237.129.154:9999'}
# 正在爬取第9页
# 0
# {'https': 'https://123.196.124.230:10000'}
# 正在爬取第5页
# 0
# {'https': 'https://123.53.135.133:45470'}
# 正在爬取第6页
# 0
# {'https': 'https://27.219.36.127:8118'}
# 正在爬取第7页
# 0
# {'https': 'https://223.241.116.155:8010'}
# 正在爬取第10页
# 0
# {'https': 'https://120.78.73.169:808'}
# 正在爬取第11页
# 0
# {'https': 'https://182.90.108.188:8123'}
# 正在爬取第8页
# 0
# {'https': 'https://223.241.116.155:8010'}
# 正在爬取第9页
# 0
# {'https': 'https://60.255.186.169:8888'}
# 超时
# 正在爬取第10页
# 0
# {'https': 'https://123.196.124.230:10000'}
# 正在爬取第11页
# 0
# {'https': 'https://124.234.240.207:8118'}
# 正在爬取第12页
# 0
# {'https': 'https://183.148.67.54:28898'}
# 正在爬取第13页
# 0
# {'https': 'https://223.241.116.155:8010'}
# 1
# {'https': 'https://171.39.28.179:8123'}
# 超时
# 超时
# 2
# {'https': 'https://124.234.240.207:8118'}
# 1
# {'https': 'https://182.90.108.188:8123'}
# 超时
# 访问被拒
# 2
# {'https': 'https://114.230.125.130:41452'}
# 3
# {'https': 'https://125.109.197.177:46244'}
# 超时
# 访问被拒
# 3
# {'https': 'https://110.73.13.39:8123'}
# 4
# {'https': 'https://114.98.6.62:4326'}
# 超时
# 访问被拒
# 5
# {'https': 'https://223.241.116.155:8010'}
# 4
# {'https': 'https://110.73.13.39:8123'}
# 访问被拒
# 访问被拒
# 6
# {'https': 'https://182.90.108.188:8123'}
# 5
# {'https': 'https://171.39.28.179:8123'}
# 访问被拒
# 访问被拒
# 6
# {'https': 'https://119.136.198.124:808'}
# 7
# {'http': 'http://61.135.217.7:80'}
# 超时
# 超时
# 8
# {'https': 'https://60.255.186.169:8888'}
# 7
# {'https': 'https://171.212.141.50:8118'}
# 超时
# 9
# {'https': 'https://114.230.125.130:41452'}
# 超时
# 超时
# 10
# {'https': 'https://183.148.67.54:28898'}
# 8
# {'https': 'https://120.78.73.169:808'}
# 超时
# 超时
# 11
# {'https': 'https://114.230.125.130:41452'}
# 9
# {'https': 'https://182.90.108.188:8123'}
# 超时
# 超时
# 12
# {'https': 'https://182.90.108.188:8123'}
# 10
# {'https': 'https://183.148.67.54:28898'}
# 超时
# 超时
# 11
# 13
# {'https': 'https://114.235.82.126:8118'}
# {'https': 'https://183.148.67.54:28898'}
# 超时
# 超时
# 14
# {'https': 'https://122.193.188.236:8118'}
# 12
# {'https': 'https://223.241.118.235:8010'}
# 访问被拒
# 访问被拒
# 15
# {'https': 'https://125.109.197.177:46244'}
# 13
# {'https': 'https://183.151.224.250:8118'}
# 手动停止
# KeyboardInterrupt保存现有的offset:33
# CPU times: user 1.92 s, sys: 464 ms, total: 2.38 s
# Wall time: 25min 9s
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-2:
# Traceback (most recent call last):
#   File "/home/zhh/anaconda3/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/zhh/anaconda3/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/zhh/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhh/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-12-229cd50864d3>", line 33, in get_stores
#     soup = requests_visit_url_test(url,is_use_ip=True,timeout=2)   #更新BeautifulSoup对象
#   File "<ipython-input-15-6e92c5b4dfd6>", line 54, in requests_visit_url_test
#     res = requests.get(url,headers = headers,proxies = proxies,timeout=timeout) #设代理ip访问
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/zhh/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 357, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/zhh/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/zhh/anaconda3/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "<ipython-input-12-229cd50864d3>", line 33, in get_stores
#     soup = requests_visit_url_test(url,is_use_ip=True,timeout=2)   #更新BeautifulSoup对象
#   File "<ipython-input-15-6e92c5b4dfd6>", line 54, in requests_visit_url_test
#     res = requests.get(url,headers = headers,proxies = proxies,timeout=timeout) #设代理ip访问
#   File "/home/zhh/anaconda3/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/zhh/anaconda3/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/zhh/anaconda3/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/home/zhh/anaconda3/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 166, in connect
#     conn = self._new_conn()
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py", line 60, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 357, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/zhh/anaconda3/lib/python3.6/socket.py", line 743, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#   File "/home/zhh/anaconda3/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
# KeyboardInterrupt
#   File "/home/zhh/anaconda3/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/home/zhh/anaconda3/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/home/zhh/anaconda3/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/home/zhh/anaconda3/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 166, in connect
#     conn = self._new_conn()
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/zhh/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py", line 60, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/home/zhh/anaconda3/lib/python3.6/socket.py", line 743, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# KeyboardInterrupt
# 0
# {'https': 'https://123.53.135.133:45470'}
# 访问被拒
# 1
# {'https': 'https://110.72.18.178:8123'}
# 正在爬取第1页
# 0
# {'https': 'https://119.136.198.124:808'}
# 正在爬取第2页
# 0
# {'https': 'https://110.72.18.178:8123'}
# 正在爬取第3页
# 0
# {'https': 'https://125.109.197.177:46244'}
# 正在爬取第4页
# 0
# {'https': 'https://223.241.78.248:8010'}
# 正在爬取第5页
# 0
# {'https': 'https://171.39.28.179:8123'}
# 正在爬取第6页
# 0
# {'https': 'https://60.255.186.169:8888'}
# 正在爬取第7页
# 0
# {'https': 'https://223.241.118.235:8010'}
# 正在爬取第8页
# 0
# {'https': 'https://60.255.186.169:8888'}
# 正在爬取第9页
# 0
# {'https': 'https://58.221.179.234:8081'}
# 正在爬取第10页
# 0
# {'https': 'https://124.234.240.207:8118'}
# 正在爬取第11页
# 0
# {'https': 'https://114.235.82.126:8118'}
# 正在爬取第12页
# 0
# {'http': 'http://61.135.217.7:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# 1
# {'https': 'https://171.39.28.179:8123'}
# 正在爬取第13页
# 0
# {'https': 'https://123.196.124.230:10000'}
# 正在爬取第14页
# 0
# {'https': 'https://114.98.6.62:4326'}
# 正在爬取第15页
# 0
# {'https': 'https://114.98.6.62:4326'}
# 正在爬取第16页
# 0
# {'https': 'https://122.193.188.236:8118'}
# 正在爬取第17页
# 0
# {'https': 'https://58.221.179.234:8081'}
# 正在爬取第18页
# 0
# {'https': 'https://110.72.18.178:8123'}
# 正在爬取第19页
# 0
# {'https': 'https://60.255.186.169:8888'}
# 正在爬取第20页
# 0
# {'https': 'https://171.39.28.179:8123'}
# 正在爬取第21页
# 0
# {'https': 'https://125.109.197.177:46244'}
# 正在爬取第22页
# 0
# {'https': 'https://114.230.125.130:41452'}
# 正在爬取第23页
# 0
# {'https': 'https://183.63.140.82:53281'}
# 正在爬取第24页
# 0
# {'https': 'https://171.39.28.179:8123'}
# 正在爬取第25页
# 0
# {'https': 'https://123.196.124.230:10000'}
# 正在爬取第26页
# 0
# {'https': 'https://27.219.36.127:8118'}
# 正在爬取第27页
# 0
# {'https': 'https://183.151.224.250:8118'}
# 正在爬取第28页
# 0
# {'https': 'https://220.166.240.171:8118'}
# 正在爬取第29页
# 0
# {'https': 'https://60.255.186.169:8888'}
# 正在爬取第30页
# 0
# {'https': 'https://223.241.78.248:8010'}
# 正在爬取第31页
# 0
# {'https': 'https://110.72.18.178:8123'}
# 正在爬取第32页
# 0
# {'https': 'https://223.241.118.235:8010'}
# 正在爬取第33页
# 0
# {'https': 'https://123.196.124.230:10000'}
# 正在爬取第34页
# 0
# {'https': 'https://110.73.13.39:8123'}
# 正在爬取第35页
# 0
# {'https': 'https://27.219.36.127:8118'}
# 正在爬取第36页
# 0
# {'https': 'https://223.241.78.248:8010'}
# 正在爬取第37页
# 0
# {'https': 'https://183.63.140.82:53281'}
# 正在爬取第38页
# 0
# {'https': 'https://183.148.67.54:28898'}
# 正在爬取第39页
# 0
# {'https': 'https://114.235.82.126:8118'}
# 正在爬取第40页
# 0
# {'https': 'https://110.72.18.178:8123'}
# 正在爬取第41页
# 0
# {'https': 'https://182.90.108.188:8123'}
# 正在爬取第42页
# 0
# {'https': 'https://183.148.67.54:28898'}
# 正在爬取第43页
# 0
# {'https': 'https://125.109.197.177:46244'}
# 正在爬取第44页
# 0
# {'http': 'http://61.135.217.7:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# 1
# {'https': 'https://183.151.224.250:8118'}
# 正在爬取第45页
# 0
# {'https': 'https://124.234.240.207:8118'}
# 正在爬取第46页
# 0
# {'https': 'https://223.241.118.235:8010'}
# 正在爬取第47页
# 0
# {'https': 'https://110.72.18.178:8123'}
# 正在爬取第48页
# 0
# {'https': 'https://59.40.50.113:8010'}
# 正在爬取第49页
# 0
# {'https': 'https://58.221.179.234:8081'}
# 正在爬取第50页

# %% [markdown]
# ## 爬取所有的商家信息

# %%
def merge_chunk(file_dir,regrex="(.*?_store_ls_\d+_chunk.pickle)"):
    file_ls = os.listdir(file_dir)  #得出列出文件
    re_ptn = re.compile(regrex)   #正则表达式
    files = []
    result =[]
    for i in file_ls:
        if re_ptn.search(i):
            files.append(i)
    
    print("合并{0}个chunk".format(len(files)))
    for i in files:
        sub_result = read_cache(file_dir+i)
        result.extend(sub_result)
    return result

# %% [markdown]
# ##### 佛山

# %%
result = merge_chunk("/home/zhh/dzdp_data/酒店/dghotel/")
# Out:
# 合并97个chunk

# %%
info_chunk = get_chunk(result,10)
len(info_chunk)
# Out:
# 209

# %%
global ip_pool
ip_url = ['http://www.xicidaili.com/nn/']
test_url = "http://www.dianping.com/shop/9310903"
ip_pool= Ip_pool(ip_url).get_ip_pool(test_url)
# Out:
# 一共获取了27个ip

# %%
ip_pool
# Out:
# [['https', 'https://110.72.254.9:8123'],
#  ['https', 'https://175.171.108.227:53281'],
#  ['https', 'https://223.241.116.21:8010'],
#  ['https', 'https://220.163.36.161:8118'],
#  ['http', 'http://111.76.184.204:43231'],
#  ['http', 'http://61.135.217.7:80'],
#  ['https', 'https://125.81.59.37:8123'],
#  ['https', 'https://60.255.230.185:808'],
#  ['https', 'https://42.55.171.123:80'],
#  ['https', 'https://115.217.254.147:808'],
#  ['https', 'https://125.37.173.126:8118'],
#  ['https', 'https://111.76.17.246:4329'],
#  ['https', 'https://60.255.186.169:8888'],
#  ['https', 'https://110.73.49.97:8123'],
#  ['https', 'https://60.169.219.186:32758'],
#  ['https', 'https://122.193.246.67:8118'],
#  ['https', 'https://140.250.164.53:37247'],
#  ['http', 'http://115.219.36.69:2316'],
#  ['http', 'http://117.78.37.198:8000'],
#  ['https', 'https://124.152.80.19:4369'],
#  ['https', 'https://59.40.51.23:8010'],
#  ['https', 'https://114.99.8.138:6890'],
#  ['https', 'https://115.46.81.95:8123'],
#  ['https', 'https://121.207.194.29:8118'],
#  ['https', 'https://27.209.15.96:4356'],
#  ['https', 'https://110.73.13.122:8123'],
#  ['https', 'https://175.149.89.169:4396']]

# %%
info_chunk = list(itertools.chain.from_iterable(info_chunk))

# %%
len(info_chunk)
# Out:
# 2081

# %%
info_chunk[0]
# Out:
# ['酒店',
#  '东莞',
#  '四星级/高档型',
#  '凤岗镇',
#  '雁田',
#  'http://www.dianping.com/dongguan/hotel/g3022r23424',
#  '东莞龙门阁酒店',
#  'http://www.dianping.com/shop/19125200']

# %%
soup = requests_visit_url_test("http://www.dianping.com/shop/19125200",is_use_ip=True)
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3'}
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3'}
# 0
# {'http': 'http://111.76.184.204:43231'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3'}
# 1
# {'https': 'https://27.209.15.96:4356'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3'}
# 2
# {'https': 'https://110.72.254.9:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24'}
# 3
# {'http': 'http://61.135.217.7:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3'}
# 4
# {'https': 'https://110.73.49.97:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1'}
# 5
# {'https': 'https://125.81.59.37:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3'}
# 6
# {'https': 'https://125.81.59.37:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1'}
# 7
# {'https': 'https://121.207.194.29:8118'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1'}
# 8
# {'http': 'http://115.219.36.69:2316'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11'}
# 9
# {'https': 'https://110.73.49.97:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6'}
# 10
# {'https': 'https://115.217.254.147:808'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24'}
# 11
# {'https': 'https://175.149.89.169:4396'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3'}
# 12
# {'https': 'https://115.46.81.95:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3'}
# 13
# {'https': 'https://111.76.17.246:4329'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3'}
# 14
# {'https': 'https://122.193.246.67:8118'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3'}
# 15
# {'https': 'https://60.255.186.169:8888'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24'}
# 16
# {'https': 'https://220.163.36.161:8118'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5'}
# 17
# {'https': 'https://122.193.246.67:8118'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3'}
# 18
# {'https': 'https://121.207.194.29:8118'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1'}
# 19
# {'http': 'http://111.76.184.204:43231'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6'}
# 20
# {'https': 'https://114.99.8.138:6890'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3'}
# 21
# {'http': 'http://117.78.37.198:8000'}
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1'}
# 22
# {'https': 'https://121.207.194.29:8118'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3'}
# 23
# {'https': 'https://60.255.230.185:808'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5'}
# 24
# {'http': 'http://111.76.184.204:43231'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3'}
# 25
# {'http': 'http://111.76.184.204:43231'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1'}
# 26
# {'https': 'https://223.241.116.21:8010'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6'}
# 27
# 一共获取了125个ip
# {'https': 'https://180.120.201.32:24362'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3'}
# 1
# {'https': 'https://123.138.89.133:9999'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1'}
# 2
# {'https': 'https://112.95.207.10:8888'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3'}
# 3
# {'https': 'https://223.215.154.43:4326'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3'}
# 4
# {'https': 'https://123.170.246.35:8118'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3'}
# 5
# {'https': 'https://122.72.18.61:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3'}
# 6
# {'http': 'http://58.87.74.207:80'}
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.67 Safari/537.36'}
# 7
# {'https': 'https://223.215.154.43:4326'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3'}
# 8
# {'http': 'http://218.56.132.156:8080'}
# 超时
# {'User-Agent': 'Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11'}
# 9
# {'https': 'https://220.163.36.161:8118'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3'}
# 10
# {'http': 'http://116.53.199.233:8118'}
# ---------- <html><body><p>Maximum number of open connections reached.
# </p></body></html>
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5'}
# 11
# {'https': 'https://61.158.111.142:53281'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11'}
# 12
# {'http': 'http://113.91.64.92:8118'}
# ---------- <html><body><p>Maximum number of open connections reached.
# </p></body></html>
# {'User-Agent': 'Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11'}
# 13
# {'https': 'https://39.88.13.3:53281'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1'}
# 14
# {'http': 'http://218.56.132.156:8080'}
# 超时
# {'User-Agent': 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3'}
# 15
# {'https': 'https://115.85.206.221:4369'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5'}
# 16
# {'https': 'https://175.149.89.169:4396'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11'}
# 17
# {'https': 'https://220.163.36.161:8118'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3'}
# 18
# {'http': 'http://222.174.168.102:53281'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3'}
# 19
# {'https': 'https://14.153.53.181:3128'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3'}
# 20
# {'http': 'http://61.155.164.110:3128'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6'}
# 21
# {'https': 'https://219.228.107.62:1080'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5'}
# 22
# {'http': 'http://61.135.217.7:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1'}
# 23
# {'https': 'https://110.72.254.9:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3'}
# 24
# {'https': 'https://59.40.51.23:8010'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5'}
# 25
# {'https': 'https://61.152.230.26:8080'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24'}
# 26
# {'https': 'https://223.241.116.21:8010'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3'}
# 27
# {'https': 'https://27.44.252.40:9000'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5'}
# 28
# {'https': 'https://121.43.178.58:3128'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5'}
# 29
# {'https': 'https://1.196.122.109:9000'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3'}
# 30
# {'https': 'https://223.215.154.43:4326'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24'}
# 31
# {'https': 'https://116.52.232.98:9999'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6'}
# 32
# {'https': 'https://123.138.89.133:9999'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3'}
# 33
# {'https': 'https://49.84.71.91:45169'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3'}
# 34
# {'https': 'https://60.255.230.185:808'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24'}
# 35
# {'https': 'https://27.46.74.54:9999'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1'}
# 36
# {'https': 'https://175.149.89.169:4396'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6'}
# 37
# {'https': 'https://61.158.111.142:53281'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6'}
# 38
# {'https': 'https://124.90.27.96:8118'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5'}
# 39
# {'https': 'https://218.83.106.150:9797'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24'}
# 40
# {'https': 'https://110.72.254.9:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3'}
# 41
# {'https': 'https://175.171.108.227:53281'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24'}
# 42
# {'https': 'https://49.84.71.91:45169'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3'}
# 43
# {'https': 'https://112.95.206.62:8888'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1'}
# 44
# {'https': 'https://112.95.206.62:8888'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1'}
# 45
# {'https': 'https://1.119.184.216:3128'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3'}
# 46
# {'https': 'https://114.99.8.138:6890'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3'}
# 47
# {'http': 'http://124.152.185.209:4329'}
# 访问被拒
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6'}
# 48
# {'https': 'https://1.196.122.109:9000'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-20-974dc00512a5> in requests_visit_url_test(url, is_use_ip, timeout)
#      53                         print("ip被禁止了!!!!!!!!!!!!!!!!!!!!")
# ---> 54                         raise ConnectionError
#      55                     else:
#
# ConnectionError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-a51140d3e2ba> in <module>()
# ----> 1 soup = requests_visit_url_test("http://www.dianping.com/shop/19125200",is_use_ip=True)
#
# <ipython-input-20-974dc00512a5> in requests_visit_url_test(url, is_use_ip, timeout)
#      74                     print("访问被拒")
#      75                     prox_ip = random.choice(ip_pool)
# ---> 76                     time.sleep(1)
#      77
#      78                 except AttributeError as e:
#
# KeyboardInterrupt:

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <!-- headder中 H5页面PV埋点代码 start-->
# <!-- 上报通道标识 -->
# <meta content="hotel" name="lx:category"/>
# <!-- 上报应用标识 -->
# <meta content="dp_pc" name="lx:appnm"/>
# <!-- 页面名称：酒店商户详情页-点评PC，上报页面标识 -->
# <meta content="hotel_poidetail" name="lx:cid"/>
# <!-- 加载sdk -->
# <link href="//analytics.meituan.net" rel="dns-prefetch"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <script>
#         "use strict";!function(){var i=arguments.length>0&&void 0!==arguments[0]?arguments[0]:"_Owl_",n=window,a={page:!0,resource:!0,js:!0};n[i]||(n[i]={isRunning:!1,isReady:!1,preTasks:[],config:a,dataSet:[],use:function(i,a){this.isReady&&n.Owl&&n.Owl[i](a),this.preTasks.push({api:i,data:[a]})},add:function(i){this.dataSet.push(i)},run:function(i){var a=this;if(!this.isRunning){this.isRunning=!0;var e=i||this.config;if(!1!==e.js){var t=n.onerror;n.onerror=function(){this.isReady||this.add({type:"jsError",data:arguments}),t&&t.apply(n,arguments)}.bind(this)}!1!==e.page&&n.addEventListener("load",function(){if(!a.isReady){var i=window.performance&&window.performance.timing;a.add({type:"pageTime",data:[i]})}}),!1!==e.resource&&(window.addEventListener("error",function(i){a.isReady||a.add({type:"resError",data:[i]})},!0),window.addEventListener("load",function(i){a.isReady||a.add({type:"resTime",data:[i]})}))}}})}();
#         _Owl_.run()
#     </script>
# <script type="text/javascript">
#         (function(){
#             var ua = ["iPhone", "Android", "Windows Phone"];
#             var base = 'm.dianping.com';
#             var path = '/awp/h5/hotel-dp/shop-detail/index.html?shopId=' + location.pathname.replace(/\D+/, '');
#             var isMobile = false;
#             for(var i = 0; i < ua.length; i++){
#                 if(navigator.userAgent.indexOf(ua[i]) !== -1){
#                     isMobile = true;
#                     break;
#                 }
#             }
#             function fromMobile(){
#                 if (document.referrer.indexOf(base) !== -1) {
#                     document.cookie = "vmod=pc;expires=0;"
#                 }
#                 return document.cookie.match(/vmod=pc/);
#             }
#             if(isMobile){
#                 if(!fromMobile()){
#                    location.href = 'https://'  + base + path;
#                 }
#             }
#         })();
#     </script>
# <link href="//www.dpfile.com/s/res/favicon.5ff777c11d7833e57e01c9d192b7e427.ico" rel="Shortcut Icon" type="image/x-icon"/>
# <link href="//mc.meituan.net/hotel/dp-hotel-fe-pc/static/css/normalize.css" rel="stylesheet"/>
# <link href="//mc.meituan.net/hotel/dp-hotel-fe-pc/poi-detail.893f8f903165deb4859f.css" rel="stylesheet"/>
# <link as="script" href="//mc.meituan.net/hotel/dp-hotel-fe-pc/poi-detail-client.893f8f903165deb4859f.js" rel="preload"/>
# <link as="script" href="//mc.meituan.net/hotel/dp-hotel-fe-pc/commons.d95992de7937a9c533ad.js" rel="preload"/>
# <link as="script" href="//mc.meituan.net/hotel/dp-hotel-fe-pc/static/js/legacy.js" rel="preload"/>
# <link as="script" href="//mc.meituan.net/hotel/dp-hotel-fe-pc/static/js/qrcode.min.js" rel="preload"/>
# <link as="script" href="//awp-assets.meituan.net/hfe/hfe-assets/eb/raven-js/dist/raven.min.js" rel="preload"/>
# <link as="script" href="//awp-assets.meituan.net/hfe/rohr/1.0.2/rohr.min.js" rel="preload"/>
# <script>
#         document.documentElement.className = location.hash ? 'J_H' : '';
#         var G_rtop = +new Date,
#             _gaq = [
#                 ['_setAccount', 'UA-45699261-1'],
#                 ['_addOrganic', 'soso', 'w'],
#                 ['_addOrganic', 'sogou', 'query'],
#                 ['_addOrganic', 'yodao', 'q'],
#                 ['_addOrganic', 'bing', 'q'],
#                 ['_addOrganic', '360', 'q'],
#                 ['_addOrganic', 'gougou', 'search'],
#                 ['_setDomainName', '.dianping.com']
#                 , ['_setAllowHash', false]
#
#             ],
#             dpga = function (key) {
#                 _gaq.push(['_trackPageview', key || ''])
#             },
#             pageTracker = {_trackPageview: dpga},
#             _hip = [
#                 ['_setPageId', 12],
#                 ['_setCityId', 219],
#                 ['_setShopId', 19125200],
#                 ['_setShopType', 60],
#                 ['_setPVInitData', {p_render: +(new Date) - G_rtop, hkw: 1, shop_id: 19125200}]
#             ];
#
#     </script>
# <script>window.__INITIAL_STATE__ = {"basicInfo":{"shopId":19125200,"shopName":"东莞龙门阁酒店","fullName":"东莞龙门阁酒店","shopType":60,"power":5,"price":178,"fullAdress":"小捷滘捷东南路1号","shopPower":35,"score":38,"hits":774,"todayHits":1,"weeklyHits":12,"addUser":-26176,"lastUser":73738,"firstReviewId":null,"addUserName":"陈美丽","lastUserName":"孙笛","firstUserNickName":null,"hasBeenClaimed":false,"reviewCount":6,"favoriteCount":5,"transportInfo":null,"lat":22.806501,"lng":113.702285,"lastTime":"17-06-08","refShopId":0,"refShopTypeStr":null,"phoneNo":"89362222","city":"东莞"},"isFavoriteShop":false,"showMobileDialog":false,"isLoadingGoodsList":true,"lowestPrice":null,"curGoods":null,"breadCrumb":{"district":null,"businessArea":{"regionId":23424,"regionName":"雁田","regionAltName":"雁田","cityId":219,"parentRegionId":12024,"regionOrderId":0,"regionType":2,"gLat":22.697565,"gLng":114.173335},"categoryPath":[{"categoryId":3022,"cityId":219,"categoryName":"四星级\u002F高档型","categoryURLName":"","categoryOrderId":20,"categoryLevelType":2,"mainParentCategoryId":60},{"categoryId":3026,"cityId":219,"categoryName":"高档型","categoryURLName":"","categoryOrderId":20,"categoryLevelType":3,"mainParentCategoryId":3022}]},"cityInfo":{"cityId":219,"cityName":"东莞","provinceId":19,"parentCityId":0,"cityOrderId":1104,"isActiveCity":true,"cityEnName":"dongguan","cityPyName":"dongguan","cityAreaCode":"0769","cityAbbrCode":"DG","isOverseasCity":false,"isScenery":false,"TuanGouFlag":1,"cityLevel":4,"appHotLevel":1,"gLat":23.020536,"gLng":113.751766,"directURL":"","standardEnName":null},"picInfo":{"headPic":[{"picUrl":"https:\u002F\u002Fp0.meituan.net\u002Ftdchotel\u002F74642f4394a8c4f33c78bf6e5a98c1c5546263.png%40700w_700h_0e_1l%7Cwatermark%3D1%26%26r%3D1%26p%3D9%26x%3D2%26y%3D2%26relative%3D1%26o%3D20"},{"picUrl":"https:\u002F\u002Fp1.meituan.net\u002Ftdchotel\u002Ff2d1f4e45b223ac37120aa870a97b85d518420.png%40700w_700h_0e_1l%7Cwatermark%3D1%26%26r%3D1%26p%3D9%26x%3D2%26y%3D2%26relative%3D1%26o%3D20"},{"picUrl":"https:\u002F\u002Fp0.meituan.net\u002Ftdchotel\u002Fc1393dbadb10478c881adbbe826ed6d1380790.png%40700w_700h_0e_1l%7Cwatermark%3D1%26%26r%3D1%26p%3D9%26x%3D2%26y%3D2%26relative%3D1%26o%3D20"},{"picUrl":"https:\u002F\u002Fp0.meituan.net\u002Ftdchotel\u002Fd7203677b8965ef8822ebdc1e6bd6f25409803.png%40700w_700h_0e_1l%7Cwatermark%3D1%26%26r%3D1%26p%3D9%26x%3D2%26y%3D2%26relative%3D1%26o%3D20"},{"picUrl":"https:\u002F\u002Fp0.meituan.net\u002Ftdchotel\u002F94cf9898c5bcdac64312bee51044320b323481.png%40700w_700h_0e_1l%7Cwatermark%3D1%26%26r%3D1%26p%3D9%26x%3D2%26y%3D2%26relative%3D1%26o%3D20"},{"picUrl":"https:\u002F\u002Fp0.meituan.net\u002Ftdchotel\u002F7016bd9b0df38380849e397310396cb4565013.png%40700w_700h_0e_1l%7Cwatermark%3D1%26%26r%3D1%26p%3D9%26x%3D2%26y%3D2%26relative%3D1%26o%3D20"},{"picUrl":"https:\u002F\u002Fp1.meituan.net\u002Ftdchotel\u002F252781f8e8d28511cf8d534668d4e7e0263132.jpg%40700w_700h_0e_1l%7Cwatermark%3D1%26%26r%3D1%26p%3D9%26x%3D2%26y%3D2%26relative%3D1%26o%3D20"}],"picList":[],"picCount":37},"hotelIntro":{"openningTime":"2014年开业 2014年装修","checkInTime":"请在14:00以后入住并于次日12:00前退房","contact":"0769-89362222","intro":"皇庭酒店位于虎门镇小捷滘捷东南路1号，交通便利，环境优美，酒店拥有充足温馨的客房可供入住，设备齐全，卫生优良，是您外出旅游经商休息的好选择","reservHotline":null,"reservHotlineExtraText":null,"facilities":[],"services":[],"roomFacilities":[]},"hotelLocation":{"railwayStation":[{"name":"南城汽车站","distance":"19.8km"},{"name":"常平火车站","distance":"38.9km"},{"name":"东莞东站","distance":"38.8km"},{"name":"东莞火车站","distance":"36.5km"}],"metroStation":[],"hotMark":[]},"userComment":{"reviewCountStar1":1,"reviewCountStar2":1,"reviewCountStar3":0,"reviewCountStar4":2,"reviewCountStar5":2,"reviewCountAllStar":0,"reviewCountAll":6,"reviewCountPark":0,"reviewCountPic":1,"reviewCountForMore":6,"reviewDataList":[{"good":false,"reviewData":{"userId":885074011,"shopId":19125200,"picTotal":14,"lastTime":"2017-10-02 11:16","addTime":"2017-10-02 11:16","followNoteNo":0,"reviewBody":"[早餐]超级想念广东早茶的。吃的非常非常饱。因为觉得好吃。看来去了武汉以后任何广东菜都觉得好吃。\n环境:龙门阁二楼，比较大\n服 ...
# <title>东莞龙门阁酒店地址,电话,价格,预定(图)-东莞酒店预定-大众点评网</title>
# <meta content="东莞龙门阁酒店,东莞酒店预定" name="Keywords"/>
# <meta content="东莞龙门阁酒店,小捷滘捷东南路1号,点击查看更多关于东莞龙门阁酒店的预定电话,价格,地址,地图以及周边停车,公交等交通信息.还可以查看用户对该酒店的点评信息." name="Description"/>
# <meta content="format=html5; url=https://m.dianping.com/awp/h5/hotel-dp/shop-detail/index.html?shopId=19125200" http-equiv="mobile-agent" name="mobile-agent"/>
# <link href="https://m.dianping.com/shop/19125200" media="only screen and (max-width: 640px)" rel="alternate"/>
# <script>
#         !function(e,t,n){function s(){var e=t.createElement("script");e.async=!0,e.src="https://s0.meituan.net/bs/js/?f=mta-js:mta.min.js";var n=t.getElementsByTagName("script")[0];n.parentNode.insertBefore(e,n)}"[object String]"===Object.prototype.toString.call(n)&&(n=[n]),e.MeituanAnalyticsObject=n;for(var r=0;r<n.length;r++)!function(t){e[t]=e[t]||function(){(e[t].q=e[t].q||[]).push(arguments)}}(n[r]);if("complete"===t.readyState)s();else{var i="addEventListener",a="attachEvent";if(e[i])e[i]("load",s,!1);else if(e[a])e[a]("onload",s);else{var o=e.onload;e.onload=function(){s(),o&&o()}}}}(window,document,"mta"),function(e,t,n){if(t&&!("_mta"in t)){t._mta=!0;var s=e.location.protocol;if("file:"!==s){var r=e.location.host,i=t.prototype.open;t.prototype.open=function(t,n,a,o,l){if(this._method="string"==typeof t?t.toUpperCase():null,n){if(0===n.indexOf("http://")||0===n.indexOf("https://")||0===n.indexOf("//"))this._url=n;else if(0===n.indexOf("/"))this._url=s+"//"+r+n;else{var h=s+"//"+r+e.location.pathname;h=h.substring(0,h.lastIndexOf("/")+1),this._url=h+n}var u=this._url.indexOf("?");-1!==u?(this._searchLength=this._url.length-1-u,this._url=this._url.substring(0,u)):this._searchLength=0}else this._url=null,this._searchLength=0;return this._startTime=(new Date).getTime(),i.apply(this,arguments)};var a="onreadystatechange",o="addEventListener",l=t.prototype.send;t.prototype.send=function(t){function n(n,r){if(0!==n._url.indexOf(s+"//frep.meituan.net/_.gif")){for(var i="browser.ajax",a=[98,114,111,119,115,101,114,46,97,106,97,120],o=0,l=i.length;l>o;o++)if(i.charCodeAt(o)!==a[o])return;var h;if(n.response)switch(n.responseType){case"json":h=JSON&&JSON.stringify(n.response).length;break;case"blob":case"moz-blob":h=n.response.size;break;case"arraybuffer":h=n.response.byteLength;case"document":h=n.response.documentElement&&n.response.documentElement.innerHTML&&n.response.documentElement.innerHTML.length+28;break;default:h=n.response.length}e.mta("send",i,{url:n._url,method:n._method,error:!(0===n.status.toString().indexOf("2")||304===n.status),responseTime:(new Date).getTime()-n._startTime,requestSize:n._searchLength+(t?t.length:0),responseSize:h||0})}}if(o in this){var r=function(e){n(this,e)};this[o]("load",r),this[o]("error",r),this[o]("abort",r)}else{var i=this[a];this[a]=function(t){i&&i.apply(this,arguments),4===this.readyState&&e.mta&&e.mta&&n(this,t)}}return l.apply(this,arguments)}}}}(window,window.XMLHttpRequest,"mta");
#         mta("create","587d8794c552d508b5cd7446");
#         mta("config", "beaconImage", "https://frep.meituan.net/_.gif");
#         mta("send","page");
#     </script>
# <script async="" charset="utf-8" defer="" src="//analytics.meituan.net/analytics.js" type="text/javascript"></script>
# <script type="text/javascript">
#         !(function (win, doc, ns) {
#             var cacheFunName = '_MeiTuanALogObject';
#             win[cacheFunName] = ns;
#             if (!win[ns]) {
#                 var _LX = function () {
#                     _LX.q.push(arguments);
#                     return _LX;
#                 };
#                 _LX.q = _LX.q || [];
#                 _LX.l = +new Date();
#                 win[ns] = _LX;
#             }
#         })(window, document, 'LXAnalytics');
#
#         LXAnalytics('pageView', null, null);
#     </script>
# </head>
# <body id="top">
# <div id="app" server-rendered="true"><div id="legacy-detail-header"><div class="site-nav" id="site-nav"><div class="container"><div class="group user-action J-user-action"><a class="item" href="http://www.dianping.com/login" onclick="pageTracker._trackPageview('dp_head_login_wenzhou');" rel="nofollow">点评账号登录</a> <a class="item" href="http://www.dianping.com/thirdconnect?do=l&amp;ft=6&amp;redir=" onclick="pageTracker._trackPageview('dp_head_login_qq_wenzhou');" rel="nofollow">QQ登录</a> <a class="item" href="http://www.dianping.com/reg" onclick="pageTracker._trackPageview('dp_head_reg_wenzhou');" rel="nofollow">注册</a></div> <div class="group user-action" style="display:none"><a class="item J-user" href="http://www.dianping.com/member/undefined"><span></span> <i class="icon i-arrow"></i></a> <a class="item" href="http://www.dianping.com/logout" onclick="pageTracker._trackPageview('dp_head_esc_wenzhou');">退出</a> <a class="item left-split J-message" href="http://www.dianping.com/msg/private"><span>消息</span> <span class="count">0</span></a> <a class="item left-split J-my-center-trigger" href="http://www.dianping.com/member/myinfo"><span>个人中心</span> <i class="icon i-arrow"></i></a></div> <div class="panel my-center J-my-center Hide" style="top:35px;left:315.672px;width:80px"><a href="http://www.dianping.com/member/myinfo/setup/basic">我的设置</a> <a href="http://www.dianping.com/member/undefined/reviews">我的点评</a> <a href="http://www.dianping.com/member/undefined/groups">我的部落</a> <a href="http://www.dianping.com/member/undefined/wishlists">我的收藏</a> <a href="http://www.dianping.com/member/undefined/badge/dp">我的徽章</a> <a href="http://t.dianping.com/account/coupons" onclick="pageTracker._trackPageview('dp_head_mygroupon_wenzhou');">我的团购</a> <a href="http://waimai.dianping.com/mytakeaway" onclick="pageTracker._trackPageview('dp_head_mytakeaway');">我的外卖</a> <a href="http://www.dianping.com/hotel/order/list" onclick="pageTracker._trackPageview('dp_head_myhotel');">酒店订单</a></div> <div class="group quick-menu"><a class="item left-split" href="http://www.dianping.com/addreview/list" rel="nofollow">写点评</a> <a class="item left-split" href="http://www.dianping.com/addshop" rel="nofollow">添加商户</a> <a class="item left-split J-shop-center-trigger" rel="nofollow">商家中心<i class="icon i-arrow"></i></a> <a class="item left-split" href="//b.dianping.com" rel="nofollow">企业服务</a> <a class="item left-split J-dp-index-trigger" rel="nofollow">点评大数据<i class="icon i-arrow"></i></a> <a class="item left-split" href="http://www.dianping.com/events/m/index.htm" id="J_mobile-page" rel="nofollow"><i class="icon i-mobile"></i>手机版</a> <a class="item left-split" href="http://www.dianping.com/help" onclick="pageTracker._trackPageview('dp_head_help_wenzhou');" rel="nofollow">服务中心</a></div> <div class="panel my-center J-shop-center Hide" style="top:35px;left:766.5px;width:80px"><a href="//e.dianping.com" rel="nofollow" target="_blank">商户中心</a> <a href="//e.dianping.com/shopclaim/introduce/introducelogin" rel="nofollow" target="_blank">我想合作</a> <a href="//e.dianping.com/shopclaim/shopv" rel="nofollow" target="_blank">商户认证</a></div> <div class="panel my-center J-dp-index Hide" style="top:35px;left:912.5px;width:92px"><a href="http://dpindex.dianping.com/dpindex" rel="nofollow" target="_blank">人气指数</a> <a href="http://dpindex.dianping.com/dpindex?type=rank" rel="nofollow" target="_blank">商户风云榜</a> <a href="http://dpindex.dianping.com/maps" rel="nofollow" target="_blank">吃货地图</a></div> <div><div class="panel message J-message-list Hide" style="top:35px;left:243.562px;width:80px;display:none"><a href="http://www.dianping.com/msg/subscribe"><span>订阅</span> <strong>0</strong></a> <a class="ignore J-ignore">全部忽略</a></div></div> <div><div class="panel user-card J-user-card Hide" style="top:35px;left:112.5px;width:97px"><a class="avatar" href="http://www.dianping.com/member/undefined"><img/></a> <a class="setting" href="http://www.dianping.com/member/myinfo/setup/basic">个人设置</a> <p><a cla ...
#                         0</a> <a class="item" href="http://www.dianping.com/member/undefined/groups">帖子
#                         0</a> <a class="item" href="http://www.dianping.com/member/undefined/fans">粉丝
#                         0</a></p></div></div></div></div><div class="page-header" id="page-header"><div class="container"><div class="hotel-logo"><a class="dp-logo" href="http://www.dianping.com/dongguan"></a> <a class="dp-hotel-logo" href="http://www.dianping.com/dongguan"></a></div> <a class="city J-city"><span>东莞</span> <i class="icon i-arrow"></i></a> <div class="city-list J-city-list Hide"><div class="group clearfix"><h3 class="title">华北东北：</h3> <a href="http://www.dianping.com/beijing/hotel">北京</a> <a href="http://www.dianping.com/tianjin/hotel">天津</a> <a href="http://www.dianping.com/shenyang/hotel">沈阳</a> <a href="http://www.dianping.com/dalian/hotel">大连</a> <a href="http://www.dianping.com/changchun/hotel">长春</a> <a href="http://www.dianping.com/haerbin/hotel">哈尔滨</a> <a href="http://www.dianping.com/shijiazhuang/hotel">石家庄</a> <a href="http://www.dianping.com/taiyuan/hotel">太原</a> <a href="http://www.dianping.com/huhehaote/hotel">呼和浩特</a> <a href="http://www.dianping.com/langfang/hotel">廊坊</a></div> <div class="group clearfix"><h3 class="title">华东地区：</h3> <a href="http://www.dianping.com/shanghai/hotel">上海</a> <a href="http://www.dianping.com/hangzhou/hotel">杭州</a> <a href="http://www.dianping.com/nanjing/hotel">南京</a> <a href="http://www.dianping.com/suzhou/hotel">苏州</a> <a href="http://www.dianping.com/wuxi/hotel">无锡</a> <a href="http://www.dianping.com/jinan/hotel">济南</a> <a href="http://www.dianping.com/xiamen/hotel">厦门</a> <a href="http://www.dianping.com/ningbo/hotel">宁波</a> <a href="http://www.dianping.com/fuzhou/hotel">福州</a> <a href="http://www.dianping.com/qingdao/hotel">青岛</a> <a href="http://www.dianping.com/hefei/hotel">合肥</a> <a href="http://www.dianping.com/changzhou/hotel">常州</a> <a href="http://www.dianping.com/yangzhou/hotel">扬州</a> <a href="http://www.dianping.com/wenzhou/hotel">温州</a> <a href="http://www.dianping.com/shaoxing/hotel">绍兴</a> <a href="http://www.dianping.com/jiaxing/hotel">嘉兴</a> <a href="http://www.dianping.com/yantai/hotel">烟台</a> <a href="http://www.dianping.com/weihai/hotel">威海</a> <a href="http://www.dianping.com/zhenjiang/hotel">镇江</a> <a href="http://www.dianping.com/nantong/hotel">南通</a> <a href="http://www.dianping.com/jinhua/hotel">金华</a> <a href="http://www.dianping.com/xuzhou/hotel">徐州</a> <a href="http://www.dianping.com/weifang/hotel">潍坊</a> <a href="http://www.dianping.com/zibo/hotel">淄博</a> <a href="http://www.dianping.com/linyi/hotel">临沂</a> <a href="http://www.dianping.com/maanshan/hotel">马鞍山</a> <a href="http://www.dianping.com/zhejiangtaizhou/hotel">台州</a> <a href="http://www.dianping.com/taizhou/hotel">泰州</a> <a href="http://www.dianping.com/jining/hotel">济宁</a> <a href="http://www.dianping.com/taian/hotel">泰安</a></div> <div class="group clearfix"><h3 class="title">中部西部：</h3> <a href="http://www.dianping.com/chengdu/hotel">成都</a> <a href="http://www.dianping.com/wuhan/hotel">武汉</a> <a href="http://www.dianping.com/zhengzhou/hotel">郑州</a> <a href="http://www.dianping.com/changsha/hotel">长沙</a> <a href="http://www.dianping.com/nanchang/hotel">南昌</a> <a href="http://www.dianping.com/guiyang/hotel">贵阳</a> <a href="http://www.dianping.com/xining/hotel">西宁</a> <a href="http://www.dianping.com/chongqing/hotel">重庆</a> <a href="http://www.dianping.com/xian/hotel">西安</a> <a href="http://www.dianping.com/kunming/hotel">昆明</a> <a href="http://www.dianping.com/lanzhou/hotel">兰州</a> <a href="http://www.dianping.com/wulumuqi/hotel">乌鲁木齐</a> <a href="http://www.dianping.com/yinchuan/hotel">银川</a></div> <div class="group clearfix"><h3 class="title">华南地区：</h3> <a href="http://www.dianping.com/guangzhou/hotel">广州</a> <a href="http://www.dianping.com/shenzhen/hotel">深圳</a> <a href="http://www.dianping.com/foshan/hotel">佛山</a> <a href="http://www.dianping.com/zhuhai/hotel">珠海</a> <a href="http://www.dianping.com/dongguan/hotel">东莞</a> <a href="http://www.dianping.com/sanya/hotel">三亚</a> <a href="http://www.dianping.com/haikou/hotel">海口</a> <a href="http://www.dianping.com/nanning/hot ...
#             雁田</a></span> <span><span> &gt; </span> <a class="dp-link" href="//www.dianping.com/dongguan/hotel/g3022">四星级/高档型</a> <span> &gt; </span></span><span><span> &gt; </span> <a class="dp-link" href="//www.dianping.com/dongguan/hotel/g3026">高档型</a> <span> &gt; </span></span> <h2 class="crumb-title"><span>东莞龙门阁酒店</span></h2></div><div class="container"><div class="base-info"><!-- --> <div class="main-detail clearfix"><div class="main-detail-left"><div class="main-detail-left-top clearfix"><div class="hotel-detail-info" itemtype="http://schema.org/Hotel"><div class="hotel-title clearfix"><h1 itemprop="name">东莞龙门阁酒店</h1> <!-- --> <!-- --> <div class="hotel-price invisible"><span>¥<strong></strong></span>起
#                     </div></div></div> <div class="hotel-detail-price"><div class="hotel-address-box clearfix" itemprop="address" itemscope="itemscope" itemtype="http://schema.org/PostalAddress"><span class="hotel-address">地址：小捷滘捷东南路1号</span> <span class="hotel-metro"></span></div> <div class="hotel-detail-operation"><div class="report-error operation"><svg height="22px" version="1.1" viewbox="0 0 22 22" width="22px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><desc></desc> <defs></defs> <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g fill="#ACACAC" id="content"><g id="报错" transform="translate(0.000000, 1.000000)"><path d="M9.96592927,16.2475924 L12.0511729,16.2475924 L12.0511729,14.1508165 L9.96592927,14.1508165 L9.96592927,16.2475924 Z M9.96592927,13.1019043 L12.0511729,13.1019043 L12.0511729,7.85944034 L9.96592927,7.85944034 L9.96592927,13.1019043 Z M19.4050903,17.8013034 L2.59471353,17.8013034 C2.37717302,17.8013034 2.22201161,17.7750937 2.12241475,17.7483598 C2.14914864,17.6471903 2.20418901,17.4988434 2.31269716,17.3080368 L10.7181476,2.58133116 C10.82718,2.39104874 10.9267768,2.26786316 10.9996398,2.194476 C11.073027,2.26786316 11.1726238,2.39104874 11.281132,2.58133116 L19.6865824,17.3080368 C19.7956148,17.4988434 19.8506552,17.6471903 19.8773891,17.7483598 C19.7777922,17.7750937 19.6226308,17.8013034 19.4050903,17.8013034 L19.4050903,17.8013034 Z M21.5065839,16.2454956 L13.1011335,1.51878996 C12.5234717,0.506047191 11.7618178,0.0002 10.9996398,0.0002 C10.2379859,0.0002 9.4763321,0.506047191 8.89867033,1.51878996 L0.493219859,16.2454956 C-0.662627868,18.270457 0.283018073,19.92691 2.59471353,19.92691 L19.4050903,19.92691 C21.7167857,19.92691 22.6624317,18.270457 21.5065839,16.2454956 L21.5065839,16.2454956 Z" id="Fill-1"></path></g></g></g></svg></div> <div class="add-favorite operation"><svg height="22px" version="1.1" viewbox="0 0 22 22" width="22px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><desc></desc> <defs></defs> <g fill="none" fill-rule="evenodd" stroke="none" stroke-linecap="round" stroke-linejoin="round" stroke-width="1"><g id="content" stroke="#ACACAC" stroke-width="2"><g id="收藏" transform="translate(1.000000, 1.000000)"><path d="M19.561472,8.7527346 C19.9424603,8.38753303 20.0871728,7.90603527 19.9482488,7.46453077 C19.8093249,7.02302627 19.4199169,6.72518176 18.9094766,6.66834924 L13.5409082,6.13949105 C13.4667102,6.12738783 13.315683,6.01424901 13.2798996,5.94110345 L11.0755345,0.783552085 C10.8624125,0.293634697 10.4698471,0 10.0262377,0 C9.58157587,0 9.18953671,0.293634697 8.9753623,0.785656993 L6.72047937,5.94005099 C6.68574838,6.01161787 6.53419499,6.12738783 6.45526093,6.14001728 L1.09511215,6.66782301 C0.580462094,6.72465553 0.191054074,7.02302627 0.052130131,7.46453077 C-0.0873200385,7.90603527 0.0568661745,8.38753303 0.438380789,8.7527346 L4.42349828,12.6531295 C4.48085702,12.7125932 4.54084691,12.9094021 4.52926991,12.9878099 L3.44471595,18.4568877 C3.33262959,19.0215294 3.50417961,19.4635601 3.63257901,19.6282691 C3.96620696,20.0560917 4.59873188,20.096085 5.14021952,19.7787701 L9.83100749,17.0144994 C9.8583713,16.9992388 10.1399028,16.9987126 10.1704239,17.0150256 L14.8601595,19.7777176 C15.1432696,19.9450578 15.8505188,20.2018566 16.3409624,19.5740678 C16.4693618,19.4109374 16.6672232,19.0520505 16.5582942,18.4942498 L15.4853172,12.7578487 C15.4926844,12.744693 15.5153121,12.7125932 15.575302,12.6552344 L19.561472,8.7527346 Z" id="Fill-1"></path></g></g></g></svg></div> <div class="upload-pic operation"><svg height="22px" version="1.1" viewbox="0 0 22 22" width="22px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><desc></desc> <defs></defs> <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g id="content" stroke="#ACACAC" stroke-width="2"><g id="传照片" transform="translate(1.000000, 3.000000)"><path d="M5.96582031,15 L3.00089496,15 C1.34354644,15 0,13.655649 ...
#                 </div> <div class="hotel-scope-more"><span class="mid-rank-stars mid-str35"></span></div> <div class="hotel-all-appraise"><a href="#comment"><span>查看全部点评</span> <span class="hotel-scope-title" itemprop="reviewCount">(6)</span></a></div></div> <div id="hotel-map"></div></div></div> <!-- --> <div class="full-map-overlay" style="display:none"></div> <div class="full-map" style="display:none"><div class="full-map-header"><div class="title">东莞龙门阁酒店</div> <div class="close-btn"><img alt="" src="data:image/svg+xml;base64,..."/></div></div> <div class="info"><span class="name">地址：</span> <span class="value">小捷滘捷东南路1号</span></div> <div class="info"><span class="name">交通：</span> <span class="value"></span></div> <div class="full-map-container"></div> <div class="full-map-footer"><span class="notice">注：地图位置标注仅供参考，具体情况以实际道路标实信息为准</span></div></div></div><div class="deal-info" id="deal"><div class="hotel-rooms"><div class="clearfix hotel-rooms-head"><ul><li><a>房型预订</a></li> <li><a>酒店信息</a></li> <li><a>位置交通</a></li> <li><a>网友点评</a></li></ul></div> <div class="hotel-rooms-control" id="hotel-rooms-control"><div class="dp-container checkin"><label class="dp-label"> 入住 </label><input class="dp-input" readonly="readonly" value="2017-11-06"/><span class="weekinfo"></span><div class="calendar" style="display:none"><div class="cal-header"><a class="cal-nav-pre-m prev" href="javascript:void(0)"></a><span class="cal-input-wrapper"><input class="dp-input change-year" maxlength="4" name="current-year" readonly="readonly" type="text" value="2017"/>年<input class="dp-input change-month" maxlength="2" name="current-month" readonly="readonly" type="text" value="11"/>月</span><a class="cal-nav-next-m next" href="javascript:void(0)"></a></div><table><thead><tr class="datepicker-weekday"><th>日</th><th>一</th><th>二</th><th>三</th><th>四</th><th>五</th><th>六</th></tr></thead><tbody><tr><td class="cal-day pre" data-day="29">29</td><td class="cal-day pre" data-day="30">30</td><td class="cal-day pre" data-day="31">31</td><td class="cal-day cur" data-day="1">1</td><td class="cal-day cur" data-day="2">2</td><td class="cal-day cur" data-day="3">3</td><td class="cal-day cur" data-day="4">4</td></tr><tr><td class="cal-day cur" data-day="5">5</td><td class="cal-day cur selectable today selected" data-day="6">6</td><td class="cal-day cur selectable" data-day="7">7</td><td class="cal-day cur selectable" data-day="8">8</td><td class="cal-day cur selectable" data-day="9">9</td><td class="cal-day cur selectable" data-day="10">10</td><td class="cal-day cur selectable" data-day="11">11</td></tr><tr><td class="cal-day cur selectable" data-day="12">12</td><td class="cal-day cur selectable" data-day="13">13</td><td class="cal-day cur selectable" data-day="14">14</td><td class="cal-day cur selectable" data-day="15">15</td><td class="cal-day cur selectable" data-day="16">16</td><td class="cal-day cur selectable" data-day="17">17</td><td class="cal-day cur selectable" data-day="18">18</td></tr><tr><td class="cal-day cur selectable" data-day="19">19</td><td class="cal-day cur selectable" data-day="20">20</td><td class="cal-day cur selectable" data-day="21">21</td><td class="cal-day cur selectable" data-day="22">22</td><td class="cal-day cur selectable" data-day="23">23</td><td class="cal-day cur selectable" data-day="24">24</td><td class="cal-day cur selectable" data-day="25">25</td></tr><tr><td class="cal-day cur selectable" data-day="26">26</td><td class="cal-day cur selectable" data-day="27">27</td><td class="cal-day cur selectable" data-day="28">28</td><td class="cal-day cur selectable" data-day="29">29</td><td class="cal-day cur selectable" data-day="30">30</td><td class="cal-day next" data-day="1">1</td><td class="cal-day next" data-day="2">2</td></tr><tr><td class="cal-day next" data-day="3">3</td><td class="cal-day next" data-day="4">4</td><td class="cal-day next" data-day="5">5</td><td class="cal-day next" data-day="6">6</td><td class="cal-day next" data-day="7">7< ...
#                     19.8km</p><p>常平火车站
#                     38.9km</p><p>东莞东站
#                     38.8km</p><p>东莞火车站
#                     36.5km</p></div></li> <li style="display:none"><div class="info-key">热门景点：</div> <div class="info-value"></div></li></ul></div> <div class="user-comment-info"><!-- --> <div id="comment"><!-- --> <!-- --> <div><h2><a class="sub-title active"><span>网友点评</span> <span class="count">(6)</span></a> <span class="star-control"><a class="dp-link active" data-filter="all">全部</a> <a class="dp-link" data-filter="50"><span>5星</span> <span class="count">(2)</span></a> <a class="dp-link" data-filter="40"><span>4星</span> <span class="count">(2)</span></a> <a class="dp-link" data-filter="30"><span>3星</span> <span class="count">(0)</span></a> <a class="dp-link" data-filter="20"><span>2星</span> <span class="count">(1)</span></a> <a class="dp-link" data-filter="10"><span>1星</span> <span class="count">(1)</span></a></span></h2> <div class="comment-filter"><div class="search"><input placeholder="搜索评论" type="text" value=""/> <img class="search-btn" src="data:image/svg+xml;base64,..."/></div> <div class="filter"><!-- --> <div class="filter-item dp-link"><input class="checkbox" id="pic" type="checkbox"/> <label class="filter-item" for="pic">有图片<span class="count">(1)</span></label></div></div></div> <div class="comment"><ul><li><div class="comment-item"><a class="avatar"><img/></a> <div class="user-info"><span class="name dp-link">咕咕叽咕叽～</span> <span class="user-rank"></span></div> <div class="star-info"><span class="sml-rank-stars sml-str40"></span> <span class="score-list"><span>位置:</span><span>2</span></span><span class="score-list"><span>服务:</span><span>2</span></span><span class="score-list"><span>卫生:</span><span>2</span></span><span class="score-list"><span>设施:</span><span>2</span></span></div> <div class="comment-content"><p class="desc height">[早餐]超级想念广东早茶的。吃的非常非常饱。因为觉得好吃。看来去了武汉以后任何广东菜都觉得好吃。
# 环境:龙门阁二楼，比较大
# 服务:正常，但我们坐的地方比较远，很难叫人
# 口味:仔细想想属于还可以的范围
# #虾饺:里面有四五只大虾，皮也够韧
# #豉油排骨:好嫩啊
# #豉油凤爪:我天生喜欢这个，只要是凤爪都好吃
# #流沙包:个头大，刚咬开汁不多，其实越吃越好，不会很腻
# #牛肉丸、猪血:无功无过
# #肠粉:料比较少
# #粥:料挺多的，推荐艇仔粥
#         </p> <div class="get-more dp-link"><span>更多</span> <img alt="" class="arrow-down" src="data:image/svg+xml;base64,..."/></div></div> <div class="photos"><ul><li><img/></li><li><img/></li><li><img/></li><li><img/></li><li><img/></li></ul> <div class="check-all-pic"><span class="dp-link">查看全部14张</span></div></div> <div class="misc-info"><ul class="info"><li class="time">2017-10-02 11:16</li> <li class="shop">东莞龙门阁酒店</li></ul> <ul class="actions"><!-- --> <li class="action dp-link"><span>赞</span> <!-- --></li> <li class="action dp-link"><span>回应</span> <!-- --></li> <li class="action dp-link">收藏</li> <li class="action dp-link">举报</li></ul></div> <!-- --></div></li><li><div class="comment-item"><a class="avatar"><img/></a> <div class="user-info"><span class="name dp-link">蜗牛_129259</span> <span class="user-rank"></span></div> <div class="star-info"><span class="sml-rank-stars sml-str40"></span> <span class="score-list"><span>位置:</span><span>2</span></span><span class="score-list"><span>服务:</span><span>2</span></span><span class="score-list"><span>卫生:</span><span>3</span></span><span class="score-list"><span>设施:</span><span>2</span></span></div> <div class="comment-content"><p class="desc height">早餐券居然是现金券，吃个早餐自己还得贴钱，味道不好还贵。
#         </p> <div class="get-more dp-link"><span>更多</span> <img alt="" class="arrow-down" src="data:image/svg+xml;base64,..."/></div></div> <!-- --> <div class="misc-info"><ul class="info"><li class="time">2017-07-01 11:39</li> <li class="shop">东莞龙门阁酒店</li></ul> <ul class="actions"><!-- --> <li class="action dp-link"><span>赞</span> <!-- --></li> <li class="action dp-link"><span>回应</span> <!-- --></li> <li class="action dp-link">收藏</li> <li class="action dp-link">举报</li></ul></div> <!-- --></div></li><li><div class="comment-item"><a class="avatar"><img/></a> <div class="user-info"><span class="name dp-link">dpuser_5370320576</span> <span class="user-rank"></span></div> <div class="star-info"><span class="sml-rank-stars sml-str20"></span> <span class="score-list"><span>房间:</span><span>0</span></span><span class="score-list"><span>位置:</span><span>2</span></span><span class="score-list"><span>服务:</span><span>0</span></span></div> <div class="comment-content"><p class="desc height">没有WiFi，不干净，洗澡水往外流。电视台比较少。抽风机很吵，电话坏的，灯也坏的。
#         </p> <div class="get-more dp-link"><span>更多</span> <img alt="" class="arrow-down" src="data:image/svg+xml;base64,..."/></div></div> <!-- --> <div class="misc-info"><ul class="info"><li class="time">2016-11-04 09:59</li> <li class="shop">东莞龙门阁酒店</li></ul> <ul class="actions"><!-- --> <li class="action dp-link"><span>赞</span> <!-- --></li> <li class="action dp-link"><span>回应</span> <!-- --></li> <li class="action dp-link">收藏</li> <li class="action dp-link">举报</li></ul></div> <!-- --></div></li><li><div class="comment-item"><a class="avatar"><img/></a> <div class="user-info"><span class="name dp-link">紫嫣_9260</span> <span class="user-rank"></span></div> <div class="star-info"><span class="sml-rank-stars sml-str50"></span> <span class="score-list"><span>房间:</span><span>4</span></span><span class="score-list"><span>位置:</span><span>4</span></span><span class="score-list"><span>服务:</span><span>4</span></span></div> <div class="comment-content"><p class="desc height">方便快捷，服务好，房间干净整洁，停车方便，只是吃东西不太方便！
#         </p> <div class="get-more dp-link"><span>更多</span> <img alt="" class="arrow-down" src="data:image/svg+xml;base64,..."/></div></div> <!-- --> <div class="misc-info"><ul class="info"><li class="time">2016-08-05 20:18</li> <li class="shop">东莞龙门阁酒店</li></ul> <ul class="actions"><!-- --> <li class="action dp-link"><span>赞</span> <!-- --></li> <li class="action dp-link"><span>回应</span> <span>(1)</span></li> <li class="action dp-link">收藏</li> <li class="action dp-link">举报</li></ul></div> <!-- --></div></li><li><div class="comment-item"><a class="avatar"><img/></a> <div class="user-info"><span class="name dp-link">小丁哥样样</span> <span class="user-rank"></span></div> <div class="star-info"><span class="sml-rank-stars sml-str50"></span> <span class="score-list"><span>房间:</span><span>4</span></span><span class="score-list"><span>位置:</span><span>4</span></span><span class="score-list"><span>服务:</span><span>4</span></span></div> <div class="comment-content"><p class="desc height">帮朋友订的，据说还是比较满意的，我先去买票价值不值班主任您好啊哈哈大笑三声
#         </p> <div class="get-more dp-link"><span>更多</span> <img alt="" class="arrow-down" src="data:image/svg+xml;base64,..."/></div></div> <!-- --> <div class="misc-info"><ul class="info"><li class="time">2015-09-06 20:24</li> <li class="shop">东莞龙门阁酒店</li></ul> <ul class="actions"><!-- --> <li class="action dp-link"><span>赞</span> <!-- --></li> <li class="action dp-link"><span>回应</span> <!-- --></li> <li class="action dp-link">收藏</li> <li class="action dp-link">举报</li></ul></div> <!-- --></div></li><li><div class="comment-item"><a class="avatar"><img/></a> <div class="user-info"><span class="name dp-link">一个人的时光_3348</span> <span class="user-rank"></span></div> <div class="star-info"><span class="sml-rank-stars sml-str10"></span> <span class="score-list"><span>房间:</span><span>0</span></span><span class="score-list"><span>服务:</span><span>0</span></span></div> <div class="comment-content"><p class="desc height">服务太差了！一晚上没一个业务进房，生日房
#         </p> <div class="get-more dp-link"><span>更多</span> <img alt="" class="arrow-down" src="data:image/svg+xml;base64,..."/></div></div> <!-- --> <div class="misc-info"><ul class="info"><li class="time">2016-10-09 23:43</li> <li class="shop">东莞龙门阁酒店</li></ul> <ul class="actions"><!-- --> <li class="action dp-link"><span>赞</span> <!-- --></li> <li class="action dp-link"><span>回应</span> <!-- --></li> <li class="action dp-link">收藏</li> <li class="action dp-link">举报</li></ul></div> <!-- --></div></li></ul> <div class="more-comment"><a class="dp-link"><span>更多点评</span> <span class="count">(6)</span></a></div> <div class="dp-dialog" style="display:none"><div class="dp-dialog-overlay"></div> <div class="dp-dialog-body"><div class="dp-dialog-header"><!-- --> <!-- --> <div class="dp-dialog-title">删除收藏</div> <img alt="" class="dp-dialog-close-btn" src="data:image/svg+xml;base64,..."/></div> <div class="dp-dialog-content"><!-- --> <!-- --></div> <div class="dp-dialog-footer "><button class="cancel-btn">取消</button> <button class="submit-btn"><span>删除</span></button></div></div></div></div></div></div></div> <div class="nearby-info"><h2><!-- --> <!-- --> <!-- --> <!-- --></h2> <div class="nearby-container"></div></div> <div class="ugcinfo"><div><em>会员贡献：</em> <a class="dp-link" href="/member/-26176" rel="nofollow" target="_blank">陈美丽</a> <span>添加商户 | 系统在16-07-19最后更新</span></div> <div>
#         东莞龙门阁酒店共774人浏览，最近一周12人浏览，共5人收藏。
#         <a class="dp-link" href="/shopsitemap/219_60_A_1" rel="nofollow" target="_blank" title="">查看更多商户</a></div></div> <div class="seo-nav-info" data-v-79573858=""><dl class="introduce" data-v-79573858=""><dt data-v-79573858="">酒店介绍：</dt> <dd class="desc" data-v-79573858="">为您推荐东莞龙门阁酒店以及酒店预订、价格查询、酒店评论，东莞龙门阁酒店信息，酒店地址：小捷滘捷东南路1号; 涵盖酒店周边设施，酒店交通地图，真实用户点评等信息。 上海酒店预订，酒店团购，特价酒店，选点评更放心！</dd></dl> <dl class="nearyByShops" data-v-79573858=""><dt data-v-79573858="">附近酒店：</dt> <dd class="desc" data-v-79573858=""><ul data-v-79573858=""><li class="shop-item" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/shop/58576709">东莞龙泉国际大酒店</a></li><li class="shop-item" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/shop/21096712">金银岛国际大酒店</a></li><li class="shop-item" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/shop/5183670">富莱酒店</a></li><li class="shop-item" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/shop/51003623">东莞虎门东方锦河大饭店</a></li><li class="shop-item hide" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/shop/5153442">东莞明苑大酒店</a></li><li class="shop-item hide" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/shop/8871713">家迎连锁酒店(长安店)</a></li><li class="shop-item hide" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/shop/12162837">威尔曼酒店</a></li><li class="shop-item hide" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/shop/5151340">美思威尔顿酒店</a></li><li class="shop-item hide" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/shop/4684915">7天连锁酒店(黄河时装城店)</a></li><li class="shop-item hide" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/shop/90321665">东莞银泰酒店</a></li> <li class="toggle more" data-v-79573858=""><span data-v-79573858="">更多</span> <i data-v-79573858=""></i></li></ul></dd></dl> <dl class="hotRegion" data-v-79573858=""><dt data-v-79573858="">热门商圈：</dt> <dd class="desc" data-v-79573858=""><ul data-v-79573858=""><li class="region-item" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/dongguan/hotel/r27028" title="东城万达​广场酒店预订">东城万达​广场酒店预订</a></li><li class="region-item" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/dongguan/hotel/r6157" title="第一国际酒店预订">第一国际酒店预订</a></li><li class="region-item" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/dongguan/hotel/r8811" title="星河城/十三碗酒店预订">星河城/十三碗酒店预订</a></li><li class="region-item" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/dongguan/hotel/r23550" title="汇一城酒店预订">汇一城酒店预订</a></li><li class="region-item hide" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/dongguan/hotel/r8807" title="雍华庭酒店预订">雍华庭酒店预订</a></li><li class="region-item hide" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/dongguan/hotel/r9300" title="华南摩尔酒店预订">华南摩尔酒店预订</a></li> <li class="toggle more" data-v-79573858=""><span data-v-79573858="">更多</span> <i data-v-79573858=""></i></li></ul></dd></dl> <dl class="hotCities" data-v-79573858=""><dt data-v-79573858="">热门城市：</dt> <dd class="desc" data-v-79573858=""><ul data-v-79573858=""><li class="city-item" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/shanghai/hotel/" title="上海酒店预订">上海酒店预订</a></li><li class="city-item" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/beijing/hotel/" title="北京酒店预订">北京酒店预订</a></li><li class="city-item" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/guangzhou/hotel/" title="广州酒店预订">广州酒店预订</a></li><li class="city-item" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/shenzhen/hotel/" title="深圳酒店预订">深圳酒店预订</a></li><li class="city-item hide" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/wuhan/hotel/" title="武汉酒店预订">武汉酒店预订</a></li><li class="city-item hide" data-v-79573858=""><a data-v-79573858="" href="//www.dianping.com/tianjin/hotel/" title="天津酒店预订">天津酒店预订</a></li><li class=" ...
# <div class="footer" id="footer">
# <p class="links">
# <a href="http://www.dianping.com/aboutus" rel="nofollow" target="_blank">关于大众点评</a>|
#         <a href="http://s.dianping.com/topic/2815561" rel="nofollow" target="_blank">诚信公约</a>|
#         <a href="http://www.dianping.com/help" rel="nofollow" target="_blank">网站帮助</a>|
#         <a href="http://www.dianping.com/business/" rel="nofollow" target="_blank">推广服务</a>|
#         <a href="http://www.dianping.com/aboutus/media" rel="nofollow" target="_blank">媒体报道</a>|
#         <a href="http://careers.dianping.com" rel="nofollow" target="_blank">人才招聘</a>|
#         <a href="http://www.dianping.com/forum" rel="nofollow" target="_blank">站务论坛</a>|
#         <a href="http://www.dianping.com/contactus" rel="nofollow" target="_blank">联系我们</a>|
#         <a href="http://developer.dianping.com" rel="nofollow" target="_blank">开发者</a>|
#         <a class="J-tuan" href="javascript:;" onclick="return false;">点评团</a>
# </p>
# <p class="rights">©2003-2015 dianping.com, All Rights Reserved.　　本站发布的所有内容，未经许可，不得转载，详见<a href="http://www.dianping.com/aboutus/zhishichanquan.html" rel="nofollow">《知识产权声明》</a>。</p>
# </div>
# <script id="neuron-js" src="//www.dpfile.com/mod/neuron/7.1.4/neuron.js"></script>
# <script>neuron.config({
#     path: "//www.dpfile.com/mod",
#     loaded: ["app-midas@0.6.9/js/mkt.js", "app-main-hotelshop@1.0.47", "app-main-hotel-search-bar@1.0.1", "hippo@1.2.23", "app-main-hotelheader@1.0.0", "app-main-hotelshop-comment@1.0.0", "css-reset@1.0.0", "app-main-header@1.4.0", "json@1.0.1", "util@1.0.5", "clone@0.1.13", "events@1.0.5", "underscore@1.5.3", "jquery@1.9.2", "hexrgb@0.0.1", "lang@1.0.1", "class@2.0.5", "asset@1.0.2", "lang@1.0.0", "attributes@1.4.1", "fx@2.0.0", "mix@1.0.1", "easy-login@0.4.13", "request@0.2.7", "mbox@1.0.3", "cookie@0.1.2", "placeholder@0.1.1", "event-transfer@0.1.0", "tpl@0.2.1", "mbox@1.0.1", "request@0.2.6", "hippo@1.2.22", "switch@0.1.0", "css-shop-tag@0.1.3", "midas-log@0.0.0", "main-authbox@1.0.4", "main-datepicker@1.0.1", "storage@0.2.4", "event-transfer@1.0.0", "page-event-transfer@1.0.0", "css-rating@1.0.1", "shop-alert@1.0.0", "request@1.0.1", "main-datepicker@1.0.0", "css-rating@1.0.0", "shop-confirm@1.0.0", "main-authbox@1.0.0", "request@1.0.7", "storage@0.1.2", "suggest@1.0.1"],
#     graph: {
#         "0": ["1.0.0"],
#         "1": ["1.4.0", {
#             "storage@~0.1.0": 2,
#             "placeholder@~0.1.1": 5,
#             "hippo@^1.2.13": 7,
#             "tpl@~0.2.1": 8,
#             "event-transfer@~0.1.0": 9,
#             "request@^1.0.7": 15,
#             "class@^2.0.5": 10,
#             "suggest@~1.0.0": 17,
#             "jquery@~1.9.2": 6
#         }],
#         "2": ["0.1.2", {"json@~1.0.0": 3, "lang@~1.0.0": 4}],
#         "3": ["1.0.1"],
#         "4": ["1.0.1"],
#         "5": ["0.1.1", {"jquery@~1.9.2": 6}],
#         "6": ["1.9.2"],
#         "7": ["1.2.22"],
#         "8": ["0.2.1"],
#         "9": ["0.1.0", {"class@~2.0.5": 10}],
#         "10": ["2.0.5", {"util@~1.0.0": 11, "clone@~0.1.11": 12, "events@~1.0.0": 13, "underscore@~1.5.2": 14}],
#         "11": ["1.0.5", {"json@~1.0.0": 3}],
#         "12": ["0.1.13", {"util@~1.0.2": 11}],
#         "13": ["1.0.5", {"util@~1.0.0": 11}],
#         "14": ["1.5.3"],
#         "15": ["1.0.7", {"json@~1.0.0": 3, "lang@~1.0.0": 4, "class@~2.0.0": 10, "asset@~1.0.0": 16}],
#         "16": ["1.0.2"],
#         "17": ["1.0.1", {"class@~2.0.0": 10, "jquery@~1.9.2": 6}],
#         "18": ["1.0.0", {
#             "placeholder@~0.1.1": 5,
#             "tpl@~0.2.1": 8,
#             "mbox@~1.0.1": 19,
#             "shop-alert@~1.0.0": 21,
#             "json@~1.0.1": 3,
#             "main-authbox@~1.0.0": 22,
#             "request@~0.2.4": 24,
#             "css-rating@~1.0.0": 25,
#             "shop-confirm@~1.0.0": 26,
#             "jquery@~1.9.2": 6
#         }],
#         "19": ["1.0.1", {"class@~2.0.5": 10, "lang@~1.0.0": 20, "jquery@~1.9.2": 6}],
#         "20": ["1.0.0"],
#         "21": ["1.0.0", {"tpl@~0.2.1": 8, "mbox@~1.0.1": 19, "jquery@~1.9.2": 6}],
#         "22": ["1.0.0", {
#             "placeholder@~0.1.1": 5,
#             "mbox@~1.0.1": 19,
#             "cookie@~0.1.0": 23,
#             "request@~0.2.4": 24,
#             "jquery@~1.9.2": 6
#         }],
#         "23": ["0.1.2"],
#         "24": ["0.2.6", {"json@~1.0.0": 3, "lang@~1.0.0": 20, "class@~2.0.0": 10, "asset@~1.0.0": 16}],
#         "25": ["1.0.0"],
#         "26": ["1.0.0", {"tpl@~0.2.1": 8, "mbox@^1.0.1": 19, "jquery@~1.9.2": 6}],
#         "27": ["0.6.9", {
#             "css-shop-tag@~0.1.0": 28,
#             "tpl@~0.2.1": 8,
#             "switch@~0.1.0": 29,
#             "midas-log@~0.0.0": 34,
#             "json@~1.0.1": 3,
#             "hippo@~1.2.2": 7,
#             "fx@^2.0.0": 31,
#             "request@~0.2.4": 35,
#             "jquery@~1.9.2": 6
#         }],
#         "28": ["0.1.3"],
#         "29": ["0.1.0", {
#             "util@~1.0.4": 11,
#             "clone@~0.1.12": 12,
#             "mix@~1.0.1": 30,
#             "fx@~2.0.0": 31,
#             "attributes@~1.4.0": 33,
#             "events@~1.0.5": 13,
#             "underscore@~1.5.3": 14,
#             "jquery@~1.9.2": 6
#         }],
#         "30": ["1.0.1"],
#         "31": ["2.0.0", {
#             "util@~1.0.4": 11,
#             "lang@~1.0.0": 4,
#             "hexrgb@~0.0.1": 32,
#             "events@~1.0.5": 13,
#             "jquery@~1.9.2": 6
#         }],
#         "32": ["0.0.1"],
#         "33": ["1.4.1", {"clone@~0.1.11": 12, "util@~1.0.0": 11}],
#         "34": ["0.0.0", {"jquery@^1.9.2": 6}],
#         "35": ["0.2.7", {"json@~1.0.0": 3, "lang@~1.0.0": 4, "class@~2.0.0": 10, "asset@~1.0.0": 16}],
#         "36": ["1.0.1", {
#             "main-datepicker@~1.0.0": 37,
#             "request@~1.0.0": 38,
#             "class@~2.0.5": 10,
#             "storage@~0.2.4": 39,
#             "lang@~1.0.0": 20,
#             "jquery@~1.9.2": 6,
#             "cookie@~0.1.2": 23
#         }],
#         "37": ["1.0.0", {"class@~2.0.5": 10, "lang@~1.0.0": 20, "jquery@~1.9.2": 6}],
#         "38": ["1.0.1", {"json@~1.0.0": 3, "lang@~1.0.0": 20, "class@~2.0.0": 10, "asset@~1.0.0": 16}],
#         "39": ["0.2.4", {"json@~1.0.0": 3, "underscore@~1.5.3": 14}],
#         "40": ["1.0.47", {
#             "main-datepicker@~1.0.0": 41,
#             "tpl@~0.2.1": 8,
#             "switch@~0.1.0": 29,
#             "cookie@~0.1.0": 23,
#             "storage@~0.2.4": 39,
#             "request@~0.2.4": 35,
#             "page-event-transfer@~1.0.0": 42,
#             "mbox@~1.0.1": 43,
#             "shop-alert@~1.0.0": 44,
#             "class@~2.0.5": 10,
#             "event-transfer@~1.0.0": 45,
#             "main-authbox@~1.0.0": 46,
#             "fx@~2.0.0": 31,
#             "lang@~1.0.0": 4,
#             "css-rating@~1.0.0": 48,
#             "jquery@~1.9.2": 6,
#             "app-hotelshop-full-map@~1.0.0": 49
#         }],
#         "41": ["1.0.1", {"class@~2.0.5": 10, "lang@~1.0.0": 4, "jquery@~1.9.2": 6}],
#         "42": ["1.0.0", {"event-transfer@~0.1.0": 9}],
#         "43": ["1.0.3", {"class@~2.0.5": 10, "lang@~1.0.0": 4, "jquery@~1.9.2": 6}],
#         "44": ["1.0.0", {"tpl@~0.2.1": 8, "mbox@~1.0.1": 43, "jquery@~1.9.2": 6}],
#         "45": ["1.0.0", {"class@~2.0.5": 10}],
#         "46": ["1.0.4", {
#             "placeholder@~0.1.1": 5,
#             "mbox@~1.0.1": 43,
#             "easy-login@~0.4.0": 47,
#             "cookie@~0.1.0": 23,
#             "request@~0.2.4": 35,
#             "jquery@~1.9.2": 6
#         }],
#         "47": ["0.4.13"],
#         "48": ["1.0.1"],
#         "49": ["1.0.0", {
#             "placeholder@~0.1.1": 5,
#             "map-iframe-dp@~1.0.0": 50,
#             "tpl@~0.2.1": 8,
#             "mbox@~1.0.1": 43,
#             "json@~1.0.1": 3,
#             "shop-alert@~1.0.0": 44,
#             "main-authbox@~1.0.0": 46,
#             "request@~0.2.4": 35,
#             "jquery@~1.9.2": 6
#         }],
#         "50": ["1.0.0", {"jquery@~1.9.2": 6}],
#         "51": ["1.0.0", {
#             "main-datepicker@~1.0.0": 37,
#             "request@~1.0.0": 38,
#             "class@~2.0.5": 10,
#             "storage@~0.2.4": 39,
#             "lang@~1.0.0": 20,
#             "jquery@~1.9.2": 6,
#             "cookie@~0.1.2": 23
#         }],
#         "52": ["1.2.23"],
#         "_": {
#             "css-reset@*": 0,
#             "app-main-header@*": 1,
#             "app-main-hotelshop-comment@*": 18,
#             "app-midas@*": 27,
#             "app-main-hotel-search-bar@*": 36,
#             "app-main-hotelshop@*": 40,
#             "app-main-hotelheader@*": 51,
#             "hippo@*": 52
#         }
#     }
# })</script>
# <script type="text/javascript">
#     var baseSearch = function () {
#         function a (a) {
#             return j.getElementById(a)
#         }
#
#         function b (a) {
#             return a.replace(/^\s+|\s+$/g, k)
#         }
#
#         function c () {
#             q();
#             var a = encodeURIComponent, c = b(d().replace(l, " ")).replace(/\//g, ""), e = f(o), g = f(p), h = -1 !== e.indexOf("{q}") ? e.replace("{q}", a(c)) : e + a(c);
#             return c || g ? i.location.href = -1 !== ["可送外卖", "外卖", "附近外卖", "外送", "外卖网"].indexOf(c) && "1" === m.getAttribute("data-s-cityid") ? "http://waimai.dianping.com" : c ? h : g : m.focus(), !1
#         }
#
#         function d () {
#             return m.value
#         }
#
#         function e (a) {
#             return m.getAttribute(a)
#         }
#
#         function f (a) {
#             for (var b = h, c = b.length; c--;)a = a.replace("{" + c + "}", b[c]);
#             return a
#         }
#
#         function g (a) {
#             var b;
#             document.createEvent ? (b = document.createEvent("HTMLEvents"), b.initEvent("click", !0, !0)) : (b = document.createEventObject(), b.eventType = "click"), b.eventName = "click", document.createEvent ? a.dispatchEvent(b) : a.fireEvent("on" + b.eventType, b)
#         }
#
#         var h = arguments, i = this, j = i.document, k = "", l = /[\\<]+/g, m = a("page-header").getElementsByTagName("input")[0], n = m.parentNode.getElementsByTagName("a")[0], o = e("data-s-pattern"), p = e("data-s-epattern"), q = n.onclick || function () {
#             };
#         return m.onkeydown = function (a) {
#             return a = a || i.event, 13 === a.keyCode ? (g(n), !1) : void 0
#         }, n.onclick = c, {
#             s: l, data: function () {
#                 h = arguments
#             }, val: function (a) {
#                 d = a
#             }, submit: c
#         }
#     }(1, 0);
# </script>
# <script>
#     facade({
#         entry: "app-main-hotel-search-bar", data: {
#             hotDestn: {
#                 "domestic": [
#                     {
#                         "cityId": 1,
#                         "displayName": "上海",
#                         "cityEnName": "shanghai",
#                         "url": "/shanghai/hotel/"
#                     },
#                     {
#                         "cityId": 2,
#                         "displayName": "北京",
#                         "cityEnName": "beijing",
#                         "url": "/beijing/hotel/"
#                     },
#                     {
#                         "cityId": 3,
#                         "displayName": "杭州",
#                         "cityEnName": "hangzhou",
#                         "url": "/hangzhou/hotel/"
#                     },
#                     {
#                         "cityId": 4,
#                         "displayName": "广州",
#                         "cityEnName": "guangzhou",
#                         "url": "/guangzhou/hotel/"
#                     },
#                     {
#                         "cityId": 5,
#                         "displayName": "南京",
#                         "cityEnName": "nanjing",
#                         "url": "/nanjing/hotel/"
#                     },
#                     {
#                         "cityId": 6,
#                         "displayName": "苏州",
#                         "cityEnName": "suzhou",
#                         "url": "/suzhou/hotel/"
#                     },
#                     {
#                         "cityId": 7,
#                         "displayName": "深圳",
#                         "cityEnName": "shenzhen",
#                         "url": "/shenzhen/hotel/"
#                     },
#                     {
#                         "cityId": 10,
#                         "displayName": "天津",
#                         "cityEnName": "tianjin",
#                         "url": "/tianjin/hotel/"
#                     },
#                     {
#                         "cityId": 8,
#                         "displayName": "成都",
#                         "cityEnName": "chengdu",
#                         "url": "/chengdu/hotel/"
#                     },
#                     {
#                         "cityId": 17,
#                         "displayName": "西安",
#                         "cityEnName": "xian",
#                         "url": "/xian/hotel/"
#                     },
#                     {
#                         "cityId": 16,
#                         "displayName": "武汉",
#                         "cityEnName": "wuhan",
#                         "url": "/wuhan/hotel/"
#                     },
#                     {
#                         "cityId": 15,
#                         "displayName": "厦门",
#                         "cityEnName": "xiamen",
#                         "url": "/xiamen/hotel/"
#                     },
#                     {
#                         "cityId": 9,
#                         "displayName": "重庆",
#                         "cityEnName": "chongqing",
#                         "url": "/chongqing/hotel/"
#                     },
#                     {
#                         "cityId": 341,
#                         "displayName": "香港",
#                         "cityEnName": "hongkong",
#                         "url": "/hongkong/hotel/"
#                     },
#                     {
#                         "cityId": 342,
#                         "displayName": "澳门",
#                         "cityEnName": "macau",
#                         "url": "/macau/hotel/"
#                     },
#                     {
#                         "cityId": 2335,
#                         "displayName": "台北",
#                         "cityEnName": "taipei",
#                         "url": "/taipei/hotel/"
#                     }
#                 ],
#                 "overseas": [
#                     {
#                         "cityId": 2342,
#                         "displayName": "曼谷",
#                         "cityEnName": "bangkok",
#                         "url": "/bangkok/hotel/"
#                     },
#                     {
#                         "cityId": 2343,
#                         "displayName": "普吉岛",
#                         "cityEnName": "phuket",
#                         "url": "/phuket/hotel/"
#                     },
#                     {
#                         "cityId": 2344,
#                         "displayName": "芭堤雅",
#                         "cityEnName": "pattaya",
#                         "url": "/pattaya/hotel/"
#                     },
#                     {
#                         "cityId": 2345,
#                         "displayName": "清迈",
#                         "cityEnName": "chiangmai",
#                         "url": "/chiangmai/hotel/"
#                     },
#                     {
#                         "cityId": 2369,
#                         "displayName": "首尔",
#                         "cityEnName": "seoul",
#                         "url": "/seoul/hotel/"
#                     },
#                     {
#                         "cityId": 2370,
#                         "displayName": "釜山",
#                         "cityEnName": "busan",
#                         "url": "/busan/hotel/"
#                     },
#                     {
#                         "cityId": 2371,
#                         "displayName": "济州岛",
#                         "cityEnName": "jeju",
#                         "url": "/jeju/hotel/"
#                     },
#                     {
#                         "cityId": 2372,
#                         "displayName": "东京",
#                         "cityEnName": "tokyo",
#                         "url": "/tokyo/hotel/"
#                     },
#                     {
#                         "cityId": 2373,
#                         "displayName": "京都",
#                         "cityEnName": "kyoto",
#                         "url": "/kyoto/hotel"
#                     },
#                     {
#                         "cityId": 2374,
#                         "displayName": "大阪",
#                         "cityEnName": "osaka",
#                         "url": "/osaka/hotel/"
#                     }
#                 ]
#             }
#         }
#     });
#     facade({entry: "app-main-hotelheader"});
#     facade({
#         entry: "app-main-header", data: {
#             isLogin: false,
#             loadUserDomain: "//www.dianping.com",
#             needAjaxOutput: false,
#             baseSearch: baseSearch,
#             cityId: 219
#         }
#     });
# </script>
# <script>
#     var rohrdata = "";
#     var Rohr_Opt = new Object;
#     Rohr_Opt.Flag = 100014;
#     Rohr_Opt.LogVal = "rohrdata";
# </script>
# <script crossorigin="anonymous" src="//www.dpfile.com/app/owl/static/owl_1.5.7.js"></script>
# <script>
#     Owl.start({
#         project: 'com.sankuai.hotel.fe.dphotelpc',
#         pageUrl: 'http://www.dianping.com/shop/'
#     })
# </script>
# <script crossorigin="anonymous" src="//awp-assets.meituan.net/hfe/hfe-assets/eb/raven-js/dist/raven.min.js"></script>
# <script crossorigin="anonymous" src="//awp-assets.meituan.net/hfe/rohr/1.0.2/rohr.min.js"></script>
# <script crossorigin="anonymous" src="//mc.meituan.net/hotel/dp-hotel-fe-pc/commons.d95992de7937a9c533ad.js"></script>
# <script crossorigin="anonymous" src="//mc.meituan.net/hotel/dp-hotel-fe-pc/poi-detail-client.893f8f903165deb4859f.js"></script>
# <script crossorigin="anonymous" defer="" src="//mc.meituan.net/hotel/dp-hotel-fe-pc/static/js/qrcode.min.js"></script>
# <!--<script defer src="//mc.meituan.net/hotel/dp-hotel-fe-pc/static/js/legacy.js"></script>-->
# </body>
# </html>

# %%
from multiprocessing.dummy import Pool as ThreadPool

# %%
async_pool = ThreadPool(processes=100)
result = async_pool.map_async(requests_visit_url_test,)
async_pool.close()
async_pool.join()
store_ls = result.get()
store_ls = list(itertools.chain.from_iterable(store_ls))
