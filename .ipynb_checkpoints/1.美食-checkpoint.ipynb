# %%
import os
import requests
import re
from bs4 import BeautifulSoup
import lxml
import os.path
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException,WebDriverException
from selenium.webdriver.common.keys import Keys
import time
import warnings
warnings.filterwarnings("ignore")
import pickle
import pandas as pd
from requests.exceptions import ProxyError,ConnectionError,Timeout,HTTPError,ChunkedEncodingError
import itertools
import multiprocessing
import Ipynb_importer
from IPpool import GetHeaders
from IPpool import Ip_pool
import random
import copy
import os
# import requests_toolbelt.adapters.appengine

# requests_toolbelt.adapters.appengine.monkeypatch()
# Out:
# importing Jupyter notebook from IPpool.ipynb

# %%
def requests_visit_url_test(url,is_use_ip =False,timeout=3):
        global ip_pool
        global bad_ip
        #headers = {"User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/61.0.3163.100 Chrome/61.0.3163.100 Safari/537.36"}
        headers = {"Accept":"application/json, text/javascript, */*; q=0.01",
                    "Accept-Encoding":"gzip, deflate",
                    "Accept-Language":"zh-CN,zh;q=0.8,en;q=0.6",
                    "Connection":"keep-alive",
                    "Cookie":"_hc.v=f72dbe69-bcfc-a9d4-1f7f-d8daeca1ad7f.1505634421; __utma=1.1801105885.1505634423.1505634423.1505636820.2; __utmz=1.1505634423.1.1.utmcsr=google.com.hk|utmccn=(referral)|utmcmd=referral|utmcct=/; _lxsdk_cuid=15e956d9d5ec8-0a28c942cf39be-2a044871-100200-15e956d9d5fc8; _lxsdk=15e956d9d5ec8-0a28c942cf39be-2a044871-100200-15e956d9d5fc8; _lx_utm=utm_source%3DBaidu%26utm_medium%3Dorganic; __mta=222713764.1505836341840.1507819135553.1507819166825.4; JSESSIONID=D2D3D245867334198A59E676F146C5A8; aburl=1; cy=4; cye=guangzhou; s_ViewType=10; _lxsdk_s=15f2012787a-db4-26a-c8%7C%7C47",
                    "Host":"www.dianping.com",
                    "Referer":"http://www.dianping.com/shop/92374637",
                    #"User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/61.0.3163.100 Chrome/61.0.3163.100 Safari/537.36",
                    "X-Requested-With":"XMLHttpRequest"}

        #获取任意一个请求头
        headers["User-Agent"] = random.choice(GetHeaders().user_agent_list)
        bad_ip = []  #用来装坏的ip
        
        #*********如果不设置ip的话**********************************
        if is_use_ip == False:
            res = requests.get(url,headers = headers,timeout=timeout)  #访问url，不设代理ip访问
            html =  res.content.decode('utf-8')
            soup  =  BeautifulSoup(html,'lxml')
            if soup.title.text == '403 Forbidden' or "有道" in soup.text:
                print("ip被禁止了！！！！！！！！！！！！！！！！")
                raise ConnectionError
           
        #************如果设置ip的话，则执行这一段*********************
        else:
            is_continue = True   #设置循环标志
            while is_continue:
            #整理成ip地址的格式
                try:
                    #
                    if len(ip_pool)==len(bad_ip):
                        ip_url = ['http://www.xicidaili.com/nn/']
                        test_url = "http://www.dianping.com/shop/2954893"
                        ip_pool= Ip_pool(ip_url).get_ip_pool(test_url)
                        prox_ip = random.choice(ip_pool)
                        bad_ip = []
                        
                    #******随机生成一个ip*******
                    prox_ip = random.choice(ip_pool)
                    http = prox_ip[0]
                    ip = prox_ip[1]
                    proxies={http:ip}
                    print(proxies)
                    
                    #*******用代理ip访问********
                    res = requests.get(url,headers = headers,proxies = proxies,timeout=timeout) #设代理ip访问
                    html =  res.content.decode('utf-8')
                    soup  =  BeautifulSoup(html,'lxml')
            
                    #********如果返回网页被禁止的情况，触发异常,否则返回正常**********
                    if soup.title.text == '403 Forbidden' or "有道" in soup.text:
                        print("ip被禁止了!!!!!!!!!!!!!!!!!!!!")
                        raise ConnectionError
                    else:
                        is_continue = False

                except HTTPError as e:
                    bad_ip.append(prox_ip)
                    print("断网")
                    prox_ip = random.choice(ip_pool)


                except Timeout as e:
                    bad_ip.append(prox_ip)
                    print("超时")
                    prox_ip = random.choice(ip_pool)


                except ConnectionError as e:
                    print("访问被拒")
                    prox_ip = random.choice(ip_pool)

        return soup

# %%
#**************将装机地址变成一组一组*****************
def get_chunk(adr_ls,n):
    new_adr_ls = copy.deepcopy(adr_ls)
    adr_chunk = [new_adr_ls[i:i + n] for i in range(0, len(new_adr_ls), n)]
    return adr_chunk

# %%
#设置谷歌浏览器的参数
def set_chrome_param():
    #PROXY = '175.155.24.61:808'
    options = webdriver.ChromeOptions()
    chrome_path = '/home/zhh/下载/chromedriver'  
    #options.add_argument('--proxy-server={0}'.format(PROXY))
    # 设置成中文
    options.add_argument('lang=zh_CN.UTF-8')
    # 添加头部
    #1允许所有图片；2阻止所有图片；3阻止第三方服务器图片
    prefs = {'profile.default_content_setting_values': { 'images':2}}
    options.add_experimental_option('prefs', prefs)
    options.add_argument('user-agent="Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.103 Safari/537.36"')
    chrome = webdriver.Chrome(chrome_path,chrome_options=options)
    return chrome

# %%
#requests请求网页，返回一个BeautifulSoup对象
def requests_visit_url(url,prox_ip=None):
    
    #*******设置请求头*************
    headers = {"Accept":"application/json, text/javascript, */*; q=0.01",
                    "Accept-Encoding":"gzip, deflate",
                    "Accept-Language":"zh-CN,zh;q=0.8,en;q=0.6",
                    "Connection":"keep-alive",
                    "Cookie":"_hc.v=f72dbe69-bcfc-a9d4-1f7f-d8daeca1ad7f.1505634421; __utma=1.1801105885.1505634423.1505634423.1505636820.2; __utmz=1.1505634423.1.1.utmcsr=google.com.hk|utmccn=(referral)|utmcmd=referral|utmcct=/; _lxsdk_cuid=15e956d9d5ec8-0a28c942cf39be-2a044871-100200-15e956d9d5fc8; _lxsdk=15e956d9d5ec8-0a28c942cf39be-2a044871-100200-15e956d9d5fc8; _lx_utm=utm_source%3DBaidu%26utm_medium%3Dorganic; __mta=222713764.1505836341840.1507819135553.1507819166825.4; JSESSIONID=D2D3D245867334198A59E676F146C5A8; aburl=1; cy=4; cye=guangzhou; s_ViewType=10; _lxsdk_s=15f2012787a-db4-26a-c8%7C%7C47",
                    "Host":"www.dianping.com",
                    "Referer":"http://www.dianping.com/shop/92374637",
                    #"User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/61.0.3163.100 Chrome/61.0.3163.100 Safari/537.36",
                    "X-Requested-With":"XMLHttpRequest"}
    headers["User-Agent"] = random.choice(GetHeaders().user_agent_list)
    #headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.103 Safari/537.36"}
    
    #********是否循环*************
    is_continue = True
    num = 0
    while is_continue:
        num +=1
        print("访问{0}次".format(num))
        try:
            #***********不设代理访问*************
            if prox_ip is None:
                res = requests.get(url,headers = headers)  #访问url，不设代理ip访问
            else:
                
            #*********设置代理ip访问*************
                http = prox_ip[0]
                ip = http+"://"+prox_ip[1]
                proxies={http:ip}
                res = requests.get(url,headers = headers,proxies = proxies) #设代理ip访问
            html =  res.content.decode('utf-8')
            soup  =  BeautifulSoup(html,'lxml')
            is_continue = False 
            
        except HTTPError as e:
            print("断网")
            time.sleep(2)
            
        except Timeout as e:
            print("请求超时")
            time.sleep(2)
            
        except ConnectionError as e:
            print("访问被拒")
            is_continue = True
            time.sleep(2)
    return soup

# %%
#缓存结果
def save_cache(result,filename):
    with open(filename,'wb') as f1:
        pickle.dump(result,f1)

# %%
#加载缓存
def read_cache(filename):
    with open(filename,'rb')as f1:
        result = pickle.load(f1)
    return result

# %%
# 切换路径
def get_spc_path(father_path,child_path):
    os.chdir(father_path)
    if os.path.exists(child_path):
        os.chdir(child_path)
    else:
        os.mkdir(child_path)
        os.chdir(child_path)
    print("done!!")

# %% [markdown]
# ## 1.二级分类层

# %%
# %%time
#获取所有的二级分类url
def classify(city_url,city,big_class):
    soup = requests_visit_url(city_url)
    clf_ls = []
    for i in soup.select("#classfy a"):
        clf_url = i["href"] #分类网址
        clf_tl = i.text.strip() # 分类标题
        clf_ls.append([big_class,city,clf_tl,clf_url])
    return clf_ls
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 7.87 µs

# %%
# %%time
# clf_ls = classify("http://www.dianping.com/search/category/7/10",'深圳',"美食")

# %% [markdown]
# ## 2.区县层

# %%
def get_region(class_ls=None,prox_ip=None):
    print('正在爬取{0}'.format(class_ls[-2]))
    url = class_ls[-1]  #url
    soup = requests_visit_url(url,prox_ip) #访问
    region_ls = [] #地区的列表
    for i in soup.select("#region-nav a"):
        if i.text.strip() != "不限":
            region_url = i["href"] 
            region_tl = i.text.strip()
            region = class_ls[:-1]
            region.extend([region_tl,region_url])
            region_ls.append(region)
    return region_ls

# %%
# ip = Ip_pool(['http://www.xicidaili.com/nn/'])
# ip_pool = ip.get_ip_pool(test_url='http://www.dianping.com/search/category/7/10/g104',timeout =1)

# %%
# %%time
# prox_ip = random.choice(ip_pool)
# region_ls = []
# for i in clf_ls:
#     print(i)
#     sub_region = get_region(i,prox_ip)
#     region_ls.append(sub_region)

# %%
# region_ls

# %% [markdown]
# ## 3.商圈层

# %%
def get_circle(region_ls=None):
    url = region_ls[-1]   #url网址
    soup = requests_visit_url(url) #访问BeautifulSoup
    circle_ls =[]             
    for i in soup.select("#region-nav-sub a"):  #商圈信息
        if i.span.text.strip()!="不限":   #剔除掉不限的url
            circle_url = i["href"]       #商圈url
            circle_tit = i.span.text.strip()  #商圈名
            circle = region_ls[:-1] 
            circle.extend([circle_tit,circle_url]) 
            circle_ls.append(circle)
            
    #如果没有商圈的话，就拿原来的url当作是商圈的url
    if circle_ls==[]:
        print(region_ls[-2]+"没有子分类！！")
        region_ls.insert(4,"没有商圈")
        circle_ls.append(region_ls)

    return circle_ls

# %%
# %%time
# circle_ls = get_circle(['美食',
#   '广州',
#   '茶餐厅',
#   '天河区',
#   'http://www.dianping.com/search/category/4/10/g207r22'])

# %% [markdown]
# ## 4.商家信息层

# %%
#获取每个商家的链接、店名
def get_stores(circle_ls = None):
    store_ls=[] #存储的列表
    url = circle_ls[-1]  #url
    soup = requests_visit_url_test(url,is_use_ip=True,timeout=1)  #访问当前主页
    is_continue = True
    page = 0
    while is_continue:
        page += 1
        print("正在爬取第{0}页".format(page))
        
        #解析数据
        if soup.select(".content") ==[]:
            print("此页没有任何信息！！")
            store_ls = []
            is_continue = False 
            
        else:
            for i in soup.select(".content"):  
                for j in i.select(".pic"):
                    store_name = j.img["alt"]   #店名
                    link = j.a["href"]     #详情层
                    store = circle_ls[:5]  #只取前5位
                    store.extend([url,store_name,link]) 
                    store_ls.append(store)


            #获取下一页的数据

            next_tag = soup.find_all("a",text = re.compile("下一页"))  #获取字符属性为下一页的url
            if next_tag != []:                                         #保证含有字符属性
                url = next_tag[0]["href"]                              #获取下一页的url
                soup = requests_visit_url_test(url,is_use_ip=True,timeout=2)   #更新BeautifulSoup对象
            else:
                url = ''
                is_continue  = False                                  #如果没有下一页，就停止更新
    
    return store_ls

# %%
# %%time
# store_ls = get_stores(['美食',
#   '广州',
#   '茶餐厅',
#   '天河区',
#   '天河城/体育中心',
#   'http://www.dianping.com/search/category/4/10/g207r1519'])

# %% [markdown]
# ## 5.详情层

# %%
#获取详情层的数据，如星级用户、浏览人数、均价
def get_info(store_ls=None):
    
    #首先先保证导入的数据不为空
    if store_ls !=[]:
        url = store_ls[-1] #详情信息表
        soup = requests_visit_url_test(url,is_use_ip =True,timeout=4)
        try:
            start = soup.select(".mid-rank-stars")[0]["title"]       #星级用户
        except Exception as e:
            print("start",e)
            start = ''

        try:
            review_count = soup.select("#reviewCount")[0].text  #浏览人数
        except Exception as e:
            review_count = ''
            print("review_coun",e)

        try:
            avgprice = soup.select("#avgPriceTitle")[0].text   #均价
        except Exception as e:
            avgprice = ''
            print("avgprice",e)

        #评分系统
        try:
            score= []
            for j in soup.select("#comment_score .item"):
                score.append(j.text)
            score = "|".join(score)

        except Exception as e:
            score = ""
            print("score",e)

        try:   
            address = soup.select(".address .item")[0].text.strip() #地址
        except Exception as e:
            address = ''
            print("address出错了",e)

        #电话号码
        try:
            tel =[]
            for i in soup.select(".tel .item"):
                tel.append(i.text)
            tel = "|".join(tel)

        except:
            tel=""
            print("tel出错了",e)

        #路径
        try:
            path = []
            for i in soup.select(".breadcrumb a"):
                path.append(i.text.strip())
            path ='>'.join(path)
        except Exception as e:
            print("path出错了",e)
            path =''
            
        #五星评论人数
        try:
            
            five_starts = soup.find_all(id=re.compile("reviewCountStar\d"))
            if five_starts ==[]:
                five =''
                four =''
                three =''
                two =''
                one =''
            else:
                five,four,three,two,one = list(map(lambda x:x.text.strip(),five_starts))
        except Exception as e:
            print("五星评论人数出错","---->",e)
            five =''
            four =''
            three =''
            two =''
            one =''

        info = store_ls[:]
        info.extend([start,review_count,avgprice,score,address,tel,five,four,three,two,one,path])
    return info

# %%
# get_info(['美食',
#   '广州',
#   '茶餐厅',
#   '天河区',
#   '天河城/体育中心',
#   'http://www.dianping.com/search/category/4/10/g207r1519p2',
#   '粤港烧卤鸭饭(天河店)',
#   'http://www.dianping.com/shop/94311152'])

# %% [markdown]
# ## 6 主程序

# %%
# %%time

clf_ls = classify("http://www.dianping.com/search/category/219/10",'东莞',"美食")
print("所有二级分类已经获取完毕")

region_ls = list(map(get_region,clf_ls))
print("获取所有的区域清单")
# Out:
# 访问1次
# 所有二级分类已经获取完毕
# 正在爬取小吃快餐
# 访问1次
# 正在爬取自助餐
# 访问1次
# 正在爬取面包甜点
# 访问1次
# 正在爬取粤菜
# 访问1次
# 正在爬取西餐
# 访问1次
# 正在爬取咖啡厅
# 访问1次
# 正在爬取日本料理
# 访问1次
# 正在爬取火锅
# 访问1次
# 正在爬取韩国料理
# 访问1次
# 正在爬取湘菜
# 访问1次
# 正在爬取东南亚菜
# 访问1次
# 正在爬取农家菜
# 访问1次
# 正在爬取烧烤
# 访问1次
# 正在爬取川菜
# 访问1次
# 正在爬取台湾菜
# 访问1次
# 正在爬取小龙虾
# 访问1次
# 正在爬取东北菜
# 访问1次
# 正在爬取私房菜
# 访问1次
# 正在爬取面馆
# 访问1次
# 正在爬取素菜
# 访问1次
# 正在爬取其他
# 访问1次
# 正在爬取创意菜
# 访问1次
# 正在爬取家常菜
# 访问1次
# 获取所有的区域清单
# CPU times: user 4.55 s, sys: 160 ms, total: 4.71 s
# Wall time: 51.6 s

# %%
#解链
region_ls = list(itertools.chain.from_iterable(region_ls))
region_ls
# Out:
# [['美食',
#   '东莞',
#   '小吃快餐',
#   '东城区',
#   'http://www.dianping.com/search/category/219/10/g112r434'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '南城区',
#   'http://www.dianping.com/search/category/219/10/g112r435'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '长安镇',
#   'http://www.dianping.com/search/category/219/10/g112r439'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '虎门镇',
#   'http://www.dianping.com/search/category/219/10/g112r437'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '万江区',
#   'http://www.dianping.com/search/category/219/10/g112r436'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '常平镇',
#   'http://www.dianping.com/search/category/219/10/g112r441'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '厚街镇',
#   'http://www.dianping.com/search/category/219/10/g112r438'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '莞城区',
#   'http://www.dianping.com/search/category/219/10/g112r433'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '塘厦镇',
#   'http://www.dianping.com/search/category/219/10/g112r445'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '石龙镇',
#   'http://www.dianping.com/search/category/219/10/g112r447'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '寮步镇',
#   'http://www.dianping.com/search/category/219/10/g112r12198'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '大朗镇',
#   'http://www.dianping.com/search/category/219/10/g112r442'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '松山湖高新区',
#   'http://www.dianping.com/search/category/219/10/g112r15442'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '凤岗镇',
#   'http://www.dianping.com/search/category/219/10/g112r12024'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '樟木头镇',
#   'http://www.dianping.com/search/category/219/10/g112r443'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '黄江镇',
#   'http://www.dianping.com/search/category/219/10/g112r12199'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '大岭山镇',
#   'http://www.dianping.com/search/category/219/10/g112r440'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '麻涌镇',
#   'http://www.dianping.com/search/category/219/10/g112r12203'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '中堂镇',
#   'http://www.dianping.com/search/category/219/10/g112r448'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '石碣镇',
#   'http://www.dianping.com/search/category/219/10/g112r446'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '清溪镇',
#   'http://www.dianping.com/search/category/219/10/g112r444'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '桥头镇',
#   'http://www.dianping.com/search/category/219/10/g112r12195'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '石排镇',
#   'http://www.dianping.com/search/category/219/10/g112r12192'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '茶山镇',
#   'http://www.dianping.com/search/category/219/10/g112r12191'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '高埗镇',
#   'http://www.dianping.com/search/category/219/10/g112r12204'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '横沥镇',
#   'http://www.dianping.com/search/category/219/10/g112r12194'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '东坑镇',
#   'http://www.dianping.com/search/category/219/10/g112r12197'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '道滘镇',
#   'http://www.dianping.com/search/category/219/10/g112r12201'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '沙田镇',
#   'http://www.dianping.com/search/category/219/10/g112r12200'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '企石镇',
#   'http://www.dianping.com/search/category/219/10/g112r12193'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '望牛墩镇',
#   'http://www.dianping.com/search/category/219/10/g112r12205'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '洪梅镇',
#   'http://www.dianping.com/search/category/219/10/g112r12202'],
#  ['美食',
#   '东莞',
#   '小吃快餐',
#   '谢岗镇',
#   'http://www.dianping.com/search/category/219/10/g112r12196'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '东城区',
#   'http://www.dianping.com/search/category/219/10/g111r434'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '南城区',
#   'http://www.dianping.com/search/category/219/10/g111r435'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '长安镇',
#   'http://www.dianping.com/search/category/219/10/g111r439'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '虎门镇',
#   'http://www.dianping.com/search/category/219/10/g111r437'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '万江区',
#   'http://www.dianping.com/search/category/219/10/g111r436'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '常平镇',
#   'http://www.dianping.com/search/category/219/10/g111r441'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '厚街镇',
#   'http://www.dianping.com/search/category/219/10/g111r438'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '莞城区',
#   'http://www.dianping.com/search/category/219/10/g111r433'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '塘厦镇',
#   'http://www.dianping.com/search/category/219/10/g111r445'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '石龙镇',
#   'http://www.dianping.com/search/category/219/10/g111r447'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '寮步镇',
#   'http://www.dianping.com/search/category/219/10/g111r12198'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '大朗镇',
#   'http://www.dianping.com/search/category/219/10/g111r442'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '松山湖高新区',
#   'http://www.dianping.com/search/category/219/10/g111r15442'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '凤岗镇',
#   'http://www.dianping.com/search/category/219/10/g111r12024'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '樟木头镇',
#   'http://www.dianping.com/search/category/219/10/g111r443'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '黄江镇',
#   'http://www.dianping.com/search/category/219/10/g111r12199'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '大岭山镇',
#   'http://www.dianping.com/search/category/219/10/g111r440'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '中堂镇',
#   'http://www.dianping.com/search/category/219/10/g111r448'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '石碣镇',
#   'http://www.dianping.com/search/category/219/10/g111r446'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '清溪镇',
#   'http://www.dianping.com/search/category/219/10/g111r444'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '桥头镇',
#   'http://www.dianping.com/search/category/219/10/g111r12195'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '石排镇',
#   'http://www.dianping.com/search/category/219/10/g111r12192'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '茶山镇',
#   'http://www.dianping.com/search/category/219/10/g111r12191'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '高埗镇',
#   'http://www.dianping.com/search/category/219/10/g111r12204'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '东坑镇',
#   'http://www.dianping.com/search/category/219/10/g111r12197'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '道滘镇',
#   'http://www.dianping.com/search/category/219/10/g111r12201'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '企石镇',
#   'http://www.dianping.com/search/category/219/10/g111r12193'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '洪梅镇',
#   'http://www.dianping.com/search/category/219/10/g111r12202'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '麻涌镇',
#   'http://www.dianping.com/search/category/219/10/g111r12203'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '横沥镇',
#   'http://www.dianping.com/search/category/219/10/g111r12194'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '沙田镇',
#   'http://www.dianping.com/search/category/219/10/g111r12200'],
#  ['美食',
#   '东莞',
#   '自助餐',
#   '谢岗镇',
#   'http://www.dianping.com/search/category/219/10/g111r12196'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '东城区',
#   'http://www.dianping.com/search/category/219/10/g117r434'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '南城区',
#   'http://www.dianping.com/search/category/219/10/g117r435'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '长安镇',
#   'http://www.dianping.com/search/category/219/10/g117r439'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '虎门镇',
#   'http://www.dianping.com/search/category/219/10/g117r437'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '万江区',
#   'http://www.dianping.com/search/category/219/10/g117r436'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '常平镇',
#   'http://www.dianping.com/search/category/219/10/g117r441'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '厚街镇',
#   'http://www.dianping.com/search/category/219/10/g117r438'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '莞城区',
#   'http://www.dianping.com/search/category/219/10/g117r433'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '塘厦镇',
#   'http://www.dianping.com/search/category/219/10/g117r445'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '石龙镇',
#   'http://www.dianping.com/search/category/219/10/g117r447'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '寮步镇',
#   'http://www.dianping.com/search/category/219/10/g117r12198'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '大朗镇',
#   'http://www.dianping.com/search/category/219/10/g117r442'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '松山湖高新区',
#   'http://www.dianping.com/search/category/219/10/g117r15442'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '凤岗镇',
#   'http://www.dianping.com/search/category/219/10/g117r12024'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '樟木头镇',
#   'http://www.dianping.com/search/category/219/10/g117r443'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '黄江镇',
#   'http://www.dianping.com/search/category/219/10/g117r12199'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '大岭山镇',
#   'http://www.dianping.com/search/category/219/10/g117r440'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '麻涌镇',
#   'http://www.dianping.com/search/category/219/10/g117r12203'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '中堂镇',
#   'http://www.dianping.com/search/category/219/10/g117r448'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '石碣镇',
#   'http://www.dianping.com/search/category/219/10/g117r446'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '清溪镇',
#   'http://www.dianping.com/search/category/219/10/g117r444'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '桥头镇',
#   'http://www.dianping.com/search/category/219/10/g117r12195'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '石排镇',
#   'http://www.dianping.com/search/category/219/10/g117r12192'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '茶山镇',
#   'http://www.dianping.com/search/category/219/10/g117r12191'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '高埗镇',
#   'http://www.dianping.com/search/category/219/10/g117r12204'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '横沥镇',
#   'http://www.dianping.com/search/category/219/10/g117r12194'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '东坑镇',
#   'http://www.dianping.com/search/category/219/10/g117r12197'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '道滘镇',
#   'http://www.dianping.com/search/category/219/10/g117r12201'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '沙田镇',
#   'http://www.dianping.com/search/category/219/10/g117r12200'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '企石镇',
#   'http://www.dianping.com/search/category/219/10/g117r12193'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '望牛墩镇',
#   'http://www.dianping.com/search/category/219/10/g117r12205'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '洪梅镇',
#   'http://www.dianping.com/search/category/219/10/g117r12202'],
#  ['美食',
#   '东莞',
#   '面包甜点',
#   '谢岗镇',
#   'http://www.dianping.com/search/category/219/10/g117r12196'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '东城区',
#   'http://www.dianping.com/search/category/219/10/g103r434'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '南城区',
#   'http://www.dianping.com/search/category/219/10/g103r435'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '长安镇',
#   'http://www.dianping.com/search/category/219/10/g103r439'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '虎门镇',
#   'http://www.dianping.com/search/category/219/10/g103r437'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '万江区',
#   'http://www.dianping.com/search/category/219/10/g103r436'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '常平镇',
#   'http://www.dianping.com/search/category/219/10/g103r441'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '厚街镇',
#   'http://www.dianping.com/search/category/219/10/g103r438'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '莞城区',
#   'http://www.dianping.com/search/category/219/10/g103r433'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '塘厦镇',
#   'http://www.dianping.com/search/category/219/10/g103r445'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '石龙镇',
#   'http://www.dianping.com/search/category/219/10/g103r447'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '寮步镇',
#   'http://www.dianping.com/search/category/219/10/g103r12198'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '大朗镇',
#   'http://www.dianping.com/search/category/219/10/g103r442'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '松山湖高新区',
#   'http://www.dianping.com/search/category/219/10/g103r15442'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '凤岗镇',
#   'http://www.dianping.com/search/category/219/10/g103r12024'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '樟木头镇',
#   'http://www.dianping.com/search/category/219/10/g103r443'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '黄江镇',
#   'http://www.dianping.com/search/category/219/10/g103r12199'],
#  ['美食',
#   '东莞',
#   '粤菜',
#   '大岭山镇',
#   'http://www.dianping.com/search/category/219/10/
],
#  ['美食',
#   '东莞',
#   '面馆',
#   '桥头镇',
#   'http://www.dianping.com/search/category/219/10/g215r12195'],
#  ['美食',
#   '东莞',
#   '面馆',
#   '石排镇',
#   'http://www.dianping.com/search/category/219/10/g215r12192'],
#  ['美食',
#   '东莞',
#   '面馆',
#   '茶山镇',
#   'http://www.dianping.com/search/category/219/10/g215r12191'],
#  ['美食',
#   '东莞',
#   '面馆',
#   '高埗镇',
#   'http://www.dianping.com/search/category/219/10/g215r12204'],
#  ['美食',
#   '东莞',
#   '面馆',
#   '横沥镇',
#   'http://www.dianping.com/search/category/219/10/g215r12194'],
#  ['美食',
#   '东莞',
#   '面馆',
#   '东坑镇',
#   'http://www.dianping.com/search/category/219/10/g215r12197'],
#  ['美食',
#   '东莞',
#   '面馆',
#   '沙田镇',
#   'http://www.dianping.com/search/category/219/10/g215r12200'],
#  ['美食',
#   '东莞',
#   '面馆',
#   '望牛墩镇',
#   'http://www.dianping.com/search/category/219/10/g215r12205'],
#  ['美食',
#   '东莞',
#   '面馆',
#   '道滘镇',
#   'http://www.dianping.com/search/category/219/10/g215r12201'],
#  ['美食',
#   '东莞',
#   '面馆',
#   '企石镇',
#   'http://www.dianping.com/search/category/219/10/g215r12193'],
#  ['美食',
#   '东莞',
#   '面馆',
#   '洪梅镇',
#   'http://www.dianping.com/search/category/219/10/g215r12202'],
#  ['美食',
#   '东莞',
#   '面馆',
#   '谢岗镇',
#   'http://www.dianping.com/search/category/219/10/g215r12196'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '东城区',
#   'http://www.dianping.com/search/category/219/10/g109r434'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '南城区',
#   'http://www.dianping.com/search/category/219/10/g109r435'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '长安镇',
#   'http://www.dianping.com/search/category/219/10/g109r439'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '万江区',
#   'http://www.dianping.com/search/category/219/10/g109r436'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '常平镇',
#   'http://www.dianping.com/search/category/219/10/g109r441'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '厚街镇',
#   'http://www.dianping.com/search/category/219/10/g109r438'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '莞城区',
#   'http://www.dianping.com/search/category/219/10/g109r433'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '塘厦镇',
#   'http://www.dianping.com/search/category/219/10/g109r445'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '石龙镇',
#   'http://www.dianping.com/search/category/219/10/g109r447'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '寮步镇',
#   'http://www.dianping.com/search/category/219/10/g109r12198'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '大朗镇',
#   'http://www.dianping.com/search/category/219/10/g109r442'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '黄江镇',
#   'http://www.dianping.com/search/category/219/10/g109r12199'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '大岭山镇',
#   'http://www.dianping.com/search/category/219/10/g109r440'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '石碣镇',
#   'http://www.dianping.com/search/category/219/10/g109r446'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '石排镇',
#   'http://www.dianping.com/search/category/219/10/g109r12192'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '茶山镇',
#   'http://www.dianping.com/search/category/219/10/g109r12191'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '高埗镇',
#   'http://www.dianping.com/search/category/219/10/g109r12204'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '虎门镇',
#   'http://www.dianping.com/search/category/219/10/g109r437'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '凤岗镇',
#   'http://www.dianping.com/search/category/219/10/g109r12024'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '樟木头镇',
#   'http://www.dianping.com/search/category/219/10/g109r443'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '中堂镇',
#   'http://www.dianping.com/search/category/219/10/g109r448'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '清溪镇',
#   'http://www.dianping.com/search/category/219/10/g109r444'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '横沥镇',
#   'http://www.dianping.com/search/category/219/10/g109r12194'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '东坑镇',
#   'http://www.dianping.com/search/category/219/10/g109r12197'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '道滘镇',
#   'http://www.dianping.com/search/category/219/10/g109r12201'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '企石镇',
#   'http://www.dianping.com/search/category/219/10/g109r12193'],
#  ['美食',
#   '东莞',
#   '素菜',
#   '谢岗镇',
#   'http://www.dianping.com/search/category/219/10/g109r12196'],
#  ['美食',
#   '东莞',
#   '其他',
#   '东城区',
#   'http://www.dianping.com/search/category/219/10/g118r434'],
#  ['美食',
#   '东莞',
#   '其他',
#   '南城区',
#   'http://www.dianping.com/search/category/219/10/g118r435'],
#  ['美食',
#   '东莞',
#   '其他',
#   '长安镇',
#   'http://www.dianping.com/search/category/219/10/g118r439'],
#  ['美食',
#   '东莞',
#   '其他',
#   '虎门镇',
#   'http://www.dianping.com/search/category/219/10/g118r437'],
#  ['美食',
#   '东莞',
#   '其他',
#   '万江区',
#   'http://www.dianping.com/search/category/219/10/g118r436'],
#  ['美食',
#   '东莞',
#   '其他',
#   '常平镇',
#   'http://www.dianping.com/search/category/219/10/g118r441'],
#  ['美食',
#   '东莞',
#   '其他',
#   '厚街镇',
#   'http://www.dianping.com/search/category/219/10/g118r438'],
#  ['美食',
#   '东莞',
#   '其他',
#   '莞城区',
#   'http://www.dianping.com/search/category/219/10/g118r433'],
#  ['美食',
#   '东莞',
#   '其他',
#   '塘厦镇',
#   'http://www.dianping.com/search/category/219/10/g118r445'],
#  ['美食',
#   '东莞',
#   '其他',
#   '石龙镇',
#   'http://www.dianping.com/search/category/219/10/g118r447'],
#  ['美食',
#   '东莞',
#   '其他',
#   '寮步镇',
#   'http://www.dianping.com/search/category/219/10/g118r12198'],
#  ['美食',
#   '东莞',
#   '其他',
#   '大朗镇',
#   'http://www.dianping.com/search/category/219/10/g118r442'],
#  ['美食',
#   '东莞',
#   '其他',
#   '松山湖高新区',
#   'http://www.dianping.com/search/category/219/10/g118r15442'],
#  ['美食',
#   '东莞',
#   '其他',
#   '凤岗镇',
#   'http://www.dianping.com/search/category/219/10/g118r12024'],
#  ['美食',
#   '东莞',
#   '其他',
#   '樟木头镇',
#   'http://www.dianping.com/search/category/219/10/g118r443'],
#  ['美食',
#   '东莞',
#   '其他',
#   '黄江镇',
#   'http://www.dianping.com/search/category/219/10/g118r12199'],
#  ['美食',
#   '东莞',
#   '其他',
#   '大岭山镇',
#   'http://www.dianping.com/search/category/219/10/g118r440'],
#  ['美食',
#   '东莞',
#   '其他',
#   '麻涌镇',
#   'http://www.dianping.com/search/category/219/10/g118r12203'],
#  ['美食',
#   '东莞',
#   '其他',
#   '中堂镇',
#   'http://www.dianping.com/search/category/219/10/g118r448'],
#  ['美食',
#   '东莞',
#   '其他',
#   '石碣镇',
#   'http://www.dianping.com/search/category/219/10/g118r446'],
#  ['美食',
#   '东莞',
#   '其他',
#   '清溪镇',
#   'http://www.dianping.com/search/category/219/10/g118r444'],
#  ['美食',
#   '东莞',
#   '其他',
#   '桥头镇',
#   'http://www.dianping.com/search/category/219/10/g118r12195'],
#  ['美食',
#   '东莞',
#   '其他',
#   '石排镇',
#   'http://www.dianping.com/search/category/219/10/g118r12192'],
#  ['美食',
#   '东莞',
#   '其他',
#   '茶山镇',
#   'http://www.dianping.com/search/category/219/10/g118r12191'],
#  ['美食',
#   '东莞',
#   '其他',
#   '高埗镇',
#   'http://www.dianping.com/search/category/219/10/g118r12204'],
#  ['美食',
#   '东莞',
#   '其他',
#   '横沥镇',
#   'http://www.dianping.com/search/category/219/10/g118r12194'],
#  ['美食',
#   '东莞',
#   '其他',
#   '东坑镇',
#   'http://www.dianping.com/search/category/219/10/g118r12197'],
#  ['美食',
#   '东莞',
#   '其他',
#   '道滘镇',
#   'http://www.dianping.com/search/category/219/10/g118r12201'],
#  ['美食',
#   '东莞',
#   '其他',
#   '沙田镇',
#   'http://www.dianping.com/search/category/219/10/g118r12200'],
#  ['美食',
#   '东莞',
#   '其他',
#   '企石镇',
#   'http://www.dianping.com/search/category/219/10/g118r12193'],
#  ['美食',
#   '东莞',
#   '其他',
#   '望牛墩镇',
#   'http://www.dianping.com/search/category/219/10/g118r12205'],
#  ['美食',
#   '东莞',
#   '其他',
#   '洪梅镇',
#   'http://www.dianping.com/search/category/219/10/g118r12202'],
#  ['美食',
#   '东莞',
#   '其他',
#   '谢岗镇',
#   'http://www.dianping.com/search/category/219/10/g118r12196'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '东城区',
#   'http://www.dianping.com/search/category/219/10/g250r434'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '南城区',
#   'http://www.dianping.com/search/category/219/10/g250r435'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '长安镇',
#   'http://www.dianping.com/search/category/219/10/g250r439'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '万江区',
#   'http://www.dianping.com/search/category/219/10/g250r436'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '厚街镇',
#   'http://www.dianping.com/search/category/219/10/g250r438'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '莞城区',
#   'http://www.dianping.com/search/category/219/10/g250r433'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '石龙镇',
#   'http://www.dianping.com/search/category/219/10/g250r447'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '寮步镇',
#   'http://www.dianping.com/search/category/219/10/g250r12198'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '松山湖高新区',
#   'http://www.dianping.com/search/category/219/10/g250r15442'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '大岭山镇',
#   'http://www.dianping.com/search/category/219/10/g250r440'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '桥头镇',
#   'http://www.dianping.com/search/category/219/10/g250r12195'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '虎门镇',
#   'http://www.dianping.com/search/category/219/10/g250r437'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '塘厦镇',
#   'http://www.dianping.com/search/category/219/10/g250r445'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '大朗镇',
#   'http://www.dianping.com/search/category/219/10/g250r442'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '凤岗镇',
#   'http://www.dianping.com/search/category/219/10/g250r12024'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '樟木头镇',
#   'http://www.dianping.com/search/category/219/10/g250r443'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '石碣镇',
#   'http://www.dianping.com/search/category/219/10/g250r446'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '道滘镇',
#   'http://www.dianping.com/search/category/219/10/g250r12201'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '沙田镇',
#   'http://www.dianping.com/search/category/219/10/g250r12200'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '洪梅镇',
#   'http://www.dianping.com/search/category/219/10/g250r12202'],
#  ['美食',
#   '东莞',
#   '创意菜',
#   '谢岗镇',
#   'http://www.dianping.com/search/category/219/10/g250r12196'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '东城区',
#   'http://www.dianping.com/search/category/219/10/g1783r434'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '南城区',
#   'http://www.dianping.com/search/category/219/10/g1783r435'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '长安镇',
#   'http://www.dianping.com/search/category/219/10/g1783r439'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '虎门镇',
#   'http://www.dianping.com/search/category/219/10/g1783r437'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '万江区',
#   'http://www.dianping.com/search/category/219/10/g1783r436'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '常平镇',
#   'http://www.dianping.com/search/category/219/10/g1783r441'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '厚街镇',
#   'http://www.dianping.com/search/category/219/10/g1783r438'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '莞城区',
#   'http://www.dianping.com/search/category/219/10/g1783r433'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '塘厦镇',
#   'http://www.dianping.com/search/category/219/10/g1783r445'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '凤岗镇',
#   'http://www.dianping.com/search/category/219/10/g1783r12024'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '黄江镇',
#   'http://www.dianping.com/search/category/219/10/g1783r12199'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '中堂镇',
#   'http://www.dianping.com/search/category/219/10/g1783r448'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '石排镇',
#   'http://www.dianping.com/search/category/219/10/g1783r12192'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '寮步镇',
#   'http://www.dianping.com/search/category/219/10/g1783r12198'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '大朗镇',
#   'http://www.dianping.com/search/category/219/10/g1783r442'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '樟木头镇',
#   'http://www.dianping.com/search/category/219/10/g1783r443'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '大岭山镇',
#   'http://www.dianping.com/search/category/219/10/g1783r440'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '麻涌镇',
#   'http://www.dianping.com/search/category/219/10/g1783r12203'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '石碣镇',
#   'http://www.dianping.com/search/category/219/10/g1783r446'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '清溪镇',
#   'http://www.dianping.com/search/category/219/10/g1783r444'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '桥头镇',
#   'http://www.dianping.com/search/category/219/10/g1783r12195'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '茶山镇',
#   'http://www.dianping.com/search/category/219/10/g1783r12191'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '高埗镇',
#   'http://www.dianping.com/search/category/219/10/g1783r12204'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '横沥镇',
#   'http://www.dianping.com/search/category/219/10/g1783r12194'],
#  ['美食',
#   '东莞',
#   '家常菜',
#   '东坑镇',
#   'http://www.dianping.com/search/category/219/10/g1783r12197']]

# %%
# %%time
#***************获取所有的商圈信息****************************888
circle_ls = list(map(get_circle,region_ls))
# Out:
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 麻涌镇没有子分类！！
# 访问1次
# 横沥镇没有子分类！！
# 访问1次
# 沙田镇没有子分类！！
# 访问1次
# 谢岗镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 谢岗镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 东坑镇没有子分类！！
# 访问1次
# 洪梅镇没有子分类！！
# 访问1次
# 谢岗镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 麻涌镇没有子分类！！
# 访问1次
# 石排镇没有子分类！！
# 访问1次
# 道滘镇没有子分类！！
# 访问1次
# 沙田镇没有子分类！！
# 访问1次
# 谢岗镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 洪梅镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 石排镇没有子分类！！
# 访问1次
# 横沥镇没有子分类！！
# 访问1次
# 企石镇没有子分类！！
# 访问1次
# 谢岗镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 寮步镇没有子分类！！
# 访问1次
# 大岭山镇没有子分类！！
# 访问1次
# 麻涌镇没有子分类！！
# 访问1次
# 茶山镇没有子分类！！
# 访问1次
# 横沥镇没有子分类！！
# 访问1次
# 道滘镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 莞城区没有子分类！！
# 访问1次
# 大岭山镇没有子分类！！
# 访问1次
# 麻涌镇没有子分类！！
# 访问1次
# 桥头镇没有子分类！！
# 访问1次
# 高埗镇没有子分类！！
# 访问1次
# 横沥镇没有子分类！！
# 访问1次
# 道滘镇没有子分类！！
# 访问1次
# 沙田镇没有子分类！！
# 访问1次
# 企石镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 道滘镇没有子分类！！
# 访问1次
# 沙田镇没有子分类！！
# 访问1次
# 望牛墩镇没有子分类！！
# 访问1次
# 洪梅镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 凤岗镇没有子分类！！
# 访问1次
# 樟木头镇没有子分类！！
# 访问1次
# 麻涌镇没有子分类！！
# 访问1次
# 中堂镇没有子分类！！
# 访问1次
# 桥头镇没有子分类！！
# 访问1次
# 茶山镇没有子分类！！
# 访问1次
# 东坑镇没有子分类！！
# 访问1次
# 沙田镇没有子分类！！
# 访问1次
# 企石镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 樟木头镇没有子分类！！
# 访问1次
# 黄江镇没有子分类！！
# 访问1次
# 大岭山镇没有子分类！！
# 访问1次
# 麻涌镇没有子分类！！
# 访问1次
# 中堂镇没有子分类！！
# 访问1次
# 石碣镇没有子分类！！
# 访问1次
# 清溪镇没有子分类！！
# 访问1次
# 桥头镇没有子分类！！
# 访问1次
# 石排镇没有子分类！！
# 访问1次
# 茶山镇没有子分类！！
# 访问1次
# 高埗镇没有子分类！！
# 访问1次
# 横沥镇没有子分类！！
# 访问1次
# 东坑镇没有子分类！！
# 访问1次
# 道滘镇没有子分类！！
# 访问1次
# 沙田镇没有子分类！！
# 访问1次
# 企石镇没有子分类！！
# 访问1次
# 谢岗镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 石碣镇没有子分类！！
# 访问1次
# 桥头镇没有子分类！！
# 访问1次
# 石排镇没有子分类！！
# 访问1次
# 茶山镇没有子分类！！
# 访问1次
# 横沥镇没有子分类！！
# 访问1次
# 东坑镇没有子分类！！
# 访问1次
# 望牛墩镇没有子分类！！
# 访问1次
# 谢岗镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 大岭山镇没有子分类！！
# 访问1次
# 麻涌镇没有子分类！！
# 访问1次
# 桥头镇没有子分类！！
# 访问1次
# 东坑镇没有子分类！！
# 访问1次
# 道滘镇没有子分类！！
# 访问1次
# 企石镇没有子分类！！
# 访问1次
# 望牛墩镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 道滘镇没有子分类！！
# 访问1次
# 企石镇没有子分类！！
# 访问1次
# 洪梅镇没有子分类！！
# 访问1次
# 谢岗镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 虎门镇没有子分类！！
# 访问1次
# 凤岗镇没有子分类！！
# 访问1次
# 樟木头镇没有子分类！！
# 访问1次
# 中堂镇没有子分类！！
# 访问1次
# 清溪镇没有子分类！！
# 访问1次
# 横沥镇没有子分类！！
# 访问1次
# 东坑镇没有子分类！！
# 访问1次
# 道滘镇没有子分类！！
# 访问1次
# 企石镇没有子分类！！
# 访问1次
# 谢岗镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 望牛墩镇没有子分类！！
# 访问1次
# 洪梅镇没有子分类！！
# 访问1次
# 谢岗镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 虎门镇没有子分类！！
# 访问1次
# 塘厦镇没有子分类！！
# 访问1次
# 大朗镇没有子分类！！
# 访问1次
# 凤岗镇没有子分类！！
# 访问1次
# 樟木头镇没有子分类！！
# 访问1次
# 石碣镇没有子分类！！
# 访问1次
# 道滘镇没有子分类！！
# 访问1次
# 沙田镇没有子分类！！
# 访问1次
# 洪梅镇没有子分类！！
# 访问1次
# 谢岗镇没有子分类！！
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 访问1次
# 寮步镇没有子分类！！
# 访问1次
# 大朗镇没有子分类！！
# 访问1次
# 樟木头镇没有子分类！！
# 访问1次
# 大岭山镇没有子分类！！
# 访问1次
# 麻涌镇没有子分类！！
# 访问1次
# 石碣镇没有子分类！！
# 访问1次
# 清溪镇没有子分类！！
# 访问1次
# 桥头镇没有子分类！！
# 访问1次
# 茶山镇没有子分类！！
# 访问1次
# 高埗镇没有子分类！！
# 访问1次
# 横沥镇没有子分类！！
# 访问1次
# 东坑镇没有子分类！！
# CPU times: user 2min 3s, sys: 3.65 s, total: 2min 6s
# Wall time: 24min 45s

# %%
#解链
circle_ls = list(itertools.chain.from_iterable(circle_ls))

# %%
get_spc_path("/home/zhh/dzdp_data/","dgmeishi")
# Out:
# done!!

# %%
save_cache(circle_ls,"/home/zhh/dzdp_data/dgmeishi/东莞_circle_ls.pickle")

# %%
circle_ls = read_cache("/home/zhh/dzdp_data/dgmeishi/东莞_circle_ls.pickle")
print(len(circle_ls))
circle_chunk = get_chunk(circle_ls,5)
len(circle_chunk)
# Out:
# 2063
# 413

# %%
offset=1
save_cache(offset,"/home/zhh/dzdp_data/dgmeishi/东莞_offset.pickle")

# %%
# %%time
if __name__=='__main__':
    
    
    is_continue = True
    while is_continue:
        
        try:
            #如果偏移量已经达到了660,跳出整个大循环
            offset = read_cache("/home/zhh/dzdp_data/dgmeishi/东莞_offset.pickle")
            end = len(circle_chunk)
            if offset >= len(circle_chunk):
                print("整个程序已经完毕！！！")
                break
                
            #************爬取代理ip******************
            global ip_pool
            ip_url = ['http://www.xicidaili.com/nn/']
            test_url = "http://www.dianping.com/shop/2954893"
            ip_pool= Ip_pool(ip_url).get_ip_pool(test_url)
        
                
            #***********多进程处理*************************
            for index,chunk in enumerate(circle_chunk[offset:end]):
                offset_index = offset + index                       #偏移量+计数器
                print("正在爬第{0}chunk".format(offset_index))
                pool = multiprocessing.Pool(processes=3)           # 创建3个进程
                result = []
                for i in chunk:
                    result.append(pool.apply_async(get_stores, (i, ))) #将参数全部加进去
                pool.close()                                  # 关闭进程池，表示不能再往进程池中添加进程，需要在join之前调用
                pool.join()                                   # 等待进程池中的所有进程执行完毕
                
                #***********遍历每个进程的结果*****************
                store_ls = []
                for res in result:
                    store_ls.append(res.get())               #
                
                #***********获取每一个chunk的内容****************
                print("第{0}chunk已经爬完了".format(offset_index))
                store_ls = list(itertools.chain.from_iterable(store_ls))
                save_cache(store_ls,"/home/zhh/dzdp_data/dgmeishi/东莞_store_ls_{0}_chunk.pickle".format(offset_index))
                
                #********爬完直接将偏移量设为下一个*************************
                last_offset_1 = offset_index+1
                save_cache(last_offset_1,"/home/zhh/dzdp_data/dgmeishi/东莞_offset.pickle")
                
        #***************如果出现ChunkedEncodingError重复执行这段代码*********************     
        except ChunkedEncodingError as e:
            print("出现ChunkedEncodingError")
            last_offset_2 = offset_index
            print("chunkedEncodingError保存offset:{0}".format(last_offset_2))
            save_cache(last_offset_2,"/home/zhh/dzdp_data/dgmeishi/东莞_offset.pickle")
            continue
            
        #***************如果出现ChunkedEncodingError重复执行这段代码*********************      
        except KeyboardInterrupt as e:
            print("手动停止")
            last_offset_3 = offset_index
            print("KeyboardInterrupt保存现有的offset:{0}".format(last_offset_3))
            save_cache(last_offset_3,"/home/zhh/dzdp_data/dgmeishi/东莞_offset.pickle")
            break
            
            
#     print("***********准备爬商家的详情信息******************")
#     pool = multiprocessing.Pool(processes=3) # 创建3个进程
#     result=[]
#     for i in store_ls:
#         result.append(pool.apply_async(get_info,(i,)))
#     pool.close()
#     pool.join()
    
#     print("信息页已经爬完了！！")
#     info_ls=[]
#     for res in result:
#         info_ls.append(res.get())
#     save_cache(info_ls,"/media/zhh/东方国信/智润安排/移动互联网需求/爬虫/缓存/广州_info_test_ls.pickle")
# Out:
# http://www.xicidaili.com/nn/
# {'Accept': 'application/json, text/javascript, */*; q=0.01', 'Accept-Encoding': 'gzip, deflate, br', 'Accept-Language': 'zh-CN,zh;q=0.8', 'Connection': 'keep-alive', 'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8', 'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24'}
# 坏ip: ['http', 'http://121.31.100.24:8123']
# 坏ip: ['http', 'http://218.18.232.29:8080']
# 坏ip: ['http', 'http://61.178.238.122:63000']
# 坏ip: ['http', 'http://220.166.242.8:8118']
# 坏ip: ['http', 'http://110.73.10.163:8123']
# 坏ip: ['http', 'http://27.40.136.37:61234']
# 坏ip: ['http', 'http://171.38.97.227:8118']
# 坏ip: ['http', 'http://124.72.96.215:27479']
# 坏ip: ['http', 'http://110.73.40.104:8123']
# 坏ip: ['http', 'http://110.73.0.128:8123']
# 坏ip: ['http', 'http://110.73.1.101:8123']
# 坏ip: ['http', 'http://110.73.13.253:8123']
# 坏ip: ['http', 'http://180.122.150.203:36273']
# 坏ip: ['http', 'http://110.73.1.135:8123']
# 坏ip: ['http', 'http://27.40.134.51:61234']
# 坏ip: ['http', 'http://121.31.101.108:8123']
# 坏ip: ['http', 'http://182.43.198.243:22059']
# 坏ip: ['http', 'http://119.52.222.68:9999']
# 坏ip: ['http', 'http://110.73.2.48:8123']
# 坏ip: ['http', 'http://221.227.251.229:8888']
# 坏ip: ['http', 'http://121.31.100.171:8123']
# 坏ip: ['http', 'http://27.40.146.156:61234']
# 坏ip: ['http', 'http://110.73.11.18:8123']
# 坏ip: ['http', 'http://110.73.5.96:8123']
# 坏ip: ['http', 'http://113.121.21.46:808']
# 坏ip: ['http', 'http://121.31.100.36:8123']
# 坏ip: ['http', 'http://111.155.116.212:8123']
# 坏ip: ['http', 'http://180.115.8.64:47615']
# 正在爬第1chunk
# {'https': 'https://112.64.104.56:8118'}
# {'https': 'https://49.87.180.107:44472'}
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://106.58.150.19:80'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第2页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第2页
# {'https': 'https://112.64.104.56:8118'}
# 正在爬取第2页
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第1页
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第3页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第1页
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第4页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第5页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第2页
# 超时
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第6页
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第2页
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第7页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第8页
# 正在爬取第3页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第4页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第5页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第6页
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第7页
# 第1chunk已经爬完了
# 正在爬第2chunk
# {'http': 'http://111.200.58.94:80'}
# {'https': 'https://222.247.150.229:80'}
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第1页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第2页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第2页
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第1页
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第3页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第3页
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第4页
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第4页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第5页
# 正在爬取第5页
# {'https': 'https://116.30.192.84:53281'}
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第6页
# 正在爬取第6页
# {'https': 'https://39.64.0.88:8118'}
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://219.155.10.249:8118'}
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第2页
# 正在爬取第2页
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第2页
# 正在爬取第3页
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第4页
# {'http': 'http://111.200.58.94:80'}
# 正在爬取第5页
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第6页
# 第2chunk已经爬完了
# 正在爬第3chunk
# {'https': 'https://121.31.100.228:8123'}
# {'https': 'https://125.122.94.121:808'}
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第6页
# 正在爬取第10页
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第11页
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第12页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第13页
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第3页
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第14页
# 正在爬取第4页
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第5页
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第6页
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第7页
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第8页
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第9页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第10页
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第11页
# 第19chunk已经爬完了
# 正在爬第20chunk
# {'https': 'https://27.40.134.212:61234'}
# {'https': 'https://49.87.180.107:44472'}
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第1页
# {'https': 'https://171.108.205.85:53281'}
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第2页
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第2页
# 正在爬取第2页
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第3页
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第3页
# 正在爬取第3页
# {'https': 'https://112.64.104.56:8118'}
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第4页
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第4页
# 正在爬取第4页
# {'https': 'https://112.64.104.56:8118'}
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第5页
# 正在爬取第5页
# {'https': 'https://113.121.163.109:23621'}
# {'http': 'http://111.200.58.94:80'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第2页
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第3页
# 正在爬取第6页
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第7页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第8页
# 第20chunk已经爬完了
# 正在爬第21chunk
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://121.31.192.83:8123'}
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://121.31.192.83:8123'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第1页
# 正在爬取第2页
# 正在爬取第1页
# {'https': 'https://59.40.51.123:8010'}
# {'https': 'https://27.40.134.212:61234'}
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第2页
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第2页
# 正在爬取第3页
# {'https': 'https://49.87.180.107:44472'}
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第3页
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第4页
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第3页
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第5页
# 正在爬取第4页
# 正在爬取第4页
# {'https': 'https://121.12.42.68:61234'}
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第5页
# 正在爬取第5页
# 第21chunk已经爬完了
# 正在爬第22chunk
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://39.64.0.88:8118'}
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://182.42.38.49:35885'}
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第1页
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第2页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第2页
# 正在爬取第2页
# {'https': 'https://121.31.192.83:8123'}
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第3页
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第3页
# 正在爬取第3页
# {'https': 'https://121.12.42.68:61234'}
# {'http': 'http://111.200.58.94:80'}
# 正在爬取第4页
# {'https': 'https://114.99.94.101:21868'}
# 超时
# {'https': 'https://42.225.81.198:9999'}
# 访问被拒
# {'https': 'https://116.30.192.84:53281'}
# 访问被拒
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第4页
# {'http': 'http://111.200.58.94:80'}
# 超时
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第5页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第4页
# {'http': 'http://111.200.58.94:80'}
# 正在爬取第5页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第6页
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第6页
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第5页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第1页
# 正在爬取第7页
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# {'https': 'https://112.64.104.56:8118'}
# 正在爬取第8页
# {'https': 'https://112.64.104.56:8118'}
# 正在爬取第2页
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第9页
# 正在爬取第3页
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第4页
# 第22chunk已经爬完了
# 正在爬第23chunk
# {'https': 'https://49.87.180.107:44472'}
# {'https': 'https://121.12.42.68:61234'}
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://125.122.94.121:808'}
# {'https': 'https://42.225.81.198:9999'}
# 超时
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第2页
# 正在爬取第2页
# {'http': 'http://118.114.77.47:8080'}
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第1页
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第3页
# 正在爬取第3页
# {'http': 'http://118.114.77.47:8080'}
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第2页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第1页
# 正在爬取第2页
# 正在爬取第4页
# {'http': 'http://118.114.77.47:8080'}
# {'https': 'https://27.40.134.212:61234'}
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第3页
# 正在爬取第5页
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第2页
# 正在爬取第4页
# 第23chunk已经爬完了
# 正在爬第24chunk
# {'http': 'http://118.114.77.47:8080'}
# {'http': 'http://118.114.77.47:8080'}
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第1页
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://114.99.94.101:21868'}
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第2页
# 正在爬取第2页
# {'https': 'https://113.236.174.213:8118'}
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第2页
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第1页
# 正在爬取第3页
# 正在爬取第3页
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://106.58.150.19:80'}
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第2页
# 正在爬取第4页
# 正在爬取第1页
# 第24chunk已经爬完了
# 正在爬第25chunk
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://121.31.100.228:8123'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'http': 'http://111.200.58.94:80'}
# {'https': 'https://27.40.134.212:61234'}
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第2页
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第2页
# {'https': 'https://49.87.180.107:44472'}
# 超时
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第3页
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第3页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第2页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第1页
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第3页
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第2页
# 正在爬取第2页
# 超时
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第4页
# 第25chunk已经爬完了
# 正在爬第26chunk
# {'https': 'https://39.64.0.88:8118'}
# {'https': 'https://106.58.150.19:80'}
# {'http': 'http://111.200.58.94:80'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://27.40.134.212:61234'}
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第2页
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第1页
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第1页
# 正在爬取第2页
# 正在爬取第1页
# 第26chunk已经爬完了
# 正在爬第27chunk
# {'http': 'http://111.200.58.94:80'}
# {'http': 'http://111.200.58.94:80'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# {'https': 'https://114.99.94.101:21868'}
# 超时
# {'https': 'https://112.64.104.56:8118'}
# 正在爬取第1页
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第27chunk已经爬完了
# 正在爬第28chunk
# {'https': 'https://39.64.0.88:8118'}
# {'https': 'https://116.30.192.84:53281'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://39.64.0.88:8118'}
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第28chunk已经爬完了
# 正在爬第29chunk
# {'https': 'https://121.31.100.228:8123'}
# {'https': 'https://219.155.10.249:8118'}
# {'https': 'https://112.64.104.56:8118'}
# 正在爬取第1页
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第1页
# 正在爬取第1页
# 第29chunk已经爬完了
# 正在爬第30chunk
# {'https': 'https://182.42.38.49:35885'}
# {'https': 'https://222.247.150.229:80'}
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://182.42.38.49:35885'}
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第1页
# 正在爬取第1页
# 第30chunk已经爬完了
# 正在爬第31chunk
# {'https': 'https://121.12.42.68:61234'}
# {'https': 'https://113.121.163.109:23621'}
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第1页
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第1页
# 正在爬取第1页
# 第31chunk已经爬完了
# 正在爬第32chunk
# {'https': 'https://121.31.100.228:8123'}
# {'https': 'https://39.64.0.88:8118'}
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://222.247.150.229:80'}
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第1页
# 正在爬取第1页
# 第32chunk已经爬完了
# 正在爬第33chunk
# {'https': 'https://121.31.192.83:8123'}
# {'https': 'https://59.40.51.123:8010'}
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# 正在爬取第1页
# {'http': 'http://111.200.58.94:80'}
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第1页
# 正在爬取第1页
# 超时
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第1页
# 第33chunk已经爬完了
# 正在爬第34chunk
# {'https': 'https://39.64.0.88:8118'}
# {'https': 'https://112.64.104.56:8118'}
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# 正在爬取第1页
# 第34chunk已经爬完了
# 正在爬第35chunk
# {'https': 'https://222.247.150.229:80'}
# {'https': 'https://125.122.94.121:808'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第1页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第35chunk已经爬完了
# 正在爬第36chunk
# {'https': 'https://114.99.94.101:21868'}
# {'https': 'https://114.99.94.101:21868'}
# {'https': 'https://171.108.205.85:53281'}
# 超时
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第1页
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第1页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第36chunk已经爬完了
# 正在爬第37chunk
# {'https': 'https://59.40.51.123:8010'}
# {'https': 'https://219.155.10.249:8118'}
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第1页
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第1页
# 正在爬取第1页
# 第37chunk已经爬完了
# 正在爬第38chunk
# {'https': 'https://110.73.41.69:8123'}
# {'http': 'http://111.200.58.94:80'}
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第1页
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第1页
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第38chunk已经爬完了
# 正在爬第39chunk
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://39.64.0.88:8118'}
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第1页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第1页
# 正在爬取第1页
# 第39chunk已经爬完了
# 正在爬第40chunk
# {'http': 'http://111.200.58.94:80'}
# {'https': 'https://106.58.150.19:80'}
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第1页
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第40chunk已经爬完了
# 正在爬第41chunk
# {'https': 'https://182.42.38.49:35885'}
# {'https': 'https://49.87.180.107:44472'}
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第1页
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第1页
# 超时
# {'https': 'https://59.40.51.123:8010'}
# 超时
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第1页
# 正在爬取第1页
# 第41chunk已经爬完了
# 正在爬第42chunk
# {'https': 'https://116.30.192.84:53281'}
# {'https': 'https://182.42.38.49:35885'}
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://182.42.38.49:35885'}
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第42chunk已经爬完了
# 正在爬第43chunk
# {'https': 'https://222.247.150.229:80'}
# {'https': 'https://106.58.150.19:80'}
# {'http': 'http://111.200.58.94:80'}
# 超时
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://121.31.192.83:8123'}
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第43chunk已经爬完了
# 正在爬第44chunk
# {'https': 'https://39.64.0.88:8118'}
# {'https': 'https://39.64.0.88:8118'}
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第1页
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第1页
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第1页
# 超时
# {'http': 'http://111.200.58.94:80'}
# 正在爬取第1页
# 超时
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第1页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第2页
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第3页
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第4页
# 第44chunk已经爬完了
# 正在爬第45chunk
# {'http': 'http://111.200.58.94:80'}
# {'https': 'https://121.31.100.228:8123'}
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://113.236.174.213:8118'}
# {'http': 'http://118.114.77.47:8080'}
# 超时
# {'http': 'http://111.200.58.94:80'}
# 正在爬取第2页
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第2页
# {'https': 'https://110.73.41.69:8123'}
# 超时
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第3页
# 正在爬取第3页
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第1页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第2页
# {'https': 'https://182.42.38.49:35885'}
# {'http': 'http://111.200.58.94:80'}
# 正在爬取第2页
# {'https': 'https://121.31.100.228:8123'}
# 超时
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第3页
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第3页
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第4页
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第4页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第5页
# 正在爬取第5页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第6页
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第7页
# 第45chunk已经爬完了
# 正在爬第46chunk
# {'https': 'https://112.64.104.56:8118'}
# {'https': 'https://121.12.42.68:61234'}
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://121.31.192.83:8123'}
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第1页
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第1页
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第2页
# 正在爬取第2页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第3页
# 第46chunk已经爬完了
# 正在爬第47chunk
# {'http': 'http://111.200.58.94:80'}
# {'https': 'https://106.58.150.19:80'}
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第1页
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第1页
# {'http': 'http://111.200.58.94:80'}
# 正在爬取第2页
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第2页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第1页
# 正在爬取第2页
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第2页
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第3页
# 访问被拒
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第2页
# 第47chunk已经爬完了
# 正在爬第48chunk
# {'https': 'https://106.58.150.19:80'}
# {'https': 'https://113.236.174.213:8118'}
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第1页
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://121.12.42.68:61234'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# 正在爬取第2页
# 正在爬取第1页
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第2页
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第3页
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第4页
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第5页
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第6页
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第7页
# 第48chunk已经爬完了
# 正在爬第49chunk
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://110.73.41.69:8123'}
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://59.40.51.123:8010'}
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第1页
# 正在爬取第2页
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第2页
# {'http': 'http://111.200.58.94:80'}
# 正在爬取第2页
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第3页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第4页
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第1页
# {'https': 'https://42.225.81.198:9999'}
# 超时
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第5页
# 正在爬取第2页
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第3页
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第3页
# 正在爬取第4页
# {'https': 'https://121.12.42.68:61234'}
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第4页
# 正在爬取第5页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第6页
# 第49chunk已经爬完了
# 正在爬第50chunk
# {'https': 'https://27.40.134.212:61234'}
# {'https': 'https://49.87.180.107:44472'}
# {'https': 'https://112.64.104.56:8118'}
# 正在爬取第1页
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://113.236.174.213:8118'}
# {'http': 'http://118.114.77.47:8080'}
# 超时
# {'https': 'https://59.40.51.123:8010'}
# 超时
# {'https': 'https://121.12.42.68:61234'}
# 超时
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第2页
# 正在爬取第1页
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第1页
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第3页
# 正在爬取第2页
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第3页
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第4页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第5页
# 第50chunk已经爬完了
# 正在爬第51chunk
# {'https': 'https://114.99.94.101:21868'}
# {'https': 'https://106.58.150.19:80'}
# {'http': 'http://111.200.58.94:80'}
# 超时
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第1页
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第1页
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第2页
# {'https': 'https://112.64.104.56:8118'}
# 正在爬取第1页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第2页
# 正在爬取第1页
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第1页
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第2页
# 正在爬取第2页
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第3页
# 第51chunk已经爬完了
# 正在爬第52chunk
# {'https': 'https://116.30.192.84:53281'}
# {'http': 'http://118.114.77.47:8080'}
# {'https': 'https://112.64.104.56:8118'}
# 正在爬取第1页
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第1页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第1页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第1页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第2页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第2页
# 正在爬取第2页
# 正在爬取第3页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第4页
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第5页
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第6页
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第7页
# {'https': 'https://112.64.104.56:8118'}
# 正在爬取第8页
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第9页
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第10页
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第11页
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第12页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第13页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第14页
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第15页
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第16页
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第17页
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第18页
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第19页
# 第52chunk已经爬完了
# 正在爬第53chunk
# {'https': 'https://182.42.38.49:35885'}
# {'https': 'https://182.42.38.49:35885'}
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://49.87.180.107:44472'}
# {'https': 'https://42.225.81.198:9999'}
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第2页
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第2页
# 正在爬取第1页
# {'https': 'https://121.31.192.83:8123'}
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第2页
# 正在爬取第3页
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第3页
# {'https': 'https://219.155.10.249:8118'}
# {'http': 'http://111.200.58.94:80'}
# 正在爬取第1页
# 正在爬取第4页
# {'https': 'https://112.64.104.56:8118'}
# 超时
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第4页
# 正在爬取第5页
# 第53chunk已经爬完了
# 正在爬第54chunk
# {'https': 'https://112.64.104.56:8118'}
# {'https': 'https://125.122.94.121:808'}
# {'https': 'https://112.64.104.56:8118'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第1页
# {'https': 'https://42.225.81.198:9999'}
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第2页
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第1页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第2页
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第3页
# 正在爬取第2页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第3页
# {'https': 'https://42.225.81.198:9999'}
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第3页
# 正在爬取第1页
# 正在爬取第4页
# {'https': 'https://171.108.205.85:53281'}
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第5页
# 正在爬取第2页
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第3页
# {'http': 'http://118.114.77.47:8080'}
# 访问被拒
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第4页
# 第54chunk已经爬完了
# 正在爬第55chunk
# {'https': 'https://114.99.94.101:21868'}
# {'https': 'https://110.73.41.69:8123'}
# {'http': 'http://118.114.77.47:8080'}
# 访问被拒
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第1页
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第1页
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第1页
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第2页
# 正在爬取第2页
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第3页
# {'https': 'https://112.64.104.56:8118'}
# 正在爬取第4页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第5页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第6页
# 第55chunk已经爬完了
# 正在爬第56chunk
# {'https': 'https://106.58.150.19:80'}
# {'https': 'https://125.122.94.121:808'}
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第1页
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第1页
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第1页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第2页
# 正在爬取第1页
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第2页
# 正在爬取第1页
# {'https': 'https://112.64.104.56:8118'}
# 正在爬取第2页
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第3页
# 第56chunk已经爬完了
# 正在爬第57chunk
# {'https': 'https://222.247.150.229:80'}
# {'https': 'https://219.155.10.249:8118'}
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://27.40.134.212:61234'}
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第2页
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第3页
# 第57chunk已经爬完了
# 正在爬第58chunk
# {'https': 'https://116.30.192.84:53281'}
# {'https': 'https://125.122.94.121:808'}
# {'http': 'http://111.200.58.94:80'}
# 正在爬取第1页
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第1页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第2页
# {'http': 'http://111.200.58.94:80'}
# 正在爬取第2页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第3页
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第2页
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第1页
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第1页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第3页
# 正在爬取第2页
# 正在爬取第2页
# 第58chunk已经爬完了
# 正在爬第59chunk
# {'https': 'https://113.121.163.109:23621'}
# {'https': 'https://116.30.192.84:53281'}
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第1页
# {'https': 'https://112.64.104.56:8118'}
# 正在爬取第1页
# 正在爬取第1页
# {'http': 'http://111.200.58.94:80'}
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第2页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第2页
# {'https': 'https://110.73.41.69:8123'}
# 超时
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# 正在爬取第3页
# {'https': 'https://42.225.81.198:9999'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第2页
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第2页
# 正在爬取第4页
# {'https': 'https://114.99.94.101:21868'}
# ...
# 正在爬取第1页
# 正在爬取第1页
# 第363chunk已经爬完了
# 正在爬第364chunk
# {'https': 'https://49.87.180.107:44472'}
# {'https': 'https://182.42.38.49:35885'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第364chunk已经爬完了
# 正在爬第365chunk
# {'https': 'https://222.247.150.229:80'}
# {'https': 'https://39.64.0.88:8118'}
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第1页
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第1页
# 正在爬取第1页
# 第365chunk已经爬完了
# 正在爬第366chunk
# {'https': 'https://116.30.192.84:53281'}
# {'https': 'https://121.31.192.83:8123'}
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://171.108.205.85:53281'}
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第1页
# 正在爬取第1页
# 第366chunk已经爬完了
# 正在爬第367chunk
# {'https': 'https://113.121.163.109:23621'}
# {'https': 'https://59.40.51.123:8010'}
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第1页
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第1页
# 正在爬取第1页
# 第367chunk已经爬完了
# 正在爬第368chunk
# {'https': 'https://116.30.192.84:53281'}
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://116.30.192.84:53281'}
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第368chunk已经爬完了
# 正在爬第369chunk
# {'https': 'https://182.42.38.49:35885'}
# {'https': 'https://59.40.51.123:8010'}
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://121.12.42.68:61234'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第369chunk已经爬完了
# 正在爬第370chunk
# {'https': 'https://121.12.42.68:61234'}
# {'https': 'https://219.155.10.249:8118'}
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第1页
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第370chunk已经爬完了
# 正在爬第371chunk
# {'https': 'https://39.64.0.88:8118'}
# {'https': 'https://39.64.0.88:8118'}
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://113.121.163.109:23621'}
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第371chunk已经爬完了
# 正在爬第372chunk
# {'https': 'https://219.155.10.249:8118'}
# {'https': 'https://113.236.174.213:8118'}
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# 正在爬取第1页
# 第372chunk已经爬完了
# 正在爬第373chunk
# {'https': 'https://219.155.10.249:8118'}
# {'https': 'https://121.31.100.228:8123'}
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第1页
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第1页
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第1页
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第1页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第2页
# 正在爬取第1页
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第2页
# 正在爬取第2页
# 第373chunk已经爬完了
# 正在爬第374chunk
# {'https': 'https://27.40.134.212:61234'}
# {'https': 'https://219.155.10.249:8118'}
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第1页
# {'https': 'https://114.99.94.101:21868'}
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第2页
# 正在爬取第1页
# 正在爬取第1页
# 第374chunk已经爬完了
# 正在爬第375chunk
# {'https': 'https://106.58.150.19:80'}
# {'https': 'https://113.121.163.109:23621'}
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://219.155.10.249:8118'}
# {'https': 'https://114.99.94.101:21868'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# 正在爬取第2页
# 正在爬取第1页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第2页
# 第375chunk已经爬完了
# 正在爬第376chunk
# {'https': 'https://121.31.192.83:8123'}
# {'https': 'https://27.40.134.212:61234'}
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://42.225.81.198:9999'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第1页
# 正在爬取第2页
# 正在爬取第1页
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第2页
# 第376chunk已经爬完了
# 正在爬第377chunk
# {'https': 'https://222.247.150.229:80'}
# {'https': 'https://113.236.174.213:8118'}
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://116.30.192.84:53281'}
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第2页
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第2页
# 正在爬取第2页
# 正在爬取第3页
# 第377chunk已经爬完了
# 正在爬第378chunk
# {'https': 'https://125.122.94.121:808'}
# {'https': 'https://125.122.94.121:808'}
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://219.155.10.249:8118'}
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第2页
# 正在爬取第1页
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第2页
# 正在爬取第1页
# 第378chunk已经爬完了
# 正在爬第379chunk
# {'https': 'https://113.236.174.213:8118'}
# {'https': 'https://125.122.94.121:808'}
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第1页
# 正在爬取第1页
# {'http': 'http://118.114.77.47:8080'}
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第1页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# 正在爬取第2页
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第1页
# 正在爬取第3页
# 第379chunk已经爬完了
# 正在爬第380chunk
# {'https': 'https://106.58.150.19:80'}
# {'https': 'https://49.87.180.107:44472'}
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://171.108.205.85:53281'}
# {'https': 'https://113.236.174.213:8118'}
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第2页
# 正在爬取第1页
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第2页
# 正在爬取第1页
# {'http': 'http://111.200.58.94:80'}
# 超时
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第2页
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第3页
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第4页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第5页
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第6页
# {'http': 'http://111.200.58.94:80'}
# 超时
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第7页
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第8页
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第9页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第10页
# 第380chunk已经爬完了
# 正在爬第381chunk
# {'https': 'https://39.64.0.88:8118'}
# {'https': 'https://42.225.81.198:9999'}
# {'http': 'http://111.200.58.94:80'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第2页
# 正在爬取第1页
# {'https': 'https://121.12.42.68:61234'}
# 超时
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第1页
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第2页
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第3页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第2页
# 正在爬取第4页
# 第381chunk已经爬完了
# 正在爬第382chunk
# {'https': 'https://27.40.134.212:61234'}
# {'https': 'https://121.31.100.228:8123'}
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第1页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第1页
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第1页
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第2页
# 第382chunk已经爬完了
# 正在爬第383chunk
# {'https': 'https://59.40.51.123:8010'}
# {'https': 'https://27.40.134.212:61234'}
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://125.122.94.121:808'}
# {'https': 'https://219.155.10.249:8118'}
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第1页
# 正在爬取第2页
# 正在爬取第1页
# 第383chunk已经爬完了
# 正在爬第384chunk
# {'https': 'https://27.40.134.212:61234'}
# {'https': 'https://59.40.51.123:8010'}
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'http': 'http://118.114.77.47:8080'}
# {'https': 'https://27.40.134.212:61234'}
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# 正在爬取第2页
# 正在爬取第1页
# 第384chunk已经爬完了
# 正在爬第385chunk
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://121.31.192.83:8123'}
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第1页
# 正在爬取第1页
# 第385chunk已经爬完了
# 正在爬第386chunk
# {'https': 'https://121.31.192.83:8123'}
# {'https': 'https://171.108.205.85:53281'}
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第1页
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://106.58.150.19:80'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第2页
# 正在爬取第1页
# 正在爬取第1页
# 第386chunk已经爬完了
# 正在爬第387chunk
# {'https': 'https://42.225.81.198:9999'}
# {'https': 'https://121.12.42.68:61234'}
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# {'http': 'http://111.200.58.94:80'}
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第2页
# 正在爬取第1页
# {'https': 'https://116.30.192.84:53281'}
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第2页
# 正在爬取第1页
# 正在爬取第2页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第3页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第4页
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第5页
# 第387chunk已经爬完了
# 正在爬第388chunk
# {'https': 'https://49.87.180.107:44472'}
# {'https': 'https://59.40.51.123:8010'}
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://113.236.174.213:8118'}
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://112.64.104.56:8118'}
# 正在爬取第2页
# 第388chunk已经爬完了
# 正在爬第389chunk
# {'https': 'https://116.30.192.84:53281'}
# {'https': 'https://222.247.150.229:80'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'http': 'http://111.200.58.94:80'}
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第1页
# 超时
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第1页
# 第389chunk已经爬完了
# 正在爬第390chunk
# {'https': 'https://114.99.94.101:21868'}
# {'https': 'https://42.225.81.198:9999'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第1页
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第390chunk已经爬完了
# 正在爬第391chunk
# {'https': 'https://27.40.134.212:61234'}
# {'https': 'https://49.87.180.107:44472'}
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第1页
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第1页
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第391chunk已经爬完了
# 正在爬第392chunk
# {'https': 'https://171.108.205.85:53281'}
# {'https': 'https://113.121.163.109:23621'}
# {'https': 'https://39.64.0.88:8118'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第1页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第2页
# 正在爬取第2页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第1页
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第3页
# 正在爬取第2页
# 第392chunk已经爬完了
# 正在爬第393chunk
# {'http': 'http://118.114.77.47:8080'}
# {'https': 'https://42.225.81.198:9999'}
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第1页
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第1页
# 正在爬取第1页
# 第393chunk已经爬完了
# 正在爬第394chunk
# {'https': 'https://219.155.10.249:8118'}
# {'http': 'http://111.200.58.94:80'}
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第1页
# {'https': 'https://49.87.180.107:44472'}
# 正在爬取第1页
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# 正在爬取第2页
# 第394chunk已经爬完了
# 正在爬第395chunk
# {'https': 'https://121.12.42.68:61234'}
# {'https': 'https://114.99.94.101:21868'}
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第1页
# 正在爬取第1页
# {'http': 'http://118.114.77.47:8080'}
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第395chunk已经爬完了
# 正在爬第396chunk
# {'https': 'https://182.42.38.49:35885'}
# {'https': 'https://39.64.0.88:8118'}
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://106.58.150.19:80'}
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第1页
# 正在爬取第1页
# 第396chunk已经爬完了
# 正在爬第397chunk
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://42.225.81.198:9999'}
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第1页
# 正在爬取第1页
# {'http': 'http://111.200.58.94:80'}
# 正在爬取第1页
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# 正在爬取第1页
# 第397chunk已经爬完了
# 正在爬第398chunk
# {'https': 'https://113.236.174.213:8118'}
# {'https': 'https://121.31.100.228:8123'}
# {'http': 'http://111.200.58.94:80'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://114.99.94.101:21868'}
# {'http': 'http://118.114.77.47:8080'}
# 超时
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第2页
# 第398chunk已经爬完了
# 正在爬第399chunk
# {'https': 'https://121.31.100.228:8123'}
# {'https': 'https://125.122.94.121:808'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第1页
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第2页
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第3页
# 第399chunk已经爬完了
# 正在爬第400chunk
# {'https': 'https://116.30.192.84:53281'}
# {'https': 'https://42.225.81.198:9999'}
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第1页
# {'https': 'https://114.99.94.101:21868'}
# 正在爬取第1页
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第400chunk已经爬完了
# 正在爬第401chunk
# {'https': 'https://113.236.174.213:8118'}
# {'https': 'https://113.236.174.213:8118'}
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# 正在爬取第1页
# 第401chunk已经爬完了
# 正在爬第402chunk
# {'https': 'https://39.64.0.88:8118'}
# {'https': 'https://222.247.150.229:80'}
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://121.31.192.83:8123'}
# {'https': 'https://59.40.51.123:8010'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第402chunk已经爬完了
# 正在爬第403chunk
# {'https': 'https://121.12.42.68:61234'}
# {'https': 'https://114.99.94.101:21868'}
# {'https': 'https://219.155.10.249:8118'}
# 正在爬取第1页
# {'https': 'https://116.30.192.84:53281'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://106.58.150.19:80'}
# 正在爬取第1页
# 正在爬取第1页
# 第403chunk已经爬完了
# 正在爬第404chunk
# {'https': 'https://114.99.94.101:21868'}
# {'https': 'https://121.31.192.83:8123'}
# {'https': 'https://112.64.104.56:8118'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第1页
# {'https': 'https://125.122.94.121:808'}
# 正在爬取第1页
# 正在爬取第1页
# 第404chunk已经爬完了
# 正在爬第405chunk
# {'https': 'https://42.225.81.198:9999'}
# {'https': 'https://125.122.94.121:808'}
# {'https': 'https://27.40.134.212:61234'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://116.30.192.84:53281'}
# {'https': 'https://113.236.174.213:8118'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第405chunk已经爬完了
# 正在爬第406chunk
# {'https': 'https://125.122.94.121:808'}
# {'https': 'https://114.99.94.101:21868'}
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://125.122.94.121:808'}
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第406chunk已经爬完了
# 正在爬第407chunk
# {'https': 'https://121.31.100.228:8123'}
# {'https': 'https://121.31.192.83:8123'}
# {'https': 'https://222.247.150.229:80'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第1页
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第1页
# 正在爬取第1页
# 第407chunk已经爬完了
# 正在爬第408chunk
# {'https': 'https://116.30.192.84:53281'}
# {'https': 'https://112.64.104.56:8118'}
# {'https': 'https://114.99.94.101:21868'}
# 超时
# 超时
# 超时
# {'https': 'https://113.121.163.109:23621'}
# {'https': 'https://113.121.163.109:23621'}
# {'https': 'https://121.31.192.83:8123'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://121.31.192.83:8123'}
# {'http': 'http://118.114.77.47:8080'}
# 正在爬取第1页
# 正在爬取第1页
# 第408chunk已经爬完了
# 正在爬第409chunk
# {'https': 'https://222.247.150.229:80'}
# {'https': 'https://113.236.174.213:8118'}
# {'https': 'https://42.225.81.198:9999'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://121.12.42.68:61234'}
# {'https': 'https://182.42.38.49:35885'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第409chunk已经爬完了
# 正在爬第410chunk
# {'https': 'https://113.121.163.109:23621'}
# {'https': 'https://113.121.163.109:23621'}
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://110.73.41.69:8123'}
# {'https': 'https://110.73.41.69:8123'}
# 正在爬取第1页
# 正在爬取第1页
# 第410chunk已经爬完了
# 正在爬第411chunk
# {'https': 'https://49.87.180.107:44472'}
# {'https': 'https://39.64.0.88:8118'}
# {'https': 'https://121.12.42.68:61234'}
# 正在爬取第1页
# {'https': 'https://121.31.100.228:8123'}
# 正在爬取第1页
# 正在爬取第1页
# {'https': 'https://113.121.163.109:23621'}
# 正在爬取第1页
# 正在爬取第1页
# 第411chunk已经爬完了
# 正在爬第412chunk
# {'https': 'https://113.236.174.213:8118'}
# {'https': 'https://49.87.180.107:44472'}
# {'https': 'https://171.108.205.85:53281'}
# 正在爬取第1页
# 正在爬取第1页
# 正在爬取第1页
# 第412chunk已经爬完了
# 整个程序已经完毕！！！
# CPU times: user 16 s, sys: 12.9 s, total: 28.9 s
# Wall time: 46min 55s

# %% [markdown]
# ## 爬取所有的商家信息

# %%
def merge_chunk(file_dir,regrex="(.*?_store_ls_\d+_chunk.pickle)"):
    file_ls = os.listdir(file_dir)  #得出列出文件
    re_ptn = re.compile(regrex)   #正则表达式
    files = []
    result =[]
    for i in file_ls:
        if re_ptn.search(i):
            files.append(i)
    
    print("合并{0}个chunk".format(len(files)))
    for i in files:
        sub_result = read_cache(file_dir+i)
        result.extend(sub_result)
    return result

# %% [markdown]
# ##### 佛山

# %%
result = merge_chunk("/home/zhh/dzdp_data/fsmeishi/")
# Out:
# 合并214个chunk

# %%
info_chunk = get_chunk(result,10)
len(info_chunk)
# Out:
# 3110

# %%
info_chunk
# Out:
# [['美食',
#   '佛山',
#   '西北菜',
#   '南海区',
#   '保利水城',
#   'http://www.dianping.com/search/category/208/10/g26481r66732',
#   '九毛九山西面馆(保利水城店)',
#   'http://www.dianping.com/shop/22405680'],
#  ['美食',
#   '佛山',
#   '西北菜',
#   '南海区',
#   '中海环宇城',
#   'http://www.dianping.com/search/category/208/10/g26481r70294',
#   '陇·牛一碗(中海寰宇店)',
#   'http://www.dianping.com/shop/69485224'],
#  ['美食',
#   '佛山',
#   '西北菜',
#   '南海区',
#   '越秀广场',
#   'http://www.dianping.com/search/category/208/10/g26481r70305',
#   '陇·牛一碗(越秀悦汇天地店)',
#   'http://www.dianping.com/shop/76881460'],
#  ['美食',
#   '佛山',
#   '西北菜',
#   '三水区',
#   '西南',
#   'http://www.dianping.com/search/category/208/10/g26481r6144',
#   '面东家(恒福广场店)',
#   'http://www.dianping.com/shop/8849541'],
#  ['美食',
#   '佛山',
#   '西北菜',
#   '三水区',
#   '西南',
#   'http://www.dianping.com/search/category/208/10/g26481r6144',
#   '西北兰州牛肉拉面',
#   'http://www.dianping.com/shop/21162007'],
#  ['美食',
#   '佛山',
#   '西北菜',
#   '三水区',
#   '西南',
#   'http://www.dianping.com/search/category/208/10/g26481r6144',
#   '聚高新能源有限公司',
#   'http://www.dianping.com/shop/72367888'],
#  ['美食',
#   '佛山',
#   '西北菜',
#   '高明区',
#   '荷城',
#   'http://www.dianping.com/search/category/208/10/g26481r8285',
#   '面东家(高明店)',
#   'http://www.dianping.com/shop/6591654'],
#  ['美食',
#   '佛山',
#   '西北菜',
#   '高明区',
#   '荷城',
#   'http://www.dianping.com/search/category/208/10/g26481r8285',
#   '稻草屋',
#   'http://www.dianping.com/shop/65113755'],
#  ['美食',
#   '佛山',
#   '湘菜',
#   '顺德区',
#   '勒流街道',
#   'http://www.dianping.com/search/category/208/10/g104r38339',
#   '品湘楼',
#   'http://www.dianping.com/shop/8028106'],
#  ['美食',
#   '佛山',
#   '湘菜',
#   '顺德区',
#   '勒流街道',
#   'http://www.dianping.com/search/category/208/10/g104r38339',
#   '情湘阁湘菜馆',
#   'http://www.dianping.com/shop/9310903']]

# %%
global ip_pool
ip_url = ['http://www.xicidaili.com/nn/']
test_url = "http://www.dianping.com/shop/2954893"
ip_pool= Ip_pool(ip_url).get_ip_pool(test_url)
# Out:
# http://www.xicidaili.com/nn/
# {'Accept': 'application/json, text/javascript, */*; q=0.01', 'Accept-Encoding': 'gzip, deflate, br', 'Accept-Language': 'zh-CN,zh;q=0.8', 'Connection': 'keep-alive', 'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8', 'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3'}
# 坏ip: ['http', 'http://119.137.194.35:80']
# 坏ip: ['http', 'http://139.213.51.243:9999']
# 坏ip: ['http', 'http://61.178.238.122:63000']
# 坏ip: ['http', 'http://182.88.179.52:8123']
# 坏ip: ['http', 'http://171.38.97.227:8118']
# 坏ip: ['http', 'http://222.76.146.183:45832']
# 坏ip: ['http', 'http://121.31.100.24:8123']
# 坏ip: ['http', 'http://110.73.6.191:8123']
# 坏ip: ['http', 'http://121.31.101.51:8123']
# 坏ip: ['http', 'http://27.40.136.37:61234']
# 坏ip: ['http', 'http://110.73.5.145:8123']
# 坏ip: ['http', 'http://114.230.197.2:8118']
# 坏ip: ['http', 'http://124.72.96.215:27479']
# 坏ip: ['http', 'http://110.73.0.128:8123']
# 坏ip: ['http', 'http://121.12.42.99:61234']
# 坏ip: ['http', 'http://60.169.78.218:808']
# 坏ip: ['http', 'http://121.31.102.36:8123']
# 坏ip: ['http', 'http://59.40.51.149:8010']
# 坏ip: ['http', 'http://113.121.163.109:23621']

# %%
ip_pool
# Out:
# [['https', 'https://183.157.177.6:80'],
#  ['http', 'http://61.135.217.7:80'],
#  ['https', 'https://39.64.0.88:8118'],
#  ['http', 'http://183.130.10.85:80'],
#  ['https', 'https://182.88.188.243:8123'],
#  ['https', 'https://121.31.103.41:8123'],
#  ['https', 'https://59.40.50.30:8010'],
#  ['https', 'https://125.72.106.151:808'],
#  ['https', 'https://175.19.42.253:8080'],
#  ['https', 'https://121.31.102.184:8123'],
#  ['https', 'https://171.39.43.195:8123'],
#  ['https', 'https://121.31.177.198:8123'],
#  ['https', 'https://180.121.133.111:8118'],
#  ['https', 'https://153.34.199.194:80'],
#  ['https', 'https://223.241.78.15:8010'],
#  ['https', 'https://180.115.8.87:27929'],
#  ['https', 'https://110.72.29.177:8123'],
#  ['https', 'https://124.165.170.146:9999'],
#  ['https', 'https://219.155.10.249:8118'],
#  ['https', 'https://106.58.150.19:80'],
#  ['https', 'https://222.247.150.229:80'],
#  ['https', 'https://27.40.134.212:61234'],
#  ['https', 'https://110.73.41.69:8123'],
#  ['https', 'https://49.87.180.107:44472'],
#  ['https', 'https://115.201.181.143:9999'],
#  ['https', 'https://60.17.243.174:9999'],
#  ['https', 'https://110.73.11.140:8123'],
#  ['https', 'https://121.12.42.250:61234'],
#  ['https', 'https://120.78.15.63:80'],
#  ['https', 'https://123.55.2.29:30433'],
#  ['https', 'https://171.124.61.115:9999']]

# %%
get_info(['美食',
  '佛山',
  '湘菜',
  '顺德区',
  '勒流街道',
  'http://www.dianping.com/search/category/208/10/g104r38339',
  '情湘阁湘菜馆',
  'http://www.dianping.com/shop/9310903'])
# Out:
# {'http': 'http://183.130.10.85:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://110.73
8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://59.40.50.30:8010'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'http': 'http://183.130.10.85:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://115.201.181.143:9999'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://171.39.43.195:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://27.40.134.212:61234'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://121.31.177.198:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://110.72.29.177:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://39.64.0.88:8118'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://183.157.177.6:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://59.40.50.30:8010'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://110.73.41.69:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'http': 'http://61.135.217.7:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://223.241.78.15:8010'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://223.241.78.15:8010'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://115.201.181.143:9999'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://223.241.78.15:8010'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://110.73.41.69:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://39.64.0.88:8118'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://175.19.42.253:8080'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://121.31.103.41:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://110.72.29.177:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://120.78.15.63:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://171.124.61.115:9999'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://59.40.50.30:8010'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://110.73.41.69:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://171.124.61.115:9999'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://110.72.29.177:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://121.31.177.198:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://115.201.181.143:9999'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://124.165.170.146:9999'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://219.155.10.249:8118'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://219.155.10.249:8118'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'http': 'http://61.135.217.7:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://27.40.134.212:61234'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'http': 'http://183.130.10.85:80'}
# 访问被拒
# {'https': 'https://183.157.177.6:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://59.40.50.30:8010'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://121.12.42.250:61234'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://123.55.2.29:30433'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://153.34.199.194:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://120.78.15.63:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://124.165.170.146:9999'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://180.115.8.87:27929'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://121.31.177.198:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://120.78.15.63:80'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://60.17.243.174:9999'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://60.17.243.174:9999'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://124.165.170.146:9999'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://60.17.243.174:9999'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://180.121.133.111:8118'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://110.73.41.69:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://110.72.29.177:8123'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://124.165.170.146:9999'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://223.241.78.15:8010'}
# ip被禁止了!!!!!!!!!!!!!!!!!!!!
# 访问被拒
# {'https': 'https://222.247.150.229:80'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-135-c23ea91069ad> in <module>()
#       6   'http://www.dianping.com/search/category/208/10/g104r38339',
#       7   '情湘阁湘菜馆',
# ----> 8   'http://www.dianping.com/shop/9310903'])
#
# <ipython-input-112-ed221dd4a743> in get_info(store_ls)
#       5     if store_ls !=[]:
#       6         url = store_ls[-1] #详情信息表
# ----> 7         soup = requests_visit_url_test(url,is_use_ip =True,timeout=4)
#       8         try:
#       9             start = soup.select(".mid-rank-stars")[0]["title"]       #星级用户
#
# <ipython-input-134-9a9f9f0c03c8> in requests_visit_url_test(url, is_use_ip, timeout)
#      48
#      49                     #*******用代理ip访问********
# ---> 50                     res = requests.get(url,headers = headers,proxies = proxies,timeout=timeout) #设代理ip访问
#      51                     html =  res.content.decode('utf-8')
#      52                     soup  =  BeautifulSoup(html,'lxml')
#
# /home/zhh/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /home/zhh/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /home/zhh/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /home/zhh/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /home/zhh/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /home/zhh/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /home/zhh/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     355             conn.request_chunked(method, url, **httplib_request_kw)
#     356         else:
# --> 357             conn.request(method, url, **httplib_request_kw)
#     358
#     359         # Reset the timeout for the recv() on the socket
#
# /home/zhh/anaconda3/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /home/zhh/anaconda3/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# /home/zhh/anaconda3/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# /home/zhh/anaconda3/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# /home/zhh/anaconda3/lib/python3.6/http/client.py in send(self, data)
#     962         if self.sock is None:
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#     966                 raise NotConnected()
#
# /home/zhh/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     164
#     165     def connect(self):
# --> 166         conn = self._new_conn()
#     167         self._prepare_conn(conn)
#     168
#
# /home/zhh/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# /home/zhh/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      58     family = allowed_gai_family()
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#      62         sock = None
#
# /home/zhh/anaconda3/lib/python3.6/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     741     # and socket type values to enum constants.
#     742     addrlist = []
# --> 743     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     744         af, socktype, proto, canonname, sa = res
#     745         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:

# %%
soup=requests_visit_url_test("http://www.dianping.com/shop/9310903",is_use_ip=True)
# Out:
# {'http': 'http://183.130.10.85:80'}
# ip被禁止了
# 访问被拒
# {'https': 'https://106.58.150.19:80'}
# ip被禁止了
# 访问被拒
# {'http': 'http://61.135.217.7:80'}

# %%
"有道" in soup.text
# Out:
# True
